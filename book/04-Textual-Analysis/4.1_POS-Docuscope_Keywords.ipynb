# %% [markdown]
# # 4. Part-of-Speech Tagging &amp; Docuscope's Rhetorical Tagging

# %% [markdown]
# **Goal**: Learn about the textual analysis method called speech tagging.
#
# Speech-tagging methods can help us humans computationally parse, sort, and filter sentences in a large corpus, so we can retroactively also better understand any words of interest in their contexts of use.
#
# We will be working with the English-language `docuscospacy` model in this lesson—a LLM developed by rhetoricians at Carnegie Mellon University. I'd like to thank them for providing users their helpful documentation, which I have modified to use in this lesson.
#
# In this lesson, we are limited to the English language. Yet, feel free to check out Melanie Walsh's and Quinn Dombrowski's curated tutorials to work with other languages:
#
# - [Chinese POS Tagging](Multilingual/Chinese/03-POS-Keywords-Chinese)
# - [Danish POS Tagging](Multilingual/Danish/03-POS-Keywords-Danish)
# - [Portuguese POS Tagging](Multilingual/Portuguese/03-POS-Keywords-Portuguese)
# - [Russian POS Tagging](Multilingual/Russian/03-POS-Keywords-Russian)
# - [Spanish POS Tagging](Multilingual/Spanish/03-POS-Keywords-Spanish)

# %% [markdown]
# ## 4.1 What are Part-of-Speech &amp; DocuScope Tagging?

# %% [markdown]
# ### 4.1.1 Part-of-Speech tagging

# %% [markdown]
# Part-of-speech (POS) tagging, also called grammatical tagging, is the culmination of decades of work and labor to annotate lexicons by their typical syntactical role(s) by manual and probablistic/computational means. (See [Lancaster U's summary](https://ucrel.lancs.ac.uk/annotation.html#POS) of their original process for more information about POS tagging.)
#
# If you have ever diagrammed a sentence, like below, then you have a sense about POS. Note how the parts-of-speech have been tagged in the sentence. Lookup those tags in the [Lancaster's table of POS](https://ucrel.lancs.ac.uk/annotation.html#POS).
#
# <img src="../images/pos-tagging-example.png" alt="">
#
# You may currently feel as though these syntactical relations are very dense to understand and use at first. That's normal! Eventually, with some practice, POS tagging can help you explore and surface interesting language patterns used in a particular context and domain worth reporting.

# %% [markdown]
# ### 4.1.2 DocuScope's *Categorical* Tagging

# %% [markdown]
# In addition to POS tags, Docuscope's creators — David Kaufer, Suguru Ishizaki, and Kerry Ishizaki — have been developing a LLM for over 20 years that tag texts for a variety of experiences a writer can create for readers in a text. Docuscope can detect variations of word tokens, based on its token context. For instance, consider the following variations of rhetorical patterns of "I":
#
# - "I" = self-reference
# - "I know" = self-confidence
# - "I have to do chores today" = self-reluctance
# - "I get to do chores today" = eagerness
#
# As the example above demonstrates, Docuscope's rhetorical approach to language assumes that meaning is isolated better in "streams of words," i.e., co-occurrences, rather than individual words. *In other words*, single words, when accompanied by different words, can be interpreted differently. Take the word "sick" below.
#
# - I'm feeling as sick as a dog. = I am feeling very ill.
# - That was so sick! = I thought something was really cool.
# - I'm sick of talking about AI! = I don't want to talk about AI.
#
# As of 2019, DS's database included 44,000 semantic stream classes and over 70 million unique English language patterns. The result? DocuScope's LLM offers people **categorical tags** to pair with POS tagging.
#
# Categorical tags isolate potential rhetorical patterns within the corpus. To understand what I mean by rhetorical patterns, let's consider DS's categorical tags of `Reasoning` and `Character`. `Reasoning` isolates words or streams of words that are associated with reasoning statements, such as "because," "therefore," "even if," etc., while `Character` isolates multiple dimensions of a person. For example, depending on the word's company, the name "Pauline" might be tagged in relation to work-related characteristics or other domain-specific contextual information.
#
# So, if you decide to filter your corpus by the co-occurence of Reasoning tagged words with Character words, you could analyze the top and bottom relationships between the *who* is represented in the corpus (or not!) and words related to how they *reason*. From there, you can perhaps begin to imagine how you could conduct an EDA to ask questions of the patterns.

# %% [markdown]
# #### How DS tags categories

# %% [markdown]
# According to [DS's creators](https://docuscospacy.readthedocs.io/en/latest/docuscope.html), DS "consists of an enormous lexicon organized into a 3-level taxonomy. An analogue would be the lexicons typically used in sentiment analysis." A sentiment analysis typically cateogrizes words and phrases into either positive or negative sentiments. DS works similarily, but it "organizes its strings into many more categories and is orders of magnitude larger. A typical sentiment lexicon may match 3-5 thousand strings. DocuScope matches 100s of millions."
#
# Let's walk through an example sentence and what categorical tags offer in addition to POS tags:
#
# > Jaws is a shrewd cinematic equation which not only gives you one or two very nasty turns when you least expect them but, possibly more important, knows when to make you think another is coming without actually providing it.
#
# When this sentence is analyzed by the DS, it yields the following table (headers are as follows: `tag`==POS tag, `ent`==Named Entity tag; `ent_type`==DS categorical tag).
#
# Note how in addition to POS tagging, DS categorical tags offer a helpful rhetorical and contextual dimension to the token. DS tags offer numerous other categorical tags:

# %% [markdown]
# ##### *Categorical tag* results from the "Jaws is a shrewd ..." sentence above.

# %% [markdown]
# | **** | **text**  | **tag\_** | **ent\_** | **ent\_type\_**       |
# |------|-----------|-----------|-----------|-----------------------|
# | 0    | Jaws      | NN1       | B         | Character             |
# | 1    | is        | VBZ       | B         | InformationStates     |
# | 2    | a         | AT1       | I         | InformationStates     |
# | 3    | shrewd    | JJ        | B         | Strategic             |
# | 4    | cinematic | JJ        | B         | PublicTerms           |
# | 5    | equation  | NN1       | B         | AcademicTerms         |
# | 6    | which     | DDQ       | B         | SyntacticComplexity   |
# | 7    | not       | XX        | B         | ForceStressed         |
# | 8    | only      | RR        | I         | ForceStressed         |
# | 9    | gives     | VVZ       | B         | Interactive           |
# | 10   | you       | PPY       | I         | Interactive           |
# | 11   | one       | MC1       | O         |                       |
# | 12   | or        | CC        | B         | MetadiscourseCohesive |
# | 13   | two       | MC        | B         | InformationExposition |
# | 14   | very      | RG        | B         | ConfidenceHigh        |
# | 15   | nasty     | JJ        | B         | Negative              |
# | 16   | turns     | NN2       | O         |                       |
# | 17   | when      | RRQ       | B         | Narrative             |
# | 18   | you       | PPY       | I         | Narrative             |
# | 19   | least     | RRT       | B         | InformationExposition |
# | 20   | expect    | VV0       | B         | Future                |
# | 21   | them      | PPHO2     | B         | Narrative             |
# | 22   | but       | CCB       | B         | MetadiscourseCohesive |
# | 23   | ,         | Y         | B         | Contingent            |
# | 24   | possibly  | RR        | I         | Contingent            |
# | 25   | more      | RGR       | B         | InformationExposition |
# | 26   | important | JJ        | I         | InformationExposition |
# | 27   | ,         | Y         | O         |                       |
# | 28   | knows     | VVZ       | B         | ConfidenceHigh        |
# | 29   | when      | RRQ       | I         | ConfidenceHigh        |
# | 30   | to        | TO        | O         |                       |
# | 31   | make      | VVI       | B         | Interactive           |
# | 32   | you       | PPY       | I         | Interactive           |
# | 33   | think     | VVI       | B         | Character             |
# | 34   | another   | DD1       | B         | MetadiscourseCohesive |
# | 35   | is        | VBZ       | B         | InformationStates     |
# | 36   | coming    | VVG       | O         |                       |
# | 37   | without   | IW        | O         |                       |
# | 38   | actually  | RR        | B         | ForceStressed         |
# | 39   | providing | VVG       | B         | Facilitate            |
# | 40   | it        | PPH1      | O         |                       |
# | 41   | \.        | Y         | O         |                       |

# %% [markdown]
# #### Reference Table of DS Categorical Tags

# %% [markdown]
# | **\*\*Category \(Cluster\)\*\*** | **\*\*Description\*\***                                                                                                                                                                                                                                                       | **\*\*Examples\*\***                                                                                |
# |----------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|
# | **Academic Terms**               | Abstract, rare, specialized, or disciplinary\-specific terms that are indicative of informationally dense writing                                                                                                                                                             | \*market price\*, \*storage capacity\*, \*regulatory\*, \*distribution\*                            |
# | **Academic Writing Moves**       | Phrases and terms that indicate academic writing moves, which are common in research genres and are derived from the work of Swales \(1981\) and Cotos et al\. \(2015, 2017\)                                                                                                 | \*in the first section\*, \*the problem is that\*, \*payment methodology\*, \*point of contention\* |
# | **Character**                    | References multiple dimensions of a character or human being as a social agent, both individual and collective                                                                                                                                                                | \*Pauline\*, \*her\*, \*personnel\*, \*representatives\*                                            |
# | **Citation**                     | Language that indicates the attribution of information to, or citation of, another source\.                                                                                                                                                                                   | \*according to\*, \*is proposing that\*, \*quotes from\*                                            |
# | **Citation Authorized**          | Referencing the citation of another source that is represented as true and not arguable                                                                                                                                                                                       | \*confirm that\*, \*provide evidence\*, \*common sense\*                                            |
# | **Citation Hedged**              | Referencing the citation of another source that is presented as arguable                                                                                                                                                                                                      | \*suggest that\*, \*just one opinion\*                                                              |
# | **Confidence Hedged**            | Referencing language that presents a claim as uncertain                                                                                                                                                                                                                       | \*tends to get\*, \*maybe\*, \*it seems that\*                                                      |
# | **Confidence High**              | Referencing language that presents a claim with certainty                                                                                                                                                                                                                     | \*most likely\*, \*ensure that\*, \*know that\*, \*obviously\*                                      |
# | **Confidence Low**               | Referencing language that presents a claim as extremely unlikely                                                                                                                                                                                                              | \*unlikely\*, \*out of the question\*, \*impossible\*                                               |
# | **Contingent**                   | Referencing contingency, typically contingency in the world, rather than contingency in one's knowledge                                                                                                                                                                       | \*subject to\*, \*if possible\*, \*just in case\*, \*hypothetically\*                               |
# | **Description**                  | Language that evokes sights, sounds, smells, touches and tastes, as well as scenes and objects                                                                                                                                                                                | \*stay quiet\*, \*gas\-fired\*, \*solar panels\*, \*soft\*, \*on my desk\*                          |
# | **Facilitate**                   | Language that enables or directs one through specific tasks and actions                                                                                                                                                                                                       | \*let me\*, \*worth a try\*, \*I would suggest\*                                                    |
# | **First Person**                 | This cluster captures first person\.                                                                                                                                                                                                                                          | \*I\*, \*as soon as I\*, \*we have been\*                                                           |
# | **Force Stressed**               | Language that is forceful and stressed, often using emphatics, comparative forms, or superlative forms                                                                                                                                                                        | \*really good\*, \*the sooner the better\*, \*necessary\*                                           |
# | **Future**                       | Referencing future actions, states, or desires                                                                                                                                                                                                                                | \*will be\*, \*hope to\*, \*expected changes\*                                                      |
# | **Information Change**           | Referencing changes of information, particularly changes that are more neutral                                                                                                                                                                                                | \*changes\*, \*revised\*, \*growth\*, \*modification to\*                                           |
# | **Information Change Negative**  | Referencing negative change\.                                                                                                                                                                                                                                                 | \*going downhill\*, \*slow erosion\*, \*get worse\*                                                 |
# | **Information Change Positive**  | Referencing positive change\.                                                                                                                                                                                                                                                 | \*improving\*, \*accrued interest\*, \*boost morale\*                                               |
# | **Information Exposition**       | Information in the form of expository devices, or language that describes or explains, frequently in regards to quantities and comparisons                                                                                                                                    | \*final amount\*, \*several\*, \*three\*, \*compare\*, \*80%\*                                      |
# | **Information Place**            | Language designating places\.                                                                                                                                                                                                                                                 | \*the city\*, \*surrounding areas\*, \*Houston\*, \*home\*                                          |
# | **Information Report Verbs**     | Informational verbs and verb phrases of reporting\.                                                                                                                                                                                                                           | \*report\*, \*posted\*, \*release\*, \*point out\*                                                  |
# | **Information States**           | Referencing information states, or states of being\.                                                                                                                                                                                                                          | \*is\*, \*are\*, \*existing\*, \*been\*                                                             |
# | **Information Topics**           | Referencing topics, usually nominal subjects or objects, that indicate the “aboutness” of a text                                                                                                                                                                              | \*time\*, \*money\*, \*stock price\*, \*phone interview\*                                           |
# | **Inquiry**                      | Referencing inquiry, or language that points to some kind of inquiry or investigation                                                                                                                                                                                         | \*find out\*, \*let me know if you have any questions\*, \*wondering if\*                           |
# | **Interactive**                  | Addresses from the author to the reader or from persons in the text to other persons\. The address comes in the language of everyday conversation, colloquy, exchange, questions, attention\-getters, feedback, interactive genre markers, and the use of the second person\. | \*can you\*, \*thank you for\*, \*please see\*, \*sounds good to me\*                               |
# | **Metadiscourse Cohesive**       | The use of words to build cohesive markers that help the reader navigate the text and signal linkages in the text, which are often additive or contrastive                                                                                                                    | \*or\*, \*but\*, \*also\*, \*on the other hand\*, \*notwithstanding\*, \*that being said\*          |
# | **Metadiscourse Interactive**    | The use of words to build cohesive markers that interact with the reader                                                                                                                                                                                                      | \*I agree\*, \*let’s talk\*, \*by the way\*                                                         |
# | **Narrative**                    | Language that involves people, description, and events extending in time                                                                                                                                                                                                      | \*today\*, \*tomorrow\*, \*during the\*, \*this weekend\*                                           |
# | **Negative**                     | Referencing dimensions of negativity, including negative acts, emotions, relations, and values                                                                                                                                                                                | \*does not\*, \*sorry for\*, \*problems\*, \*confusion\*                                            |
# | **Positive**                     | Referencing dimensions of positivity, including actions, emotions, relations, and values                                                                                                                                                                                      | \*thanks\*, \*approval\*, \*agreement\*, \*looks good\*                                             |
# | **Public Terms**                 | Referencing public terms, concepts from public language, media, the language of authority, institutions, and responsibility                                                                                                                                                   | \*discussion\*, \*amendment\*, \*corporation\*, \*authority\*, \*settlement\*                       |
# | **Reasoning**                    | Language that has a reasoning focus, supporting inferences about cause, consequence, generalization, concession, and linear inference either from premise to conclusion or conclusion to premise                                                                              | \*because\*, \*therefore\*, \*analysis\*, \*even if\*, \*as a result\*, \*indicating that\*         |
# | **Responsibility**               | Referencing the language of responsibility\.                                                                                                                                                                                                                                  | \*supposed to\*, \*requirements\*, \*obligations\*                                                  |
# | **Strategic**                    | This dimension is active when the text structures strategies activism, advantage\-seeking, game\-playing cognition, plans, and goal\-seeking\.                                                                                                                                | \*plan\*, \*trying to\*, \*strategy\*, \*decision\*, \*coordinate\*, \*look at the\*                |
# | **Syntactic Complexity**         | The features in this category are often what are called “function words,” like determiners and prepositions\.                                                                                                                                                                 | \*the\*, \*to\*, \*for\*, \*in\*, \*a lot of\*                                                      |
# | **Uncertainty**                  | References uncertainty, when confidence levels are unknown\.                                                                                                                                                                                                                  | \*kind of\*, \*I have no idea\*, \*for some reason\*                                                |
# | **Updates**                      | References updates that anticipate someone searching for information and receiving it                                                                                                                                                                                         | \*already\*, \*a new\*, \*now that\*, \*here are some\*                                             |

# %% [markdown]
# ## 4.2 Why is Speech Tagging Useful?

# %% [markdown]
# <img src="https://imgs.xkcd.com/comics/language_nerd.png" alt="I don't mean to go all [Language Nerd](https://xkcd.com/1443/) on you, but parts of speech are important. Even if they seem kind of boring. *Parts of speech* are the grammatical units of language — such as (in English) nouns, verbs, adjectives, adverbs, pronouns, and prepositions. Each of these parts of speech plays a different role in a sentence.">

# %% [markdown]
# By computationally identifying parts of speech, we can start computationally exploring *syntax*, the relationship between words, rather than only focusing on words in isolation, as other analyses perform such as *tf-idf*.
#
# Though parts of speech may seem pedantic, and difficult to apply at first, the POS and DS tags (*LANGUAGE AS DIGITAL DATA!*) help us work with our computational media, i.e., computers, to work toward that ever-elusive abstract noun: *meaning*.
#
# The *xkcd* comic above nicely illustrates how words are not monolithic or static in meaning. Why? Language is a dynamic part of the human experience. Language has a history—a history that feeds into what we do with language right now, which also impacts how words develop into our future. Consequently, syntactical tagging of word relationships - even within the seemingly simple language unit that we call sentences - is difficult. Words can and do shift roles and functions and how they impact social relationships (rhetoric!), because langauge is more than a "bag of words" and their syntactical relationships, e.g. "legit" as *adjective* and *adverb*. We've tangled up language in all aspects of our world.

# %% [markdown]
# ## 4.3 Speech Tagging Lesson

# %% [markdown]
# ### 4.3.1 Install necessary libraries

# %%
# %pip install -U spacy==3.5.0 
# Special modified version of tmtoolkit to work with docuscospacy (I logged the issue with DS, so this works with 0.2.3)
# %pip install pip install https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
# %pip install docuscospacy==0.2.3
# Run the install command for 'json' just in case you don't have it
# %pip install json
# Out:
# Requirement already satisfied: spacy==3.5.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (3.5.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (0.10.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (1.10.13)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (1.0.10)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (1.26.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (4.66.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (6.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (2.31.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (2.4.8)
# Requirement already satisfied: jinja2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (58.1.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (1.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (8.1.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (3.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy==3.5.0) (2.0.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from spacy==3.5.0) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.0) (4.8.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\cradd\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from jinja2->spacy==3.5.0) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\cradd\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Collecting https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
#   Using cached https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
# Requirement already satisfied: pip in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (21.2.4)
# Requirement already satisfied: install in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (1.26.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (1.11.3)
# Requirement already satisfied: globre>=0.1.5 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (0.1.5)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (2.1.2)
# Requirement already satisfied: xlrd>=2.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (2.0.1)
# Requirement already satisfied: openpyxl>=3.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (3.1.2)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from temptmtoolkit==0.11.2) (3.8.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (6.1.0)
# Requirement already satisfied: pillow>=8 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (10.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.0->temptmtoolkit==0.11.2) (3.17.0)
# Requirement already satisfied: et-xmlfile in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from openpyxl>=3.0.0->temptmtoolkit==0.11.2) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.4.0->temptmtoolkit==0.11.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.4.0->temptmtoolkit==0.11.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\cradd\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: docuscospacy==0.2.3 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (0.2.3)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from docuscospacy==0.2.3) (0.22.1)
# Requirement already satisfied: spacy>=3.3.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from docuscospacy==0.2.3) (3.5.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from docuscospacy==0.2.3) (2.1.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from docuscospacy==0.2.3) (1.26.1)
# Requirement already satisfied: loky>=3.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from docuscospacy==0.2.3) (3.4.1)
# Requirement already satisfied: tmtoolkit>=0.11.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from docuscospacy==0.2.3) (0.12.0)
# Requirement already satisfied: cloudpickle in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from loky>=3.0.0->docuscospacy==0.2.3) (3.0.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->docuscospacy==0.2.3) (1.16.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (8.1.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (6.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.0.5)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (0.10.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.0.10)
# Requirement already satisfied: setuptools in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (58.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (23.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (4.66.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.4.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.10.13)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (0.7.0)
# Requirement already satisfied: jinja2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.3.0->docuscospacy==0.2.3) (4.8.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (2023.7.22)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.7.11)
# Requirement already satisfied: scipy<2.0,>=1.7.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.11.3)
# Requirement already satisfied: matplotlib<4.0,>=3.5.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.8.1)
# Requirement already satisfied: wheel<1.0,>=0.40 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.41.3)
# Requirement already satisfied: openpyxl<4.0,>=3.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.1.2)
# Requirement already satisfied: globre<0.2,>=0.1.5 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.1.5)
# Requirement already satisfied: xlrd>=2.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (4.43.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (6.1.0)
# Requirement already satisfied: pillow>=8 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (10.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.17.0)
# Requirement already satisfied: et-xmlfile in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from openpyxl<4.0,>=3.0.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.1.0)
# Requirement already satisfied: colorama in c:\users\cradd\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy>=3.3.0->docuscospacy==0.2.3) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from jinja2->spacy>=3.3.0->docuscospacy==0.2.3) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\cradd\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\cradd\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### 4.3.2 Import Libraries + EDA

# %%
import spacy
from spacy import displacy
from temptmtoolkit.corpus import Corpus, vocabulary_size, corpus_num_tokens
import re
from docuscospacy.corpus_analysis import convert_corpus, frequency_table, tags_table, ngrams_table, coll_table, tags_dtm, kwic_center_node, keyness_table
import pandas as pd
import json
import statistics

# %% [markdown]
# #### Quick EDA to understand the data

# %%
##############
## Import Data
##############

# Open/read the sample JSON file
file_adj_corpus = open('../data/04-textual-analysis/kaggle-nb-example/dict_viz_and_adjacent_cells.json', 'r')

# Convert the JSON data into python dict object
dict_adj_corpus = json.load(file_adj_corpus)

# Check the type of the Python object
print(type(dict_adj_corpus))

# Iterate through the dictionary
# And print the key: value pairs
# for key, value in dict_adj_corpus.items():
#   print(f"\nKey: {key}")
#   print(f"Value: {value}\n")

# Close the opened sample JSON file
file_adj_corpus.close()
# Out:
# <class 'dict'>

# %% [markdown]
# #### What is the sum of cells adjacent to visual cells per position?

# %% [markdown]
# **PROVENANCE**: This data comes from Kaggle.com, where data scientists share data and notebooks that analyze it. This set specifically collected notebooks that employ machine-learning techniques with the goal to understand how people used visuals throughout the process. Consequently, the data are organized by two factors:
#
# 1. whether or not a notebook cell is a "code" cell or a "Markdown" cell, and
# 2. whether the cell is positioned before or after a cell that produces a visualization.
#
# Review the summary stats work below to get to know the data some more before we use other more specific `.txt` files that I created from this particular data set.

# %%
####################################################################
# 1. What is the sum of cells adjacent to visual cells per position?
####################################################################
def sum_adj_cells(c):
  md_before_count = 0
  md_after_count = 0
  code_before_count = 0
  code_after_count = 0
  for vcell_key in c:
    if c[vcell_key]['adjacent_before'] != 'None':
      if c[vcell_key]['adjacent_before']['cell_type'] == 'markdown':
        md_before_count = md_before_count + 1
      elif c[vcell_key]['adjacent_before']['cell_type'] == 'code':
        code_before_count = code_before_count + 1
    elif c[vcell_key]['adjacent_after'] != 'None':
      if c[vcell_key]['adjacent_after']['cell_type'] == 'markdown':
        md_after_count = md_after_count + 1
      elif c[vcell_key]['adjacent_after']['cell_type'] == 'code':
        code_after_count = code_after_count + 1

  print(
    'Q1: What is the sum of cells adjacent to visual cells per posiiton?'
    '\n- md_before_count:', md_before_count,
    '\n- md_after_count:', md_after_count,
    '\n- code_before_count:', code_before_count,
    '\n- code_after_count:', code_after_count,
    '\n- TOTAL:', md_before_count+md_after_count+code_before_count+code_after_count
  )

sum_adj_cells(dict_adj_corpus)
# Out:
# Q1: What is the sum of cells adjacent to visual cells per posiiton?
# - md_before_count: 6749
# - md_after_count: 54
# - code_before_count: 3546
# - code_after_count: 53
# - TOTAL: 10402

# %% [markdown]
# #### What positions are visual cells in the notebook?

# %%
##################################################
# 2. What positions are visual cells in the notebook?
##################################################
def describe_viz_cell_positions(c):
  # Overall positioning
  cp_occurrences = 0
  ni_cp_occurrences = 0
  overall_cell_position_sum = 0
  no_import_cell_position_sum = 0
  sum_cells_sum = 0
  overall_position_list = []
  no_import_position_list = []
  sum_of_cells_list = []
  for vcell_key in c:
    # Tally occurrences
    cp_occurrences = cp_occurrences+1
    sum_cells_sum = sum_cells_sum+c[vcell_key]['total_cells_in_nb']

    # List total cells in notebooks
    sum_of_cells_list.append(c[vcell_key]['total_cells_in_nb'])

    overall_cell_position_sum = overall_cell_position_sum + c[vcell_key]['cell_position_in_nb']
    overall_position_list.append(c[vcell_key]['cell_position_in_nb'])

    # Filter out imports
    re_import = r'import\s'
    import_match = re.match(re_import, c[vcell_key]['source'])
    # print(import_match)
    if import_match == None:
      ni_cp_occurrences = ni_cp_occurrences+1
      no_import_cell_position_sum = no_import_cell_position_sum + c[vcell_key]['cell_position_in_nb']
      no_import_position_list.append(c[vcell_key]['cell_position_in_nb'])

  # MEDIAN
  # Sort the lists in ascending order
  overall_position_list = sorted(overall_position_list)
  no_import_position_list = sorted(no_import_position_list)
  sum_of_cells_list = sorted(sum_of_cells_list)

  overall_position_median = statistics.median(overall_position_list)
  no_imports_position_median = statistics.median(no_import_position_list)
  sum_cells_median = statistics.median(sum_of_cells_list)

  # MODE
  # Round numbers in list to whole number
  whole_num_overall_position_list = []
  for op in overall_position_list:
    whole_num_overall_position_list.append(round(op))
  
  whole_num_ni_position_list = []
  for nip in no_import_position_list:
    whole_num_ni_position_list.append(round(nip))
  
  overall_position_mode = statistics.mode(whole_num_overall_position_list)
  no_imports_position_mode = statistics.mode(whole_num_ni_position_list)
  sum_cells_mode = statistics.mode(sum_of_cells_list)

  print(
    '\n\nQ2: What positions are visual cells in the notebook?',
    '\n- OVERALL Avg Mean Cell Position:', overall_cell_position_sum / cp_occurrences,
    '\n- OVERALL Median Cell Position:', overall_position_median,
    '\n- OVERALL Mode Cell Position:', overall_position_mode,
    '\n- NO IMPORTS Avg Mean Cell Position:', no_import_cell_position_sum / ni_cp_occurrences,
    '\n- NO IMPORTS Median Cell Position:', no_imports_position_median,
    '\n- NO IMPORTS Mode Cell Position:', no_imports_position_mode,
    '\n- TOTAL CELLS Avg Mean:', sum_cells_sum / cp_occurrences,
    '\n- TOTAL CELLS Median:', sum_cells_median,
    '\n- TOTAL CELLS Mode:', sum_cells_mode,
    '\n- OVERALL Sum Total Cells:', cp_occurrences,
    '\n- NO IMPORTS Sum Total Cells:', ni_cp_occurrences,
    '\n- IMPORTS ONLY Sum Total Cells:', (ni_cp_occurrences-cp_occurrences),
    '\n'
  )

describe_viz_cell_positions(dict_adj_corpus)
# Out:
# Q2: What positions are visual cells in the notebook?
# - OVERALL Avg Mean Cell Position: 65.78426175765347
# - OVERALL Median Cell Position: 41.009803921568626
# - OVERALL Mode Cell Position: 2
# - NO IMPORTS Avg Mean Cell Position: 68.74707099136471
# - NO IMPORTS Median Cell Position: 43.014084507042256
# - NO IMPORTS Mode Cell Position: 21
# - TOTAL CELLS Avg Mean: 135.87084092434557
# - TOTAL CELLS Median: 99
# - TOTAL CELLS Mode: 827
# - OVERALL Sum Total Cells: 10429
# - NO IMPORTS Sum Total Cells: 9707
# - IMPORTS ONLY Sum Total Cells: -722

# %% [markdown]
# #### Other EDA?

# %% [markdown]
# Feel free to use the pandas dataframes below to do any more EDA, if you'd like. But, the main part of this lesson is to learn more about POS and Categorical tagging.

# %%
# Isolate NON-IMPORT-ADJACENT Markdown Cells
def get_non_import_adj_md_cells(c):
  list__all_cell_content = []
  list__ni_md_before_cell_content = []
  list__ni_md_after_cell_content = []
  for vcell_key in c:
    # Filter out imports
    re_import = r'import\s'
    import_match = re.match(re_import, c[vcell_key]['source'])
    if (import_match == None):
      # Before Vcell
      if c[vcell_key]['adjacent_before'] != 'None' and (c[vcell_key]['adjacent_before']['cell_type'] == 'markdown'):
        list__ni_md_before_cell_content.append(c[vcell_key]['adjacent_before']['source'])
        list__all_cell_content.append(c[vcell_key]['adjacent_before']['source'])
      # After Vcell
      elif c[vcell_key]['adjacent_after'] != 'None' and (c[vcell_key]['adjacent_after']['cell_type'] == 'markdown'):
        list__ni_md_after_cell_content.append(c[vcell_key]['adjacent_after']['source'])
        list__all_cell_content.append(c[vcell_key]['adjacent_after']['source'])

  dict__ni_md_cell_contents = [
    {'all_vcells': list__all_cell_content},
    {'before_vcells': list__ni_md_before_cell_content},
    {'after_vcells': list__ni_md_after_cell_content}
  ]

  return dict__ni_md_cell_contents

# %%
# Remove "Import" cells from samples
dict__ni_adj_corpus = get_non_import_adj_md_cells(dict_adj_corpus)

# Convert dictionaries to dataframes
df__ALL_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[0]['all_vcells']).rename(columns={0:'all_vcells'})
df__BEFORE_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[1]['before_vcells']).rename(columns={0:'before_vcells'})
df__AFTER_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[2]['after_vcells']).rename(columns={0:'after_vcells'})

# %%
# Optional EDA code

# %% [markdown]
# ### 4.3.3 Download LLM

# %% [markdown]
# Ok, now that you know the data a little better than before, we can start our POS and Categorical tags analysis.
#
# First, we need to download DocuScope's LLM: `en_docusco_spacy`. Their (English-only) LLM will process and make predictions about our texts.
#
# - **NOTE**: Another commonly used LLM is spacy's `en_core_web_sm`. This LLM was trained on the annotated "OntoNotes" corpus.
#
# To download and install the `en_docusco_spacy` model,
#
# 1. Execute the cell below: `%pip install en_docusco_spacy`.
# 2. Execute the subsequent cell that uses `spacy` to load the `en_docusco_spacy` model as a variable method.
#
# Now, we can use DS's LLM!

# %%
# %pip install https://huggingface.co/browndw/en_docusco_spacy/resolve/main/en_docusco_spacy-any-py3-none-any.whl
# Out:
# Collecting en-docusco-spacy==any
#   Downloading https://huggingface.co/browndw/en_docusco_spacy/resolve/main/en_docusco_spacy-any-py3-none-any.whl (7.5 MB)
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from en-docusco-spacy==any) (3.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (58.1.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (8.1.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.26.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (4.66.1)
# Requirement already satisfied: jinja2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (23.2)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.10.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.10.13)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (6.4.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\cradd\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (4.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.7.11)
# Requirement already satisfied: colorama in c:\users\cradd\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cradd\appdata\local\programs\python\python39\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Users\cradd\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
nlp = spacy.load('en_docusco_spacy')
nlp

# %% [markdown]
# ### 4.3.4 Conducting a corpus analysis with docuscopacy

# %% [markdown]
# In this part of the lesson, we will follow the `docuscospacy` package's [documentation tutorial](https://docuscospacy.readthedocs.io/en/latest/corpus_analysis.html).
#
# Using this LLM, we will conduct some of the following actions to conduct a corpus analysis:
#
# - Token frequencies
# - Ngrams
# - Word collocations around a node word
# - Keyword comparisions against a reference corpus
#
# What's great about `docuscospacy` (DS) is how it provides methods by which review the results from the analysis—another form of EDA!
#
# For example, DS can render outputs, such as tables with either POS or DS tags. This will help you differentiate potential moments when a POS like *can* functions as a *noun* vs. *can as verb*. It may prove interesting! Who knows until see what language patterns may be found!
#
# In another example, we'll review how `docuscospacy` conducts and aggregates multi-token sequenced tags, e.g., where *in spite of* is tagged as a token sequence, it is combined into a signle token.
#
# Overall, our goal is to get to know the data and get creative with how we analyze it.

# %% [markdown]
# ### 4.3.5 Load Corpus Data and Pre-Processing the Corpus

# %% [markdown]
# Accurate tagging requires some processing/cleaning of the data. In the function below, we
#
# 1. Make all of the text uniformly lowercase, because remember that computers define every type of character, such as lowercase `k` vs. uppercase `K`.
# 2. Remove any potential HTML tags in this particular corpus.
# 3. Split the possessive `its` into two tokens.
# 4. Removes carriage returns, tabs, extra spaces, etc.

# %%
def pre_process(txt):
    # 1. remove lowercase
    txt=txt.lower()
    # 2. remove HTML tags
    txt=re.sub('</?.*?>','', txt)
    # 3. remove posessives
    txt = re.sub(r'\bits\b', 'it s', txt)
    txt = re.sub(r'\bIts\b', 'It s', txt)
    # Split text into tokens (tokenize it)
    txt = " ".join(txt.split())
    
    return(txt)

# %%
# You may need to change this variable, if you end up using diferent data sets
nlp.max_length = 1300000
# 1300000 for Kaggle's by-position
print(nlp.max_length)
# Out:
# 1300000

# %%
# %%time
corp = Corpus.from_folder(
    # Note how this uses a folder reference, not just a file.
    # It parses txt files divvied up into differently sorted parts of a corpus/es

    # CHOOSE YOUR CORPUS! :-) The lesson starts by using the Kaggle 'by-position' data.
    # Use this data first. Then, for your application, choose another set if you'd like

    '../data/04-textual-analysis/jeopardy', 
    # '../data/04-textual-analysis/kaggle-nb-example/by-votes',
    
    # NOTE: For the sake of file sizes and in-memory work, I randomly sampled the Jeopardy questions (10000 per document set)
    # '../data/04-textual-analysis/jeopardy/split', 
    spacy_instance=nlp, # Our loaded LLM
    raw_preproc=[pre_process], # Cleaning function
    spacy_token_attrs=['tag', 'ent_iob', 'ent_type', 'is_punct'] #Run these tagging functions
)
# Out:
# CPU times: total: 35.6 s
# Wall time: 1min 24s

# %% [markdown]
# ### 4.3.6 Basic Summary Stats About Corpus

# %% [markdown]
# It is always a good idea to calcu;ate and review some aggregated information about your corpus. These stats can help you identify potential oddities before you even begin the other work. And, some of the values will be useful later.

# %%
corpus_total = corpus_num_tokens(corp)
corpus_types = vocabulary_size(corp)
total_punct = []
for i in range(0,len(corp)):
    total_punct.append(sum(corp[i]['is_punct']))
total_punct = sum(total_punct)
non_punct = corpus_total - total_punct

print(
    'Aphanumeric tokens:', non_punct, 
    '\nPunctuation tokens:', total_punct, 
    '\nTotal tokens:', corpus_total, 
    '\nToken types:', corpus_types
)
# Out:
# Aphanumeric tokens: 447075
# Punctuation tokens: 128240
# Total tokens: 575315
# Token types: 36790

# %% [markdown]
# ### 4.3.7 Converting the corpus to a DS class object

# %% [markdown]
# Before we generate any tables, we first need to convert the corpus into a convenient object that we can manipulate. From `docuscospacy.corpus_analysis` we will import a number of functions including `convert_corpus`, which takes the object produced by the `Corpus.from_folder` function and converts it into a dictionary, whose keys are the names of the corpus files.

# %%
from docuscospacy.corpus_analysis import convert_corpus, frequency_table, tags_table, ngrams_table, coll_table, tags_dtm, kwic_center_node, keyness_table

# %%
tp = convert_corpus(corp)

# %%
# Listify the keys to review them for accuracy: Did it get all of the desired files?
list(tp.keys())

# ['kaggle_LAST_THIRD_CELLS_votes_notebooks',
#  'kaggle_SECOND_THIRD_CELLS_votes_notebooks',
#  'kaggle_FIRST_THIRD_CELLS_notebooks']
# Out:
# ['split-q_greater_than_1000',
#  'split-q_greater_than_400_less_than_1000',
#  'split-q_less_than_400']

# %%
# Listify a file's content in the dictionary by changing the positional values to change the file and tagged tokens in the file
list(tp.values())[1][10:]
# Out:
# [('was ', 'VBDZ', 'B-Narrative'),
#  ('adopted ', 'VVN', 'O-'),
#  ('from ', 'II', 'O-'),
#  ('belfort', 'NN1', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-InformationPlace'),
#  ('city ', 'NN1', 'I-InformationPlace'),
#  ('where ', 'CS', 'O-'),
#  ('an ', 'AT1', 'O-'),
#  ('early ', 'JJ', 'B-Narrative'),
#  ('model ', 'NN1', 'B-AcademicTerms'),
#  ('was ', 'VBDZ', 'B-Narrative'),
#  ('made', 'VVN', 'B-InformationReportVerbs'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('he', 'PPHS1', 'B-Character'),
#  ("'s ", 'VBZ', 'I-Character'),
#  ('the ', 'AT', 'O-'),
#  ('member ', 'NN1', 'B-InformationTopics'),
#  ('of ', 'IO', 'O-'),
#  ('p.funk ', 'NN1', 'O-'),
#  ('seen ', 'VVN', 'B-Description'),
#  ('here', 'RL', 'B-Narrative'),
#  (':', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('later ', 'RRR', 'B-Narrative'),
#  ('caught ', 'VVN', 'O-'),
#  ('with ', 'IW', 'O-'),
#  ('his ', 'APPGE', 'B-Description'),
#  ('hand ', 'NN1', 'I-Description'),
#  ('figuratively ', 'RR', 'B-AcademicTerms'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('cookie ', 'NN1', 'B-Description'),
#  ('jar', 'NN1', 'B-Description'),
#  (', ', 'Y', 'O-'),
#  ('he ', 'PPHS1', 'B-Character'),
#  ('jumps ', 'VVZ', 'B-Description'),
#  ('when ', 'RRQ', 'O-'),
#  ('mom ', 'NN1', 'B-Character'),
#  ('says', 'VVZ', 'B-Citation'),
#  (', ', 'Y', 'I-Citation'),
#  ('"', 'Y', 'I-Citation'),
#  ('"', 'Y', 'O-'),
#  ('get ', 'VV0', 'B-Narrative'),
#  ('out ', 'II21', 'I-Narrative'),
#  ('of ', 'II22', 'I-Narrative'),
#  ('there', 'RL', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-Description'),
#  ('shaft ', 'NN1', 'I-Description'),
#  ('around ', 'II', 'O-'),
#  ('which ', 'DDQ', 'O-'),
#  ('a ', 'AT1', 'B-Description'),
#  ('wheel ', 'NN1', 'I-Description'),
#  ('rotates ', 'NN2', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('grandfather ', 'NN1', 'B-Character'),
#  ('of ', 'IO', 'O-'),
#  ('charlemagne ', 'NN1', 'B-Description'),
#  ('nailed ', 'VVD', 'B-Description'),
#  ('the ', 'AT', 'O-'),
#  ('moors ', 'NN2', 'B-Description'),
#  ('at ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('battle ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('tours ', 'NN2', 'B-Narrative'),
#  ('in ', 'II', 'O-'),
#  ('732', 'MC', 'B-InformationExposition'),
#  (', ', 'Y', 'O-'),
#  ('checking ', 'VVG', 'B-Strategic'),
#  ('their ', 'APPGE', 'I-Strategic'),
#  ('advance', 'NN1', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('news ', 'NN1', 'B-Updates'),
#  ('gathering ', 'VVG', 'B-Positive'),
#  ('& ', 'Y', 'O-'),
#  ('reporting', 'NN1', 'B-InformationReportVerbs'),
#  ('; ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('university ', 'NN1', 'B-PublicTerms'),
#  ('of ', 'IO', 'I-PublicTerms'),
#  ('missouri ', 'NN1', 'B-InformationPlace'),
#  ('had ', 'VHD', 'B-Narrative'),
#  ('the ', 'AT', 'O-'),
#  ('usa', 'NN1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('first ', 'MD', 'B-InformationTopics'),
#  ('school ', 'NN1', 'I-InformationTopics'),
#  ('of ', 'IO', 'O-'),
#  ('it ', 'PPH1', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('greek ', 'NN1', 'B-InformationPlace'),
#  ('who ', 'PNQS', 'O-'),
#  ('1st ', 'MD', 'O-'),
#  ('used ', 'JJ', 'O-'),
#  ('math ', 'NN1', 'B-AcademicTerms'),
#  ('to ', 'TO', 'O-'),
#  ('tune ', 'VVI', 'B-Description'),
#  ('an ', 'AT1', 'O-'),
#  ('instrument', 'NN1', 'B-InformationTopics'),
#  (', ', 'Y', 'O-'),
#  ('he', 'PPHS1', 'B-Character'),
#  ("'s ", 'VBZ', 'I-Character'),
#  ('more ', 'RGR', 'B-InformationExposition'),
#  ('famous ', 'JJ', 'B-Character'),
#  ('for ', 'IF', 'O-'),
#  ('a ', 'AT1', 'B-Description'),
#  ('triangle', 'NN1', 'I-Description'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('miranda', 'VV0', 'B-Character'),
#  (', ', 'Y', 'O-'),
#  ('spectator ', 'NN1', 'B-Character'),
#  ('& ', 'Y', 'O-'),
#  ("d'orsay ", 'NN1', 'B-Description'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('types ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'I-AcademicTerms'),
#  ('this ', 'DD1', 'O-'),
#  ('slip', 'NN1', 'B-Description'),
#  ('-', 'Y', 'O-'),
#  ('on ', 'II', 'O-'),
#  ('women', 'NN2', 'B-Character'),
#  ("'s ", 'GE', 'I-Character'),
#  ('shoe', 'NN1', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('kelly ', 'RR', 'B-Positive'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'B-Inquiry'),
#  ('clue ', 'NN1', 'I-Inquiry'),
#  ('crew ', 'NN1', 'B-Character'),
#  ('holds ', 'VVZ', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('skull ', 'NN1', 'B-Description'),
#  ('at ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('smithsonian', 'NN1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('hall ', 'NN1', 'B-Description'),
#  ('of ', 'IO', 'O-'),
#  ('human ', 'JJ', 'B-AcademicTerms'),
#  ('origins', 'NN2', 'B-Narrative'),
#  ('.', 'Y', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('when ', 'RRQ', 'O-'),
#  ('mary ', 'NN1', 'B-Character'),
#  ('leakey ', 'NN1', 'O-'),
#  ('discovered ', 'VVD', 'B-Inquiry'),
#  ('paranthropus ', 'NN1', 'B-Description'),
#  ('boisei ', 'NN2', 'O-'),
#  ('in ', 'II', 'B-Narrative'),
#  ('1959', 'MC', 'I-Narrative'),
#  (', ', 'Y', 'B-Description'),
#  ('her ', 'APPGE', 'I-Description'),
#  ('husband ', 'NN1', 'B-Narrative'),
#  ('louis ', 'NN1', 'B-Character'),
#  ('saw ', 'VVD', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('heavy ', 'JJ', 'B-Description'),
#  ('teeth ', 'NN2', 'I-Description'),
#  ('& ', 'Y', 'O-'),
#  ('jaws ', 'NN2', 'B-Description'),
#  ('& ', 'Y', 'O-'),
#  ('nicknamed ', 'VVD', 'B-Character'),
#  ('the ', 'AT', 'O-'),
#  ('species ', 'NN', 'B-AcademicTerms'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('man', 'NN1', 'B-Character'),
#  (', ', 'Y', 'B-MetadiscourseCohesive'),
#  ('like ', 'II', 'I-MetadiscourseCohesive'),
#  ('the ', 'AT', 'I-MetadiscourseCohesive'),
#  ('title ', 'NN1', 'B-AcademicTerms'),
#  ('character ', 'NN1', 'I-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('tchaikovsky ', 'JJ', 'B-Description'),
#  ('ballet', 'NN1', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('ruler ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('judea ', 'NN1', 'B-Description'),
#  ('attempted ', 'VVD', 'B-Character'),
#  ('to ', 'TO', 'I-Character'),
#  ('kill ', 'VVI', 'B-Negative'),
#  ('the ', 'AT', 'I-Negative'),
#  ('infant ', 'NN1', 'B-Character'),
#  ('jesus ', 'NN1', 'B-InformationTopics'),
#  ('"', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('hi', 'UH', 'B-MetadiscourseInteractive'),
#  (', ', 'Y', 'I-MetadiscourseInteractive'),
#  ('i', 'ZZ1', 'B-FirstPerson'),
#  ("'m ", 'VBM', 'I-FirstPerson'),
#  ('dot ', 'NN1', 'B-Description'),
#  ('richardson', 'NN1', 'B-Character'),
#  (') ', 'Y', 'O-'),
#  ('i ', 'ZZ1', 'B-FirstPerson'),
#  ('led ', 'VVD', 'B-Narrative'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('school', 'NN1', 'B-AcademicTerms'),
#  ("'s ", 'GE', 'I-AcademicTerms'),
#  ('bruins ', 'NN2', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('hitting ', 'VVG', 'B-Description'),
#  ('3 ', 'MC', 'B-InformationExposition'),
#  ('consecutive ', 'JJ', 'B-Narrative'),
#  ('years ', 'NNT2', 'I-Narrative'),
#  ('& ', 'Y', 'O-'),
#  ('was ', 'VBDZ', 'B-Narrative'),
#  ('named ', 'VVN', 'O-'),
#  ('ncaa ', 'NN1', 'B-InformationTopics'),
#  ('player ', 'NN1', 'B-Character'),
#  ('of ', 'IO', 'B-Narrative'),
#  ('the ', 'AT', 'I-Narrative'),
#  ('decade ', 'NNT1', 'I-Narrative'),
#  ('for ', 'IF', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('1980s', 'MC2', 'B-Narrative'),
#  ('" ', 'Y', 'O-'),
#  ('mossad ', 'NN1', 'B-Description'),
#  ('seen ', 'VVN', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('2008 ', 'MC', 'B-Narrative'),
#  ('film ', 'NN1', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('express', 'NN1', 'B-Interactive'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('told ', 'VVD', 'B-Interactive'),
#  ('the ', 'AT', 'B-AcademicTerms'),
#  ('story ', 'NN1', 'I-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('1961 ', 'MC', 'B-Narrative'),
#  ('heisman ', 'NN1', 'B-Character'),
#  ('trophy ', 'NN1', 'O-'),
#  ('winner', 'NN1', 'B-Positive'),
#  (', ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('first ', 'MD', 'O-'),
#  ('african ', 'JJ', 'B-Character'),
#  ('american ', 'JJ', 'B-Character'),
#  ('to ', 'TO', 'B-Strategic'),
#  ('win ', 'VVI', 'I-Strategic'),
#  ('the ', 'AT', 'O-'),
#  ('award', 'NN1', 'B-Positive'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('it ', 'PPH1', 'O-'),
#  ('opened ', 'VVD', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('1900', 'MC', 'O-'),
#  (', ', 'Y', 'B-Description'),
#  ('it ', 'PPH1', 'I-Description'),
#  ('s ', 'GE', 'I-Description'),
#  ('first ', 'MD', 'O-'),
#  ('line ', 'NN1', 'O-'),
#  ('running ', 'VVG', 'B-Narrative'),
#  ('from ', 'II', 'I-Narrative'),
#  ('paris', 'NN1', 'B-InformationPlace'),
#  ("' ", 'Y', 'O-'),
#  ('porte ', 'NN1', 'B-Character'),
#  ('de ', 'FW', 'O-'),
#  ('vincennes ', 'VVZ', 'O-'),
#  ('to ', 'II', 'O-'),
#  ('porte ', 'VVI', 'B-Character'),
#  ('maillot', 'NN1', 'B-AcademicTerms'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('gelsey ', 'NN1', 'O-'),
#  ('kirkland ', 'NN1', 'B-Description'),
#  ('starred ', 'VVD', 'B-Narrative'),
#  ('in ', 'II', 'I-Narrative'),
#  ('the ', 'AT', 'O-'),
#  ('1972 ', 'MC', 'B-Narrative'),
#  ('version ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('song ', 'NN1', 'B-Description'),
#  ('of', 'IO', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('nocturnal ', 'JJ', 'B-Narrative'),
#  ('bird', 'NN1', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('wascally ', 'RR', 'B-AcademicTerms'),
#  ('sign ', 'VV0', 'O-'),
#  ('whose ', 'DDQGE', 'B-Narrative'),
#  ('years ', 'NNT2', 'I-Narrative'),
#  ('include ', 'VV0', 'B-InformationReportVerbs'),
#  ('1951 ', 'MC', 'B-Narrative'),
#  ('& ', 'Y', 'O-'),
#  ('1999 ', 'MC', 'B-Narrative'),
#  ('shows ', 'NN2', 'O-'),
#  ('bravery ', 'NN1', 'B-Positive'),
#  ('against ', 'II', 'B-Negative'),
#  ('high ', 'JJ', 'B-Contingent'),
#  ('odds ', 'NN2', 'I-Contingent'),
#  ('& ', 'Y', 'O-'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('rarely ', 'RR', 'B-ForceStressed'),
#  ('be', 'VBI', 'B-InformationStates'),
#  ('-', 'Y', 'O-'),
#  ('fudd', 'NN1', 'B-Description'),
#  ('-', 'Y', 'O-'),
#  ('led ', 'VVD', 'B-Narrative'),
#  ('"', 'Y', 'O-'),
#  ('if ', 'CS', 'B-Contingent'),
#  ('you', 'PPY', 'B-Interactive'),
#  ("'re ", 'VBR', 'I-Interactive'),
#  ('thinking ', 'VVG', 'B-Character'),
#  ('outside ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('bun', 'NN1', 'B-Description'),
#  (', ', 'Y', 'O-'),
#  ('think ', 'VV0', 'B-Character'),
#  ('about ', 'II', 'I-Character'),
#  ('the ', 'AT', 'O-'),
#  ('990 ', 'MC', 'B-InformationExposition'),
#  ('calories ', 'NNU2', 'B-AcademicTerms'),
#  ('& ', 'Y', 'O-'),
#  ('1,930 ', 'MC', 'O-'),
#  ('mg ', 'NNU', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('sodium ', 'NN1', 'B-AcademicTerms'),
#  ('in ', 'II', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('chain', 'NN1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('volcano ', 'NN1', 'B-Description'),
#  ('nachos', 'NN2', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('famed ', 'VVN', 'B-Positive'),
#  ('for ', 'IF', 'I-Positive'),
#  ('the ', 'AT', 'O-'),
#  ('charge ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('light ', 'JJ', 'O-'),
#  ('brigade', 'NN1', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('it ', 'PPH1', 'B-Narrative'),
#  ('was ', 'VBDZ', 'I-Narrative'),
#  ('one ', 'MC1', 'B-InformationExposition'),
#  ('of ', 'IO', 'I-InformationExposition'),
#  ('the ', 'AT', 'I-InformationExposition'),
#  ('first ', 'MD', 'I-InformationExposition'),
#  ('wars ', 'NN2', 'B-Negative'),
#  ('to ', 'TO', 'O-'),
#  ('be ', 'VBI', 'O-'),
#  ('reported ', 'VVN', 'B-InformationReportVerbs'),
#  ('widely ', 'RR', 'B-Narrative'),
#  ('by ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('press', 'NN1', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('odysseus ', 'NN2', 'B-Character'),
#  ('had ', 'VHD', 'B-Narrative'),
#  ('been ', 'VBN', 'I-Narrative'),
#  ('gone ', 'VVN', 'B-Strategic'),
#  ('20 ', 'MC', 'B-Narrative'),
#  ('years', 'NNT2', 'I-Narrative'),
#  (', ', 'Y', 'O-'),
#  ('even ', 'RR', 'B-ForceStressed'),
#  ('after ', 'CS', 'I-ForceStressed'),
#  ('she', 'PPHS1', 'B-Narrative'),
#  ("'d ", 'VHD', 'I-Narrative'),
#  ('given ', 'VVN', 'O-'),
#  ('him ', 'PPHO1', 'B-Character'),
#  ('a ', 'AT1', 'B-Character'),
#  ('son', 'NN1', 'I-Character'),
#  (', ', 'Y', 'O-'),
#  ('telemachus', 'NN2', 'B-Description'),
#  ('. ', 'Y', 'B-Negative'),
#  ('yet ', 'RR', 'I-Negative'),
#  ('she ', 'PPHS1', 'B-Character'),
#  ('knew ', 'VVD', 'B-ConfidenceHigh'),
#  ('someday', 'RT', 'B-Uncertainty'),
#  (', ', 'Y', 'O-'),
#  ('odie ', 'NN1', 'B-Description'),
#  ('would ', 'VM', 'B-Narrative'),
#  ('return', 'VVI', 'B-Narrative'),
#  ('" ', 'Y', 'O-'),
#  ('martin ', 'NN1', 'B-Character'),
#  ('yan', 'NN1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('recipe ', 'NN1', 'B-Description'),
#  ('for ', 'IF', 'O-'),
#  ('the ', 'AT', 'B-Description'),
#  ('crab ', 'NN1', 'I-Description'),
#  ('version ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('egg ', 'NN1', 'B-Description'),
#  ('dish ', 'NN1', 'I-Description'),
#  ('features ', 'NN2', 'O-'),
#  ('ginger ', 'NN1', 'B-Description'),
#  ('& ', 'Y', 'O-'),
#  ('cilantro ', 'NN1', 'B-Description'),
#  ('as ', 'II31', 'O-'),
#  ('well ', 'II32', 'O-'),
#  ('as ', 'II33', 'O-'),
#  ('crab ', 'NN1', 'B-Description'),
#  ('& ', 'Y', 'O-'),
#  ('eggs ', 'NN2', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('correction ', 'NN1', 'B-AcademicTerms'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('prevention ', 'NN1', 'B-Negative'),
#  ('of ', 'IO', 'O-'),
#  ('skeletal ', 'JJ', 'B-Strategic'),
#  ('deformities', 'NN2', 'I-Strategic'),
#  (', ', 'Y', 'O-'),
#  ('sometimes ', 'RT', 'B-Contingent'),
#  ('by ', 'II', 'O-'),
#  ('surgery', 'NN1', 'B-InformationTopics'),
#  ('" ', 'Y', 'O-'),
#  ('mass ', 'JJ', 'B-AcademicTerms'),
#  ('number ', 'NN1', 'I-AcademicTerms'),
#  ('is ', 'VBZ', 'B-InformationExposition'),
#  ('defined ', 'VVN', 'I-InformationExposition'),
#  ('as ', 'II', 'I-InformationExposition'),
#  ('the ', 'AT', 'O-'),
#  ('number ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('neutrons ', 'NN2', 'B-AcademicTerms'),
#  ('& ', 'Y', 'O-'),
#  ('these ', 'DD2', 'B-Narrative'),
#  ('particles ', 'NN2', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('an ', 'AT1', 'O-'),
#  ('atom', 'NN1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('nucleus ', 'NN1', 'B-AcademicTerms'),
#  ('"', 'Y', 'O-'),
#  ('ironically', 'RR', 'B-Inquiry'),
#  (', ', 'Y', 'O-'),
#  ('fred ', 'NN1', 'B-Character'),
#  ('& ', 'Y', 'O-'),
#  ('ginger ', 'NN1', 'B-Description'),
#  ('sang ', 'VVD', 'B-Character'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('song ', 'NN1', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('1935 ', 'MC', 'B-Narrative'),
#  ('movie ', 'NN1', 'B-PublicTerms'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('roberta', 'NN1', 'B-Character'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('if ', 'CS', 'B-Contingent'),
#  ('you ', 'PPY', 'B-Interactive'),
#  ('ca', 'VM', 'B-Negative'),
#  ("n't ", 'XX', 'I-Negative'),
#  ('remember ', 'VVI', 'I-Negative'),
#  ('the ', 'AT', 'B-InformationTopics'),
#  ('name ', 'NN1', 'I-InformationTopics'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('painter', 'NN1', 'B-Character'),
#  (', ', 'Y', 'O-'),
#  ('just ', 'RR', 'B-ForceStressed'),
#  ('put ', 'VV0', 'B-Interactive'),
#  ('your ', 'APPGE', 'I-Interactive'),
#  ('lips ', 'NN2', 'B-Description'),
#  ('together ', 'RL', 'B-Positive'),
#  ('and ', 'CC', 'O-'),
#  ('blow', 'VVI', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('doctrine ', 'NN1', 'B-PublicTerms'),
#  ('asserting ', 'VVG', 'B-Citation'),
#  ('that ', 'CST', 'I-Citation'),
#  ('federal ', 'JJ', 'B-PublicTerms'),
#  ('laws ', 'NN2', 'I-PublicTerms'),
#  ('should', 'VM', 'B-Negative'),
#  ("n't ", 'XX', 'I-Negative'),
#  ('trump ', 'VVI', 'B-Strategic'),
#  ('those ', 'DD2', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('alabama ', 'NN1', 'B-InformationPlace'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('idaho ', 'NN1', 'B-InformationPlace'),
#  ('"', 'Y', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('small ', 'JJ', 'B-Description'),
#  ('cave', 'NN1', 'B-Description'),
#  (', ', 'Y', 'B-Contingent'),
#  ('perhaps ', 'RR', 'I-Contingent'),
#  ('a ', 'AT1', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('blue', 'JJ', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('one', 'MC1', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('you ', 'PPY', 'B-Interactive'),
#  ('can ', 'VM', 'I-Interactive'),
#  ('get ', 'VVI', 'O-'),
#  ('things ', 'NN2', 'B-InformationExposition'),
#  ('to ', 'TO', 'O-'),
#  ('stick ', 'VVI', 'B-Description'),
#  ('with ', 'IW', 'I-Description'),
#  ('suction ', 'NN1', 'B-Description'),
#  ('cups', 'NN2', 'I-Description'),
#  (', ', 'Y', 'O-'),
#  ('similar ', 'JJ', 'B-MetadiscourseCohesive'),
#  ('to ', 'II', 'I-MetadiscourseCohesive'),
#  ('those ', 'DD2', 'O-'),
#  ('on ', 'II', 'O-'),
#  ('octopus ', 'NN1', 'B-Description'),
#  ('arms', 'NN2', 'B-Description'),
#  (', ', 'Y', 'O-'),
#  ('where ', 'CS', 'O-'),
#  ('they', 'PPHS2', 'B-Character'),
#  ("'re ", 'VBR', 'I-Character'),
#  ('called ', 'VVN', 'O-'),
#  ('these', 'DD2', 'B-Narrative'),
#  ('" ', 'Y', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('1990 ', 'MC', 'B-Narrative'),
#  ('federal ', 'JJ', 'B-PublicTerms'),
#  ('law ', 'NN1', 'I-PublicTerms'),
#  ('defining ', 'VVG', 'B-InformationExposition'),
#  ('crops ', 'NN2', 'B-Description'),
#  ('grown ', 'VVN', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('way ', 'NN1', 'I-Narrative'),
#  ('says ', 'VVZ', 'B-Interactive'),
#  ('they ', 'PPHS2', 'O-'),
#  ('ca', 'VM', 'B-Interactive'),
#  ("n't ", 'XX', 'I-Interactive'),
#  ('be ', 'VBI', 'I-Interactive'),
#  ('produced ', 'VVN', 'B-InformationReportVerbs'),
#  ('using ', 'VVG', 'O-'),
#  ('arsenic ', 'NN1', 'B-Description'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('synthetic ', 'JJ', 'B-AcademicTerms'),
#  ('fertilizer ', 'NN1', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('abbreviated ', 'VVD', 'B-Positive'),
#  ('ez', 'NN2', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('they ', 'PPHS2', 'O-'),
#  ('were ', 'VBDR', 'B-Narrative'),
#  ('pushed ', 'VVN', 'B-Description'),
#  ('by ', 'II', 'I-Description'),
#  ('jack ', 'NN1', 'B-Description'),
#  ('kemp ', 'NN1', 'B-Description'),
#  ('as ', 'II', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('way ', 'NN1', 'O-'),
#  ('to ', 'TO', 'O-'),
#  ('revive ', 'VVI', 'B-InformationChangePositive'),
#  ('urban ', 'JJ', 'B-AcademicTerms'),
#  ('areas', 'NN2', 'B-AcademicTerms'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('45 ', 'MC', 'B-InformationExposition'),
#  ('seats ', 'NN2', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('bangladesh', 'NP1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('parliament ', 'NN1', 'B-PublicTerms'),
#  ('are ', 'VBR', 'B-Positive'),
#  ('reserved ', 'VVN', 'I-Positive'),
#  ('for ', 'IF', 'O-'),
#  ('these', 'DD2', 'O-'),
#  ('; ', 'Y', 'B-Reasoning'),
#  ('so', 'RR', 'I-Reasoning'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-Character'),
#  ('guess', 'VV0', 'I-Character'),
#  (', ', 'Y', 'O-'),
#  ('they', 'PPHS2', 'B-Character'),
#  ("'re ", 'VBR', 'I-Character'),
#  ('always ', 'RR', 'B-ConfidenceHigh'),
#  ('down', 'RP', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('governor ', 'NN1', 'B-Character'),
#  ('of ', 'IO', 'O-'),
#  ('new ', 'JJ', 'O-'),
#  ('york ', 'NN1', 'O-'),
#  ('4 ', 'MC', 'B-Narrative'),
#  ('times', 'NNT2', 'I-Narrative'),
#  (', ', 'Y', 'O-'),
#  ('he ', 'PPHS1', 'B-Character'),
#  ('ran ', 'VVD', 'B-Description'),
#  ('unsuccessfully ', 'RR', 'B-Negative'),
#  ('for ', 'IF', 'O-'),
#  ('president ', 'NN1', 'B-Character'),
#  ('in ', 'II', 'B-Narrative'),
#  ('1928', 'MC', 'I-Narrative'),
#  ('" ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('first ', 'MD', 'O-'),
#  ('primary ', 'JJ', 'B-AcademicTerms'),
#  ('teeth ', 'NN2', 'B-Description'),
#  ('to ', 'TO', 'O-'),
#  ('appear ', 'VVI', 'B-Description'),
#  ('in ', 'II', 'I-Description'),
#  ('a ', 'AT1', 'B-Character'),
#  ('baby ', 'NN1', 'I-Character'),
#  ('are ', 'VBR', 'B-Narrative'),
#  ('usually ', 'RR', 'I-Narrative'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('variety ', 'NN1', 'B-InformationTopics'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('gunga ', 'VV0', 'B-Description'),
#  ('din', 'NN1', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('author ', 'NN1', 'B-AcademicTerms'),
#  ('who ', 'PNQS', 'O-'),
#  ('rhymes ', 'VVZ', 'B-Description'),
#  ('with ', 'IW', 'I-Description'),
#  ('habitual ', 'JJ', 'B-CitationAuthority'),
#  ('drinking', 'NN1', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('jon ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('clue ', 'NN1', 'B-Character'),
#  ('crew ', 'NN1', 'I-Character'),
#  ('reports', 'NN2', 'B-InformationReportVerbs'),
#  ('.', 'Y', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('each ', 'DD1', 'B-InformationExposition'),
#  ('hemisphere ', 'NN1', 'B-Description'),
#  ('of ', 'IO', 'I-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('brain ', 'NN1', 'B-AcademicTerms'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('divided ', 'VVN', 'B-InformationReportVerbs'),
#  ('into ', 'II', 'I-InformationReportVerbs'),
#  ('4 ', 'MC', 'B-InformationExposition'),
#  ('of ', 'IO', 'O-'),
#  ('these', 'DD2', 'O-'),
#  (': ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('temporal', 'JJ', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('occipital', 'JJ', 'B-Description'),
#  (', ', 'Y', 'O-'),
#  ('parietal', 'JJ', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('frontal', 'JJ', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('cleanup ', 'NN1', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('pennsylvania ', 'NN1', 'B-InformationPlace'),
#  ('nuclear ', 'JJ', 'B-AcademicTerms'),
#  ('power ', 'NN1', 'I-AcademicTerms'),
#  ('plant ', 'NN1', 'B-Description'),
#  ('following ', 'VVG', 'B-Narrative'),
#  ('the ', 'AT', 'I-Narrative'),
#  ('1979 ', 'MC', 'B-Narrative'),
#  ('meltdown ', 'NN1', 'B-Negative'),
#  ('did', 'VD0', 'B-Negative'),
#  ("n't ", 'XX', 'I-Negative'),
#  ('end ', 'VVI', 'B-Narrative'),
#  ('until ', 'II', 'B-Narrative'),
#  ('1993 ', 'MC', 'B-Narrative'),
#  ('actor ', 'NN1', 'B-Character'),
#  ('most ', 'RGT', 'B-InformationExposition'),
#  ('associated ', 'VVN', 'B-InformationExposition'),
#  ('with ', 'IW', 'I-InformationExposition'),
#  ('the ', 'AT', 'O-'),
#  ('6 ', 'MC', 'B-InformationExposition'),
#  ('degrees ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'I-AcademicTerms'),
#  ('separation ', 'NN1', 'B-AcademicTerms'),
#  ('game ', 'NN1', 'B-Strategic'),
#  ('these ', 'DD2', 'B-Narrative'),
#  ('games ', 'NN2', 'B-Strategic'),
#  ('for ', 'IF', 'O-'),
#  ('athletes ', 'NN2', 'B-Character'),
#  ('with ', 'IW', 'O-'),
#  ('physical ', 'JJ', 'B-AcademicTerms'),
#  ('disabilities ', 'NN2', 'B-Negative'),
#  ('began ', 'VVD', 'B-Narrative'),
#  ('in ', 'II', 'I-Narrative'),
#  ('rome ', 'NN1', 'B-InformationPlace'),
#  ('in ', 'II', 'B-Narrative'),
#  ('1960 ', 'MC', 'I-Narrative'),
#  ('"', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('human ', 'JJ', 'B-Reasoning'),
#  ('rights ', 'NN2', 'I-Reasoning'),
#  ('organization', 'NN1', 'B-PublicTerms'),
#  (', ', 'Y', 'O-'),
#  ('whose ', 'DDQGE', 'B-Character'),
#  ('logo ', 'NN1', 'B-AcademicTerms'),
#  ('is ', 'VBZ', 'B-Narrative'),
#  ('seen ', 'VVN', 'I-Narrative'),
#  ('here', 'RL', 'B-Narrative'),
#  (', ', 'Y', 'I-Narrative'),
#  ('won ', 'VVD', 'B-Strategic'),
#  ('the ', 'AT', 'B-Positive'),
#  ('nobel ', 'NN1', 'I-Positive'),
#  ('peace ', 'NN1', 'B-Positive'),
#  ('prize ', 'NN1', 'B-Positive'),
#  ('in ', 'II', 'B-Narrative'),
#  ('1977', 'MC', 'I-Narrative'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('hollywood ', 'NN1', 'B-InformationPlace'),
#  ('cemetery ', 'NN1', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('city ', 'NN1', 'B-InformationPlace'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('the ', 'AT', 'I-InformationStates'),
#  ('final ', 'JJ', 'B-Narrative'),
#  ('resting ', 'NN1', 'B-Description'),
#  ('place ', 'NN1', 'I-Description'),
#  ('of ', 'IO', 'I-Description'),
#  ('james ', 'NN2', 'B-Character'),
#  ('monroe', 'NN1', 'B-Character'),
#  (', ', 'Y', 'O-'),
#  ('john ', 'NN1', 'B-Character'),
#  ('tyler ', 'NN1', 'B-Character'),
#  ('& ', 'Y', 'O-'),
#  ('jefferson ', 'NN1', 'B-Character'),
#  ('davis', 'NP1', 'B-Character'),
#  ('" ', 'Y', 'O-'),
#  ('brand ', 'NN1', 'B-InformationTopics'),
#  ('of ', 'IO', 'O-'),
#  ('cereal ', 'NN1', 'B-Description'),
#  ('thou ', 'PPY', 'B-Interactive'),
#  ('could ', 'VM', 'B-ConfidenceHedged'),
#  ('1st ', 'MD', 'O-'),
#  ('buy ', 'VVI', 'O-'),
#  ('in ', 'II', 'B-Narrative'),
#  ('1901 ', 'MC', 'I-Narrative'),
#  ('"', 'Y', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('french ', 'JJ', 'B-Character'),
#  ('existentialist ', 'NN1', 'B-Character'),
#  ('found ', 'VVD', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'B-Character'),
#  ('no ', 'AT', 'I-Character'),
#  ('exit', 'NN1', 'B-Narrative'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('at ', 'II', 'B-Narrative'),
#  ('age ', 'NN1', 'I-Narrative'),
#  ('39', 'MC', 'B-InformationExposition'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('it', 'PPH1', 'B-ConfidenceHigh'),
#  ("'s ", 'VBZ', 'I-ConfidenceHigh'),
#  ('the ', 'AT', 'I-ConfidenceHigh'),
#  ('hilarious ', 'JJ', 'B-Positive'),
#  ('title ', 'NN1', 'B-InformationTopics'),
#  ('role ', 'NN1', 'B-AcademicTerms'),
#  ('played ', 'VVN', 'O-'),
#  ('by ', 'II', 'O-'),
#  ('america ', 'NP1', 'B-InformationPlace'),
#  ('ferrera', 'NN1', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('as ', 'CSA', 'O-'),
#  ('pictured ', 'VVN', 'B-Description'),
#  ('here', 'RL', 'B-Narrative'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('cats ', 'NN2', 'B-Description'),
#  ('have ', 'VH0', 'B-InformationStates'),
#  ('tapetum ', 'NN1', 'B-Description'),
#  ('lucidum ', 'NN1', 'B-Positive'),
#  ('membranes ', 'NN2', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('body ', 'NN1', 'B-AcademicTerms'),
#  ('part', 'NN1', 'O-'),
#  (', ', 'Y', 'B-Reasoning'),
#  ('so ', 'CS', 'I-Reasoning'),
#  ('they ', 'PPHS2', 'O-'),
#  ('have ', 'VH0', 'O-'),
#  ('2 ', 'MC', 'B-InformationExposition'),
#  ('chances ', 'NN2', 'B-Contingent'),
#  ('to ', 'TO', 'O-'),
#  ('catch ', 'VVI', 'B-Strategic'),
#  ('photons', 'NN2', 'B-AcademicTerms'),
#  ('" ', 'Y', 'O-'),
#  ('mount ', 'NN1', 'B-Description'),
#  ('st', 'NNU', 'B-AcademicTerms'),
#  ('. ', 'Y', 'O-'),
#  ('elias ', 'NN1', 'B-Character'),
#  ('is ', 'VBZ', 'B-InformationExposition'),
#  ('the ', 'AT', 'I-InformationExposition'),
#  ('second', 'NNT1', 'I-InformationExposition'),
#  ('-', 'Y', 'O-'),
#  ('highest ', 'JJT', 'B-InformationExposition'),
#  ('mountain ', 'NN1', 'B-Description'),
#  ('in ', 'II', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('state ', 'NN1', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('u.s', 'NNU', 'O-'),
#  ('. ', 'Y', 'B-Character'),
#  ('starbuck ', 'VV0', 'I-Character'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('a ', 'AT1', 'I-InformationStates'),
#  ('woman ', 'NN1', 'B-Character'),
#  ('on ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('sci', 'NN1', 'O-'),
#  ('-', 'Y', 'O-'),
#  ('fi ', 'NN2', 'B-Character'),
#  ('channel', 'NN1', 'O-'),
#  ("'s ", 'GE', 'O-'),
#  ('version ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'O-'),
#  ('series ', 'NN', 'B-InformationTopics'),
#  ('he ', 'PPHS1', 'B-Character'),
#  ('reportedly ', 'RR', 'B-ConfidenceHedged'),
#  ('keeps ', 'VVZ', 'B-InformationReportVerbs'),
#  ('his ', 'APPGE', 'B-Character'),
#  ('2000 ', 'MC', 'B-Narrative'),
#  ('best ', 'JJT', 'B-Positive'),
#  ('actor ', 'NN1', 'B-Character'),
#  ('oscar ', 'NN1', 'B-Character'),
#  ('in ', 'II', 'O-'),
#  ('a ', 'AT1', 'B-Description'),
#  ('chicken ', 'NN1', 'I-Description'),
#  ('coop ', 'NN1', 'B-Description'),
#  ('on ', 'II', 'B-Description'),
#  ('his ', 'APPGE', 'I-Description'),
#  ('australian ', 'JJ', 'B-InformationPlace'),
#  ('ranch ', 'NN1', 'B-Description'),
#  ('"', 'Y', 'O-'),
#  ('in ', 'II', 'B-Narrative'),
#  ('1971 ', 'MC', 'I-Narrative'),
#  ('norman ', 'JJ', 'B-Character'),
#  ('lear ', 'NN1', 'B-Description'),
#  ('turned ', 'VVD', 'B-Narrative'),
#  ('the ', 'AT', 'I-Narrative'),
#  ('british ', 'JJ', 'B-Character'),
#  ('series ', 'NN', 'B-InformationTopics'),
#  ('"', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('till ', 'II', 'B-Negative'),
#  ('death ', 'NN1', 'I-Negative'),
#  ('us ', 'PPIO2', 'O-'),
#  ('do ', 'VD0', 'B-ForceStressed'),
#  ('part', 'NN1', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('into ', 'II', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('american ', 'JJ', 'B-Character'),
#  ('tv ', 'NN1', 'B-Description'),
#  ('hit', 'VVD', 'B-Description'),
#  ('" ', 'Y', 'O-'),
#  ('1986', 'MC', 'B-Narrative'),
#  (': ', 'Y', 'O-'),
#  ('charlie ', 'NN1', 'B-Character'),
#  ('sheen ', 'NN1', 'B-Description'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('a ', 'AT1', 'I-InformationStates'),
#  ('soldier ', 'NN1', 'B-Character'),
#  ('in ', 'II', 'O-'),
#  ('vietnam ', 'NN2', 'B-InformationPlace'),
#  ('"', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('kelly ', 'RR', 'B-Positive'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'B-Inquiry'),
#  ('clue ', 'NN1', 'I-Inquiry'),
#  ('crew ', 'NN1', 'B-Character'),
#  ('shows ', 'VVZ', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('map ', 'NN1', 'B-Description'),
#  ('on ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('monitor', 'NN1', 'B-PublicTerms'),
#  ('.', 'Y', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('stretching ', 'VVG', 'B-Description'),
#  ('from ', 'II', 'I-Description'),
#  ('the ', 'AT', 'O-'),
#  ('taurus ', 'NN1', 'B-Description'),
#  ('mountains ', 'NN2', 'B-Description'),
#  ('in ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('north ', 'ND1', 'I-Description'),
#  ('to ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('persian ', 'JJ', 'B-Character'),
#  ('gulf ', 'NN1', 'B-Description'),
#  ('in ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('south', 'ND1', 'I-Description'),
#  (', ', 'Y', 'O-'),
#  ('with ', 'IW', 'B-Description'),
#  ('it ', 'PPH1', 'I-Description'),
#  ('s ', 'GE', 'I-Description'),
#  ('heart ', 'NN1', 'O-'),
#  ('between ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('tigris ', 'NN1', 'B-AcademicTerms'),
#  ('and ', 'CC', 'O-'),
#  ('euphrates ', 'NN2', 'B-Description'),
#  ('rivers', 'NN2', 'I-Description'),
#  (', ', 'Y', 'O-'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('ancient ', 'JJ', 'B-Narrative'),
#  ('region', 'NN1', 'B-InformationPlace'),
#  (', ', 'Y', 'O-'),
#  ('home ', 'RL', 'B-Narrative'),
#  ('to ', 'II', 'I-Narrative'),
#  ('the ', 'AT', 'O-'),
#  ('world', 'NN1', 'B-ForceStressed'),
#  ("'s ", 'GE', 'I-ForceStressed'),
#  ('first ', 'MD', 'O-'),
#  ('cities', 'NN2', 'B-InformationPlace'),
#  ('" ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-Description'),
#  ('bone', 'NN1', 'I-Description'),
#  ('-', 'Y', 'O-'),
#  ('in ', 'II', 'O-'),
#  ('type ', 'II32', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('steak ', 'NN1', 'B-Description'),
#  ('with ', 'IW', 'I-Description'),
#  ('a ', 'AT1', 'O-'),
#  ('double ', 'JJ', 'B-InformationChange'),
#  ('anatomical ', 'JJ', 'B-InformationTopics'),
#  ('name ', 'NN1', 'I-InformationTopics'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('also ', 'RR', 'B-MetadiscourseCohesive'),
#  ('called ', 'VVN', 'B-InformationReportVerbs'),
#  ('a ', 'AT1', 'I-InformationReportVerbs'),
#  ('cowboy ', 'NN1', 'B-Description'),
#  ('steak ', 'NN1', 'I-Description'),
#  ('"', 'Y', 'B-Character'),
#  ('when ', 'CS', 'I-Character'),
#  ('exercising', 'VVG', 'B-InformationReportVerbs'),
#  (', ', 'Y', 'O-'),
#  ('be ', 'VBI', 'B-ConfidenceHigh'),
#  ('sure ', 'JJ', 'I-ConfidenceHigh'),
#  ('to ', 'TO', 'O-'),
#  ('replace ', 'VVI', 'B-InformationExposition'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('element ', 'NN1', 'B-AcademicTerms'),
#  ('you ', 'PPY', 'B-Interactive'),
#  ('sweat ', 'VV0', 'B-Description'),
#  ('out', 'RP', 'I-Description'),
#  (', ', 'Y', 'O-'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('you ', 'PPY', 'B-Interactive'),
#  ('risk ', 'VV0', 'B-Uncertainty'),
#  ('hyponatremia', 'NN1', 'B-AcademicTerms'),
#  ('" ', 'Y', 'O-'),
#  ('turkey ', 'NN1', 'B-Description'),
#  ('& ', 'Y', 'O-'),
#  ('ukraine ', 'NN1', 'B-InformationPlace'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('newspaper ', 'NN1', 'B-PublicTerms'),
#  ('chain ', 'NN1', 'B-InformationExposition'),
#  ('that ', 'CST', 'O-'),
#  ...]

# %% [markdown]
# ### 4.3.8 Generate Frequency Tables

# %% [markdown]
# We can use DS's `frequency_table` function to easily review counts. Here's the description from the API:
#
# <blockquote>
# <h4><a href="https://docuscospacy.readthedocs.io/en/latest/api.html#corpus-analysis-frequency-table-tok-n-tokens-count-by-pos">corpus_analysis.frequency_table(tok, n_tokens, count_by=’pos’)</a></h4>
# <p>Generate a count of token frequencies.</p>
# <div><dl class="field-list simple">
# <dt class="field-odd">Parameters</dt>
# <dd class="field-odd"><ul class="simple">
# <li><p><strong>tok</strong> - A dictionary of tuples as generated by the <cite>convert_corpus</cite> function</p></li>
# <li><p><strong>n_tokens</strong> - A count of total tokens against which to normalize</p></li>
# <li><p><strong>count_by</strong> - One of ‘pos’ or ‘ds’ for aggregating tokens</p></li>
# </ul>
# </dd>
# <dt class="field-even">Return</dt>
# <dd class="field-even"><ul class="simple">
# <li><p>a dataframe of absolute frequencies, normalized frequencies (per million tokens) and ranges</p></li>
# </ul>
# </dd>
# </dl>
# </div>
# </blockquote>
#
# `frequency_table` also [normalizes](https://en.wikipedia.org/wiki/Normalization_(statistics)) the data across the corpus, so that the counts can be compared across the corpi, i.e. compare and contrast the returned absolute frequencies (col `AF`), normalized relative frequencies (per million tokens) (col `RF`), and ranges (col `Range`). token shares a common scale.

# %% [markdown]
# #### 4.3.8.1 POS tables

# %% [markdown]
# In our first frequency table, we will normalize the counts with the non_punct (or the total number of tokens that are not punctuation), because POS token counts omit tokens tagged as punctuation. Later we will count ALLTHETHINGS, since DS includes punctuation.

# %%
freq_table_POS = frequency_table(
    tok=tp, # converted corpus into dict objs
    count_by='pos', # Count by POS tags
    n_tokens=non_punct # norm the corpus by excluding punctuation
)

# %%
freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_10436">
#   <thead>
#     <tr>
#       <th id="T_10436_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_10436_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_10436_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_10436_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_10436_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_10436_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_10436_row0_col1" class="data row0 col1" >AT</td>
#       <td id="T_10436_row0_col2" class="data row0 col2" >25344</td>
#       <td id="T_10436_row0_col3" class="data row0 col3" >56688.48</td>
#       <td id="T_10436_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row1_col0" class="data row1 col0" >this</td>
#       <td id="T_10436_row1_col1" class="data row1 col1" >DD1</td>
#       <td id="T_10436_row1_col2" class="data row1 col2" >18029</td>
#       <td id="T_10436_row1_col3" class="data row1 col3" >40326.57</td>
#       <td id="T_10436_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row2_col0" class="data row2 col0" >of</td>
#       <td id="T_10436_row2_col1" class="data row2 col1" >IO</td>
#       <td id="T_10436_row2_col2" class="data row2 col2" >15678</td>
#       <td id="T_10436_row2_col3" class="data row2 col3" >35067.94</td>
#       <td id="T_10436_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row3_col0" class="data row3 col0" >in</td>
#       <td id="T_10436_row3_col1" class="data row3 col1" >II</td>
#       <td id="T_10436_row3_col2" class="data row3 col2" >14256</td>
#       <td id="T_10436_row3_col3" class="data row3 col3" >31887.27</td>
#       <td id="T_10436_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row4_col0" class="data row4 col0" >a</td>
#       <td id="T_10436_row4_col1" class="data row4 col1" >AT1</td>
#       <td id="T_10436_row4_col2" class="data row4 col2" >12428</td>
#       <td id="T_10436_row4_col3" class="data row4 col3" >27798.47</td>
#       <td id="T_10436_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row5_col0" class="data row5 col0" >it</td>
#       <td id="T_10436_row5_col1" class="data row5 col1" >PPH1</td>
#       <td id="T_10436_row5_col2" class="data row5 col2" >5167</td>
#       <td id="T_10436_row5_col3" class="data row5 col3" >11557.34</td>
#       <td id="T_10436_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row6_col0" class="data row6 col0" >for</td>
#       <td id="T_10436_row6_col1" class="data row6 col1" >IF</td>
#       <td id="T_10436_row6_col2" class="data row6 col2" >5143</td>
#       <td id="T_10436_row6_col3" class="data row6 col3" >11503.66</td>
#       <td id="T_10436_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row7_col0" class="data row7 col0" >is</td>
#       <td id="T_10436_row7_col1" class="data row7 col1" >VBZ</td>
#       <td id="T_10436_row7_col2" class="data row7 col2" >4825</td>
#       <td id="T_10436_row7_col3" class="data row7 col3" >10792.37</td>
#       <td id="T_10436_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row8_col0" class="data row8 col0" >'s</td>
#       <td id="T_10436_row8_col1" class="data row8 col1" >GE</td>
#       <td id="T_10436_row8_col2" class="data row8 col2" >4823</td>
#       <td id="T_10436_row8_col3" class="data row8 col3" >10787.90</td>
#       <td id="T_10436_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_10436_row9_col0" class="data row9 col0" >was</td>
#       <td id="T_10436_row9_col1" class="data row9 col1" >VBDZ</td>
#       <td id="T_10436_row9_col2" class="data row9 col2" >4200</td>
#       <td id="T_10436_row9_col3" class="data row9 col3" >9394.40</td>
#       <td id="T_10436_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since it's a dataframe, we can filter and sort it easily with the `query()` method. Yay!
#
# Below, we filter for an AF greater than 10 and token tags as verbs (starting with ‘V’).
#
# Refer to the [CLAWS7 POS table](https://ucrel.lancs.ac.uk/claws7tags.html) for desired speech tags to filter against.

# %%
freq_table_POS.query('AF > 10 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_89e8e">
#   <thead>
#     <tr>
#       <th id="T_89e8e_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_89e8e_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_89e8e_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_89e8e_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_89e8e_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_89e8e_row0_col0" class="data row0 col0" >is</td>
#       <td id="T_89e8e_row0_col1" class="data row0 col1" >VBZ</td>
#       <td id="T_89e8e_row0_col2" class="data row0 col2" >4825</td>
#       <td id="T_89e8e_row0_col3" class="data row0 col3" >10792.37</td>
#       <td id="T_89e8e_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row1_col0" class="data row1 col0" >was</td>
#       <td id="T_89e8e_row1_col1" class="data row1 col1" >VBDZ</td>
#       <td id="T_89e8e_row1_col2" class="data row1 col2" >4200</td>
#       <td id="T_89e8e_row1_col3" class="data row1 col3" >9394.40</td>
#       <td id="T_89e8e_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row2_col0" class="data row2 col0" >'s</td>
#       <td id="T_89e8e_row2_col1" class="data row2 col1" >VBZ</td>
#       <td id="T_89e8e_row2_col2" class="data row2 col2" >2559</td>
#       <td id="T_89e8e_row2_col3" class="data row2 col3" >5723.87</td>
#       <td id="T_89e8e_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row3_col0" class="data row3 col0" >are</td>
#       <td id="T_89e8e_row3_col1" class="data row3 col1" >VBR</td>
#       <td id="T_89e8e_row3_col2" class="data row3 col2" >1153</td>
#       <td id="T_89e8e_row3_col3" class="data row3 col3" >2578.99</td>
#       <td id="T_89e8e_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row4_col0" class="data row4 col0" >be</td>
#       <td id="T_89e8e_row4_col1" class="data row4 col1" >VBI</td>
#       <td id="T_89e8e_row4_col2" class="data row4 col2" >913</td>
#       <td id="T_89e8e_row4_col3" class="data row4 col3" >2042.16</td>
#       <td id="T_89e8e_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row5_col0" class="data row5 col0" >has</td>
#       <td id="T_89e8e_row5_col1" class="data row5 col1" >VHZ</td>
#       <td id="T_89e8e_row5_col2" class="data row5 col2" >842</td>
#       <td id="T_89e8e_row5_col3" class="data row5 col3" >1883.35</td>
#       <td id="T_89e8e_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row6_col0" class="data row6 col0" >called</td>
#       <td id="T_89e8e_row6_col1" class="data row6 col1" >VVN</td>
#       <td id="T_89e8e_row6_col2" class="data row6 col2" >781</td>
#       <td id="T_89e8e_row6_col3" class="data row6 col3" >1746.91</td>
#       <td id="T_89e8e_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row7_col0" class="data row7 col0" >named</td>
#       <td id="T_89e8e_row7_col1" class="data row7 col1" >VVN</td>
#       <td id="T_89e8e_row7_col2" class="data row7 col2" >756</td>
#       <td id="T_89e8e_row7_col3" class="data row7 col3" >1690.99</td>
#       <td id="T_89e8e_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row8_col0" class="data row8 col0" >seen</td>
#       <td id="T_89e8e_row8_col1" class="data row8 col1" >VVN</td>
#       <td id="T_89e8e_row8_col2" class="data row8 col2" >730</td>
#       <td id="T_89e8e_row8_col3" class="data row8 col3" >1632.84</td>
#       <td id="T_89e8e_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_89e8e_row9_col0" class="data row9 col0" >can</td>
#       <td id="T_89e8e_row9_col1" class="data row9 col1" >VM</td>
#       <td id="T_89e8e_row9_col2" class="data row9 col2" >682</td>
#       <td id="T_89e8e_row9_col3" class="data row9 col3" >1525.47</td>
#       <td id="T_89e8e_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Filter for adverbs, yo! How are we modifying those verbs?
freq_table_POS.query('Tag.str.startswith("R")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_38300">
#   <thead>
#     <tr>
#       <th id="T_38300_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_38300_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_38300_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_38300_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_38300_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38300_row0_col0" class="data row0 col0" >here</td>
#       <td id="T_38300_row0_col1" class="data row0 col1" >RL</td>
#       <td id="T_38300_row0_col2" class="data row0 col2" >1020</td>
#       <td id="T_38300_row0_col3" class="data row0 col3" >2281.50</td>
#       <td id="T_38300_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row1_col0" class="data row1 col0" >also</td>
#       <td id="T_38300_row1_col1" class="data row1 col1" >RR</td>
#       <td id="T_38300_row1_col2" class="data row1 col2" >556</td>
#       <td id="T_38300_row1_col3" class="data row1 col3" >1243.64</td>
#       <td id="T_38300_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row2_col0" class="data row2 col0" >up</td>
#       <td id="T_38300_row2_col1" class="data row2 col1" >RP</td>
#       <td id="T_38300_row2_col2" class="data row2 col2" >547</td>
#       <td id="T_38300_row2_col3" class="data row2 col3" >1223.51</td>
#       <td id="T_38300_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row3_col0" class="data row3 col0" >out</td>
#       <td id="T_38300_row3_col1" class="data row3 col1" >RP</td>
#       <td id="T_38300_row3_col2" class="data row3 col2" >367</td>
#       <td id="T_38300_row3_col3" class="data row3 col3" >820.89</td>
#       <td id="T_38300_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row4_col0" class="data row4 col0" >now</td>
#       <td id="T_38300_row4_col1" class="data row4 col1" >RT</td>
#       <td id="T_38300_row4_col2" class="data row4 col2" >310</td>
#       <td id="T_38300_row4_col3" class="data row4 col3" >693.40</td>
#       <td id="T_38300_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row5_col0" class="data row5 col0" >just</td>
#       <td id="T_38300_row5_col1" class="data row5 col1" >RR</td>
#       <td id="T_38300_row5_col2" class="data row5 col2" >295</td>
#       <td id="T_38300_row5_col3" class="data row5 col3" >659.84</td>
#       <td id="T_38300_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row6_col0" class="data row6 col0" >most</td>
#       <td id="T_38300_row6_col1" class="data row6 col1" >RGT</td>
#       <td id="T_38300_row6_col2" class="data row6 col2" >266</td>
#       <td id="T_38300_row6_col3" class="data row6 col3" >594.98</td>
#       <td id="T_38300_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row7_col0" class="data row7 col0" >once</td>
#       <td id="T_38300_row7_col1" class="data row7 col1" >RR</td>
#       <td id="T_38300_row7_col2" class="data row7 col2" >241</td>
#       <td id="T_38300_row7_col3" class="data row7 col3" >539.06</td>
#       <td id="T_38300_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row8_col0" class="data row8 col0" >only</td>
#       <td id="T_38300_row8_col1" class="data row8 col1" >RR</td>
#       <td id="T_38300_row8_col2" class="data row8 col2" >232</td>
#       <td id="T_38300_row8_col3" class="data row8 col3" >518.93</td>
#       <td id="T_38300_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row9_col0" class="data row9 col0" >often</td>
#       <td id="T_38300_row9_col1" class="data row9 col1" >RR</td>
#       <td id="T_38300_row9_col2" class="data row9 col2" >231</td>
#       <td id="T_38300_row9_col3" class="data row9 col3" >516.69</td>
#       <td id="T_38300_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row10_col0" class="data row10 col0" >down</td>
#       <td id="T_38300_row10_col1" class="data row10 col1" >RP</td>
#       <td id="T_38300_row10_col2" class="data row10 col2" >195</td>
#       <td id="T_38300_row10_col3" class="data row10 col3" >436.17</td>
#       <td id="T_38300_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row11_col0" class="data row11 col0" >later</td>
#       <td id="T_38300_row11_col1" class="data row11 col1" >RRR</td>
#       <td id="T_38300_row11_col2" class="data row11 col2" >193</td>
#       <td id="T_38300_row11_col3" class="data row11 col3" >431.69</td>
#       <td id="T_38300_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row12_col0" class="data row12 col0" >back</td>
#       <td id="T_38300_row12_col1" class="data row12 col1" >RP</td>
#       <td id="T_38300_row12_col2" class="data row12 col2" >185</td>
#       <td id="T_38300_row12_col3" class="data row12 col3" >413.80</td>
#       <td id="T_38300_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row13_col0" class="data row13 col0" >about</td>
#       <td id="T_38300_row13_col1" class="data row13 col1" >RG</td>
#       <td id="T_38300_row13_col2" class="data row13 col2" >172</td>
#       <td id="T_38300_row13_col3" class="data row13 col3" >384.72</td>
#       <td id="T_38300_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row14_col0" class="data row14 col0" >off</td>
#       <td id="T_38300_row14_col1" class="data row14 col1" >RP</td>
#       <td id="T_38300_row14_col2" class="data row14 col2" >170</td>
#       <td id="T_38300_row14_col3" class="data row14 col3" >380.25</td>
#       <td id="T_38300_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row15_col0" class="data row15 col0" >then</td>
#       <td id="T_38300_row15_col1" class="data row15 col1" >RT</td>
#       <td id="T_38300_row15_col2" class="data row15 col2" >142</td>
#       <td id="T_38300_row15_col3" class="data row15 col3" >317.62</td>
#       <td id="T_38300_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row16_col0" class="data row16 col0" >home</td>
#       <td id="T_38300_row16_col1" class="data row16 col1" >RL</td>
#       <td id="T_38300_row16_col2" class="data row16 col2" >141</td>
#       <td id="T_38300_row16_col3" class="data row16 col3" >315.38</td>
#       <td id="T_38300_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row17_col0" class="data row17 col0" >there</td>
#       <td id="T_38300_row17_col1" class="data row17 col1" >RL</td>
#       <td id="T_38300_row17_col2" class="data row17 col2" >141</td>
#       <td id="T_38300_row17_col3" class="data row17 col3" >315.38</td>
#       <td id="T_38300_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row18_col0" class="data row18 col0" >never</td>
#       <td id="T_38300_row18_col1" class="data row18 col1" >RR</td>
#       <td id="T_38300_row18_col2" class="data row18 col2" >137</td>
#       <td id="T_38300_row18_col3" class="data row18 col3" >306.44</td>
#       <td id="T_38300_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_38300_row19_col0" class="data row19 col0" >when</td>
#       <td id="T_38300_row19_col1" class="data row19 col1" >RRQ</td>
#       <td id="T_38300_row19_col2" class="data row19 col2" >135</td>
#       <td id="T_38300_row19_col3" class="data row19 col3" >301.96</td>
#       <td id="T_38300_row19_col4" class="data row19 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.2 DS category tables

# %% [markdown]
# Note how we normalize by ‘corpus_total’ as DocuScope includes punctuation in its tagging system.

# %%
freq_table_DS = frequency_table(
    tok=tp, 
    n_tokens=corpus_total, 
    count_by='ds'
)

# %%
freq_table_DS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_089c7">
#   <thead>
#     <tr>
#       <th id="T_089c7_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_089c7_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_089c7_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_089c7_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_089c7_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_089c7_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_089c7_row0_col1" class="data row0 col1" >Untagged</td>
#       <td id="T_089c7_row0_col2" class="data row0 col2" >13730</td>
#       <td id="T_089c7_row0_col3" class="data row0 col3" >23865.19</td>
#       <td id="T_089c7_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row1_col0" class="data row1 col0" >this</td>
#       <td id="T_089c7_row1_col1" class="data row1 col1" >Narrative</td>
#       <td id="T_089c7_row1_col2" class="data row1 col2" >12891</td>
#       <td id="T_089c7_row1_col3" class="data row1 col3" >22406.86</td>
#       <td id="T_089c7_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row2_col0" class="data row2 col0" >of</td>
#       <td id="T_089c7_row2_col1" class="data row2 col1" >Untagged</td>
#       <td id="T_089c7_row2_col2" class="data row2 col2" >11083</td>
#       <td id="T_089c7_row2_col3" class="data row2 col3" >19264.23</td>
#       <td id="T_089c7_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row3_col0" class="data row3 col0" >in</td>
#       <td id="T_089c7_row3_col1" class="data row3 col1" >Untagged</td>
#       <td id="T_089c7_row3_col2" class="data row3 col2" >7293</td>
#       <td id="T_089c7_row3_col3" class="data row3 col3" >12676.53</td>
#       <td id="T_089c7_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row4_col0" class="data row4 col0" >a</td>
#       <td id="T_089c7_row4_col1" class="data row4 col1" >Untagged</td>
#       <td id="T_089c7_row4_col2" class="data row4 col2" >6784</td>
#       <td id="T_089c7_row4_col3" class="data row4 col3" >11791.80</td>
#       <td id="T_089c7_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row5_col0" class="data row5 col0" >to</td>
#       <td id="T_089c7_row5_col1" class="data row5 col1" >Untagged</td>
#       <td id="T_089c7_row5_col2" class="data row5 col2" >3479</td>
#       <td id="T_089c7_row5_col3" class="data row5 col3" >6047.12</td>
#       <td id="T_089c7_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row6_col0" class="data row6 col0" >for</td>
#       <td id="T_089c7_row6_col1" class="data row6 col1" >Untagged</td>
#       <td id="T_089c7_row6_col2" class="data row6 col2" >3466</td>
#       <td id="T_089c7_row6_col3" class="data row6 col3" >6024.53</td>
#       <td id="T_089c7_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row7_col0" class="data row7 col0" >'s</td>
#       <td id="T_089c7_row7_col1" class="data row7 col1" >Untagged</td>
#       <td id="T_089c7_row7_col2" class="data row7 col2" >3279</td>
#       <td id="T_089c7_row7_col3" class="data row7 col3" >5699.49</td>
#       <td id="T_089c7_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row8_col0" class="data row8 col0" >was</td>
#       <td id="T_089c7_row8_col1" class="data row8 col1" >Narrative</td>
#       <td id="T_089c7_row8_col2" class="data row8 col2" >2816</td>
#       <td id="T_089c7_row8_col3" class="data row8 col3" >4894.71</td>
#       <td id="T_089c7_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_089c7_row9_col0" class="data row9 col0" >this</td>
#       <td id="T_089c7_row9_col1" class="data row9 col1" >Untagged</td>
#       <td id="T_089c7_row9_col2" class="data row9 col2" >2433</td>
#       <td id="T_089c7_row9_col3" class="data row9 col3" >4228.99</td>
#       <td id="T_089c7_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's sort by DS tags!
#
# Review the DS tags in their [user docs](https://docuscospacy.readthedocs.io/en/latest/docuscope.html#categories).

# %%
# By INQUIRY
freq_table_DS.query('Tag.str.startswith("Inquiry")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8dce">
#   <thead>
#     <tr>
#       <th id="T_f8dce_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_f8dce_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_f8dce_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_f8dce_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_f8dce_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f8dce_row0_col0" class="data row0 col0" >the clue</td>
#       <td id="T_f8dce_row0_col1" class="data row0 col1" >Inquiry</td>
#       <td id="T_f8dce_row0_col2" class="data row0 col2" >353</td>
#       <td id="T_f8dce_row0_col3" class="data row0 col3" >613.58</td>
#       <td id="T_f8dce_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row1_col0" class="data row1 col0" >invented</td>
#       <td id="T_f8dce_row1_col1" class="data row1 col1" >Inquiry</td>
#       <td id="T_f8dce_row1_col2" class="data row1 col2" >51</td>
#       <td id="T_f8dce_row1_col3" class="data row1 col3" >88.65</td>
#       <td id="T_f8dce_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row2_col0" class="data row2 col0" >discovered</td>
#       <td id="T_f8dce_row2_col1" class="data row2 col1" >Inquiry</td>
#       <td id="T_f8dce_row2_col2" class="data row2 col2" >46</td>
#       <td id="T_f8dce_row2_col3" class="data row2 col3" >79.96</td>
#       <td id="T_f8dce_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row3_col0" class="data row3 col0" >a famous</td>
#       <td id="T_f8dce_row3_col1" class="data row3 col1" >Inquiry</td>
#       <td id="T_f8dce_row3_col2" class="data row3 col2" >43</td>
#       <td id="T_f8dce_row3_col3" class="data row3 col3" >74.74</td>
#       <td id="T_f8dce_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row4_col0" class="data row4 col0" >explorer</td>
#       <td id="T_f8dce_row4_col1" class="data row4 col1" >Inquiry</td>
#       <td id="T_f8dce_row4_col2" class="data row4 col2" >42</td>
#       <td id="T_f8dce_row4_col3" class="data row4 col3" >73.00</td>
#       <td id="T_f8dce_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row5_col0" class="data row5 col0" >when this</td>
#       <td id="T_f8dce_row5_col1" class="data row5 col1" >Inquiry</td>
#       <td id="T_f8dce_row5_col2" class="data row5 col2" >40</td>
#       <td id="T_f8dce_row5_col3" class="data row5 col3" >69.53</td>
#       <td id="T_f8dce_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row6_col0" class="data row6 col0" >reads the</td>
#       <td id="T_f8dce_row6_col1" class="data row6 col1" >Inquiry</td>
#       <td id="T_f8dce_row6_col2" class="data row6 col2" >35</td>
#       <td id="T_f8dce_row6_col3" class="data row6 col3" >60.84</td>
#       <td id="T_f8dce_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row7_col0" class="data row7 col0" >clue</td>
#       <td id="T_f8dce_row7_col1" class="data row7 col1" >Inquiry</td>
#       <td id="T_f8dce_row7_col2" class="data row7 col2" >30</td>
#       <td id="T_f8dce_row7_col3" class="data row7 col3" >52.15</td>
#       <td id="T_f8dce_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row8_col0" class="data row8 col0" >discovery</td>
#       <td id="T_f8dce_row8_col1" class="data row8 col1" >Inquiry</td>
#       <td id="T_f8dce_row8_col2" class="data row8 col2" >22</td>
#       <td id="T_f8dce_row8_col3" class="data row8 col3" >38.24</td>
#       <td id="T_f8dce_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f8dce_row9_col0" class="data row9 col0" >invention</td>
#       <td id="T_f8dce_row9_col1" class="data row9 col1" >Inquiry</td>
#       <td id="T_f8dce_row9_col2" class="data row9 col2" >21</td>
#       <td id="T_f8dce_row9_col3" class="data row9 col3" >36.50</td>
#       <td id="T_f8dce_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By INFORMATION TOPICS
freq_table_DS.query('Tag.str.startswith("Information Topics")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a384">
#   <thead>
#     <tr>
#       <th id="T_1a384_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_1a384_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_1a384_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_1a384_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_1a384_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1a384_row0_col0" class="data row0 col0" >title</td>
#       <td id="T_1a384_row0_col1" class="data row0 col1" >Information Topics</td>
#       <td id="T_1a384_row0_col2" class="data row0 col2" >470</td>
#       <td id="T_1a384_row0_col3" class="data row0 col3" >816.94</td>
#       <td id="T_1a384_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row1_col0" class="data row1 col0" >name</td>
#       <td id="T_1a384_row1_col1" class="data row1 col1" >Information Topics</td>
#       <td id="T_1a384_row1_col2" class="data row1 col2" >457</td>
#       <td id="T_1a384_row1_col3" class="data row1 col3" >794.35</td>
#       <td id="T_1a384_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row2_col0" class="data row2 col0" >the name</td>
#       <td id="T_1a384_row2_col1" class="data row2 col1" >Information Topics</td>
#       <td id="T_1a384_row2_col2" class="data row2 col2" >273</td>
#       <td id="T_1a384_row2_col3" class="data row2 col3" >474.52</td>
#       <td id="T_1a384_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row3_col0" class="data row3 col0" >group</td>
#       <td id="T_1a384_row3_col1" class="data row3 col1" >Information Topics</td>
#       <td id="T_1a384_row3_col2" class="data row3 col2" >187</td>
#       <td id="T_1a384_row3_col3" class="data row3 col3" >325.04</td>
#       <td id="T_1a384_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row4_col0" class="data row4 col0" >musical</td>
#       <td id="T_1a384_row4_col1" class="data row4 col1" >Information Topics</td>
#       <td id="T_1a384_row4_col2" class="data row4 col2" >177</td>
#       <td id="T_1a384_row4_col3" class="data row4 col3" >307.66</td>
#       <td id="T_1a384_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row5_col0" class="data row5 col0" >capital</td>
#       <td id="T_1a384_row5_col1" class="data row5 col1" >Information Topics</td>
#       <td id="T_1a384_row5_col2" class="data row5 col2" >158</td>
#       <td id="T_1a384_row5_col3" class="data row5 col3" >274.63</td>
#       <td id="T_1a384_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row6_col0" class="data row6 col0" >named</td>
#       <td id="T_1a384_row6_col1" class="data row6 col1" >Information Topics</td>
#       <td id="T_1a384_row6_col2" class="data row6 col2" >148</td>
#       <td id="T_1a384_row6_col3" class="data row6 col3" >257.25</td>
#       <td id="T_1a384_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row7_col0" class="data row7 col0" >series</td>
#       <td id="T_1a384_row7_col1" class="data row7 col1" >Information Topics</td>
#       <td id="T_1a384_row7_col2" class="data row7 col2" >140</td>
#       <td id="T_1a384_row7_col3" class="data row7 col3" >243.34</td>
#       <td id="T_1a384_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row8_col0" class="data row8 col0" >family</td>
#       <td id="T_1a384_row8_col1" class="data row8 col1" >Information Topics</td>
#       <td id="T_1a384_row8_col2" class="data row8 col2" >132</td>
#       <td id="T_1a384_row8_col3" class="data row8 col3" >229.44</td>
#       <td id="T_1a384_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row9_col0" class="data row9 col0" >company</td>
#       <td id="T_1a384_row9_col1" class="data row9 col1" >Information Topics</td>
#       <td id="T_1a384_row9_col2" class="data row9 col2" >131</td>
#       <td id="T_1a384_row9_col3" class="data row9 col3" >227.70</td>
#       <td id="T_1a384_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row10_col0" class="data row10 col0" >other</td>
#       <td id="T_1a384_row10_col1" class="data row10 col1" >Information Topics</td>
#       <td id="T_1a384_row10_col2" class="data row10 col2" >126</td>
#       <td id="T_1a384_row10_col3" class="data row10 col3" >219.01</td>
#       <td id="T_1a384_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row11_col0" class="data row11 col0" >singer</td>
#       <td id="T_1a384_row11_col1" class="data row11 col1" >Information Topics</td>
#       <td id="T_1a384_row11_col2" class="data row11 col2" >115</td>
#       <td id="T_1a384_row11_col3" class="data row11 col3" >199.89</td>
#       <td id="T_1a384_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row12_col0" class="data row12 col0" >house</td>
#       <td id="T_1a384_row12_col1" class="data row12 col1" >Information Topics</td>
#       <td id="T_1a384_row12_col2" class="data row12 col2" >114</td>
#       <td id="T_1a384_row12_col3" class="data row12 col3" >198.15</td>
#       <td id="T_1a384_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row13_col0" class="data row13 col0" >member</td>
#       <td id="T_1a384_row13_col1" class="data row13 col1" >Information Topics</td>
#       <td id="T_1a384_row13_col2" class="data row13 col2" >104</td>
#       <td id="T_1a384_row13_col3" class="data row13 col3" >180.77</td>
#       <td id="T_1a384_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row14_col0" class="data row14 col0" >color</td>
#       <td id="T_1a384_row14_col1" class="data row14 col1" >Information Topics</td>
#       <td id="T_1a384_row14_col2" class="data row14 col2" >100</td>
#       <td id="T_1a384_row14_col3" class="data row14 col3" >173.82</td>
#       <td id="T_1a384_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row15_col0" class="data row15 col0" >brand</td>
#       <td id="T_1a384_row15_col1" class="data row15 col1" >Information Topics</td>
#       <td id="T_1a384_row15_col2" class="data row15 col2" >97</td>
#       <td id="T_1a384_row15_col3" class="data row15 col3" >168.60</td>
#       <td id="T_1a384_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row16_col0" class="data row16 col0" >team</td>
#       <td id="T_1a384_row16_col1" class="data row16 col1" >Information Topics</td>
#       <td id="T_1a384_row16_col2" class="data row16 col2" >87</td>
#       <td id="T_1a384_row16_col3" class="data row16 col3" >151.22</td>
#       <td id="T_1a384_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row17_col0" class="data row17 col0" >last name</td>
#       <td id="T_1a384_row17_col1" class="data row17 col1" >Information Topics</td>
#       <td id="T_1a384_row17_col2" class="data row17 col2" >85</td>
#       <td id="T_1a384_row17_col3" class="data row17 col3" >147.75</td>
#       <td id="T_1a384_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row18_col0" class="data row18 col0" >members</td>
#       <td id="T_1a384_row18_col1" class="data row18 col1" >Information Topics</td>
#       <td id="T_1a384_row18_col2" class="data row18 col2" >82</td>
#       <td id="T_1a384_row18_col3" class="data row18 col3" >142.53</td>
#       <td id="T_1a384_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1a384_row19_col0" class="data row19 col0" >time</td>
#       <td id="T_1a384_row19_col1" class="data row19 col1" >Information Topics</td>
#       <td id="T_1a384_row19_col2" class="data row19 col2" >79</td>
#       <td id="T_1a384_row19_col3" class="data row19 col3" >137.32</td>
#       <td id="T_1a384_row19_col4" class

# %%
# By INFORMATION REPORT VERBS
freq_table_DS.query('Tag.str.startswith("Information Report Verbs")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1d7d9">
#   <thead>
#     <tr>
#       <th id="T_1d7d9_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_1d7d9_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_1d7d9_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_1d7d9_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_1d7d9_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d7d9_row0_col0" class="data row0 col0" >made</td>
#       <td id="T_1d7d9_row0_col1" class="data row0 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row0_col2" class="data row0 col2" >372</td>
#       <td id="T_1d7d9_row0_col3" class="data row0 col3" >646.60</td>
#       <td id="T_1d7d9_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row1_col0" class="data row1 col0" >include</td>
#       <td id="T_1d7d9_row1_col1" class="data row1 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row1_col2" class="data row1 col2" >193</td>
#       <td id="T_1d7d9_row1_col3" class="data row1 col3" >335.47</td>
#       <td id="T_1d7d9_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row2_col0" class="data row2 col0" >make</td>
#       <td id="T_1d7d9_row2_col1" class="data row2 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row2_col2" class="data row2 col2" >166</td>
#       <td id="T_1d7d9_row2_col3" class="data row2 col3" >288.54</td>
#       <td id="T_1d7d9_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row3_col0" class="data row3 col0" >built</td>
#       <td id="T_1d7d9_row3_col1" class="data row3 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row3_col2" class="data row3 col2" >122</td>
#       <td id="T_1d7d9_row3_col3" class="data row3 col3" >212.06</td>
#       <td id="T_1d7d9_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row4_col0" class="data row4 col0" >called the</td>
#       <td id="T_1d7d9_row4_col1" class="data row4 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row4_col2" class="data row4 col2" >116</td>
#       <td id="T_1d7d9_row4_col3" class="data row4 col3" >201.63</td>
#       <td id="T_1d7d9_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row5_col0" class="data row5 col0" >makes</td>
#       <td id="T_1d7d9_row5_col1" class="data row5 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_1d7d9_row5_col3" class="data row5 col3" >173.82</td>
#       <td id="T_1d7d9_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row6_col0" class="data row6 col0" >making</td>
#       <td id="T_1d7d9_row6_col1" class="data row6 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row6_col2" class="data row6 col2" >95</td>
#       <td id="T_1d7d9_row6_col3" class="data row6 col3" >165.13</td>
#       <td id="T_1d7d9_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row7_col0" class="data row7 col0" >including</td>
#       <td id="T_1d7d9_row7_col1" class="data row7 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row7_col2" class="data row7 col2" >87</td>
#       <td id="T_1d7d9_row7_col3" class="data row7 col3" >151.22</td>
#       <td id="T_1d7d9_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row8_col0" class="data row8 col0" >building</td>
#       <td id="T_1d7d9_row8_col1" class="data row8 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row8_col2" class="data row8 col2" >81</td>
#       <td id="T_1d7d9_row8_col3" class="data row8 col3" >140.79</td>
#       <td id="T_1d7d9_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row9_col0" class="data row9 col0" >created</td>
#       <td id="T_1d7d9_row9_col1" class="data row9 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row9_col2" class="data row9 col2" >80</td>
#       <td id="T_1d7d9_row9_col3" class="data row9 col3" >139.05</td>
#       <td id="T_1d7d9_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row10_col0" class="data row10 col0" >reports</td>
#       <td id="T_1d7d9_row10_col1" class="data row10 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row10_col2" class="data row10 col2" >80</td>
#       <td id="T_1d7d9_row10_col3" class="data row10 col3" >139.05</td>
#       <td id="T_1d7d9_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row11_col0" class="data row11 col0" >known as</td>
#       <td id="T_1d7d9_row11_col1" class="data row11 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row11_col2" class="data row11 col2" >71</td>
#       <td id="T_1d7d9_row11_col3" class="data row11 col3" >123.41</td>
#       <td id="T_1d7d9_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row12_col0" class="data row12 col0" >called a</td>
#       <td id="T_1d7d9_row12_col1" class="data row12 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row12_col2" class="data row12 col2" >65</td>
#       <td id="T_1d7d9_row12_col3" class="data row12 col3" >112.98</td>
#       <td id="T_1d7d9_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row13_col0" class="data row13 col0" >included</td>
#       <td id="T_1d7d9_row13_col1" class="data row13 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row13_col2" class="data row13 col2" >58</td>
#       <td id="T_1d7d9_row13_col3" class="data row13 col3" >100.81</td>
#       <td id="T_1d7d9_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row14_col0" class="data row14 col0" >includes</td>
#       <td id="T_1d7d9_row14_col1" class="data row14 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row14_col2" class="data row14 col2" >57</td>
#       <td id="T_1d7d9_row14_col3" class="data row14 col3" >99.08</td>
#       <td id="T_1d7d9_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row15_col0" class="data row15 col0" >sold</td>
#       <td id="T_1d7d9_row15_col1" class="data row15 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row15_col2" class="data row15 col2" >57</td>
#       <td id="T_1d7d9_row15_col3" class="data row15 col3" >99.08</td>
#       <td id="T_1d7d9_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row16_col0" class="data row16 col0" >developed</td>
#       <td id="T_1d7d9_row16_col1" class="data row16 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row16_col2" class="data row16 col2" >52</td>
#       <td id="T_1d7d9_row16_col3" class="data row16 col3" >90.39</td>
#       <td id="T_1d7d9_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row17_col0" class="data row17 col0" >produced</td>
#       <td id="T_1d7d9_row17_col1" class="data row17 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row17_col2" class="data row17 col2" >52</td>
#       <td id="T_1d7d9_row17_col3" class="data row17 col3" >90.39</td>
#       <td id="T_1d7d9_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row18_col0" class="data row18 col0" >refers to</td>
#       <td id="T_1d7d9_row18_col1" class="data row18 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row18_col2" class="data row18 col2" >43</td>
#       <td id="T_1d7d9_row18_col3" class="data row18 col3" >74.74</td>
#       <td id="T_1d7d9_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1d7d9_row19_col0" class="data row19 col0" >selling</td>
#       <td id="T_1d7d9_row19_col1" class="data row19 col1" >Information Report Verbs</td>
#       <td id="T_1d7d9_row19_col2" class="data

# %%
# By INFORMATION CHANGE
freq_table_DS.query('Tag.str.startswith("Information Change")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e8c8">
#   <thead>
#     <tr>
#       <th id="T_9e8c8_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_9e8c8_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_9e8c8_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_9e8c8_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_9e8c8_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9e8c8_row0_col0" class="data row0 col0" >became the</td>
#       <td id="T_9e8c8_row0_col1" class="data row0 col1" >Information Change</td>
#       <td id="T_9e8c8_row0_col2" class="data row0 col2" >131</td>
#       <td id="T_9e8c8_row0_col3" class="data row0 col3" >227.70</td>
#       <td id="T_9e8c8_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row1_col0" class="data row1 col0" >became</td>
#       <td id="T_9e8c8_row1_col1" class="data row1 col1" >Information Change</td>
#       <td id="T_9e8c8_row1_col2" class="data row1 col2" >119</td>
#       <td id="T_9e8c8_row1_col3" class="data row1 col3" >206.84</td>
#       <td id="T_9e8c8_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row2_col0" class="data row2 col0" >death</td>
#       <td id="T_9e8c8_row2_col1" class="data row2 col1" >Information Change Negative</td>
#       <td id="T_9e8c8_row2_col2" class="data row2 col2" >91</td>
#       <td id="T_9e8c8_row2_col3" class="data row2 col3" >158.17</td>
#       <td id="T_9e8c8_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row3_col0" class="data row3 col0" >double</td>
#       <td id="T_9e8c8_row3_col1" class="data row3 col1" >Information Change</td>
#       <td id="T_9e8c8_row3_col2" class="data row3 col2" >66</td>
#       <td id="T_9e8c8_row3_col3" class="data row3 col3" >114.72</td>
#       <td id="T_9e8c8_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row4_col0" class="data row4 col0" >into the</td>
#       <td id="T_9e8c8_row4_col1" class="data row4 col1" >Information Change</td>
#       <td id="T_9e8c8_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_9e8c8_row4_col3" class="data row4 col3" >106.03</td>
#       <td id="T_9e8c8_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row5_col0" class="data row5 col0" >became a</td>
#       <td id="T_9e8c8_row5_col1" class="data row5 col1" >Information Change</td>
#       <td id="T_9e8c8_row5_col2" class="data row5 col2" >60</td>
#       <td id="T_9e8c8_row5_col3" class="data row5 col3" >104.29</td>
#       <td id="T_9e8c8_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row6_col0" class="data row6 col0" >formed</td>
#       <td id="T_9e8c8_row6_col1" class="data row6 col1" >Information Change</td>
#       <td id="T_9e8c8_row6_col2" class="data row6 col2" >60</td>
#       <td id="T_9e8c8_row6_col3" class="data row6 col3" >104.29</td>
#       <td id="T_9e8c8_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row7_col0" class="data row7 col0" >died</td>
#       <td id="T_9e8c8_row7_col1" class="data row7 col1" >Information Change Negative</td>
#       <td id="T_9e8c8_row7_col2" class="data row7 col2" >49</td>
#       <td id="T_9e8c8_row7_col3" class="data row7 col3" >85.17</td>
#       <td id="T_9e8c8_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row8_col0" class="data row8 col0" >into a</td>
#       <td id="T_9e8c8_row8_col1" class="data row8 col1" >Information Change</td>
#       <td id="T_9e8c8_row8_col2" class="data row8 col2" >42</td>
#       <td id="T_9e8c8_row8_col3" class="data row8 col3" >73.00</td>
#       <td id="T_9e8c8_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9e8c8_row9_col0" class="data row9 col0" >become</td>
#       <td id="T_9e8c8_row9_col1" class="data row9 col1" >Information Change</td>
#       <td id="T_9e8c8_row9_col2" class="data row9 col2" >33</td>
#       <td id="T_9e8c8_row9_col3" class="data row9 col3" >57.36</td>
#       <td id="T_9e8c8_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By REASONING
freq_table_DS.query('Tag.str.startswith("Reasoning")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dfacc">
#   <thead>
#     <tr>
#       <th id="T_dfacc_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_dfacc_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_dfacc_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_dfacc_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_dfacc_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dfacc_row0_col0" class="data row0 col0" >because</td>
#       <td id="T_dfacc_row0_col1" class="data row0 col1" >Reasoning</td>
#       <td id="T_dfacc_row0_col2" class="data row0 col2" >109</td>
#       <td id="T_dfacc_row0_col3" class="data row0 col3" >189.46</td>
#       <td id="T_dfacc_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row1_col0" class="data row1 col0" >, so</td>
#       <td id="T_dfacc_row1_col1" class="data row1 col1" >Reasoning</td>
#       <td id="T_dfacc_row1_col2" class="data row1 col2" >66</td>
#       <td id="T_dfacc_row1_col3" class="data row1 col3" >114.72</td>
#       <td id="T_dfacc_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row2_col0" class="data row2 col0" >, for</td>
#       <td id="T_dfacc_row2_col1" class="data row2 col1" >Reasoning</td>
#       <td id="T_dfacc_row2_col2" class="data row2 col2" >52</td>
#       <td id="T_dfacc_row2_col3" class="data row2 col3" >90.39</td>
#       <td id="T_dfacc_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row3_col0" class="data row3 col0" >based on</td>
#       <td id="T_dfacc_row3_col1" class="data row3 col1" >Reasoning</td>
#       <td id="T_dfacc_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_dfacc_row3_col3" class="data row3 col3" >81.69</td>
#       <td id="T_dfacc_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row4_col0" class="data row4 col0" >all the</td>
#       <td id="T_dfacc_row4_col1" class="data row4 col1" >Reasoning</td>
#       <td id="T_dfacc_row4_col2" class="data row4 col2" >42</td>
#       <td id="T_dfacc_row4_col3" class="data row4 col3" >73.00</td>
#       <td id="T_dfacc_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row5_col0" class="data row5 col0" >composed</td>
#       <td id="T_dfacc_row5_col1" class="data row5 col1" >Reasoning</td>
#       <td id="T_dfacc_row5_col2" class="data row5 col2" >42</td>
#       <td id="T_dfacc_row5_col3" class="data row5 col3" >73.00</td>
#       <td id="T_dfacc_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row6_col0" class="data row6 col0" >category</td>
#       <td id="T_dfacc_row6_col1" class="data row6 col1" >Reasoning</td>
#       <td id="T_dfacc_row6_col2" class="data row6 col2" >36</td>
#       <td id="T_dfacc_row6_col3" class="data row6 col3" >62.57</td>
#       <td id="T_dfacc_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row7_col0" class="data row7 col0" >based on a</td>
#       <td id="T_dfacc_row7_col1" class="data row7 col1" >Reasoning</td>
#       <td id="T_dfacc_row7_col2" class="data row7 col2" >35</td>
#       <td id="T_dfacc_row7_col3" class="data row7 col3" >60.84</td>
#       <td id="T_dfacc_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row8_col0" class="data row8 col0" >effect</td>
#       <td id="T_dfacc_row8_col1" class="data row8 col1" >Reasoning</td>
#       <td id="T_dfacc_row8_col2" class="data row8 col2" >29</td>
#       <td id="T_dfacc_row8_col3" class="data row8 col3" >50.41</td>
#       <td id="T_dfacc_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_dfacc_row9_col0" class="data row9 col0" >especially</td>
#       <td id="T_dfacc_row9_col1" class="data row9 col1" >Reasoning</td>
#       <td id="T_dfacc_row9_col2" class="data row9 col2" >29</td>
#       <td id="T_dfacc_row9_col3" class="data row9 col3" >50.41</td>
#       <td id="T_dfacc_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By UNCERTAINTY
freq_table_DS.query('Tag.str.startswith("Uncertainty")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c4be">
#   <thead>
#     <tr>
#       <th id="T_3c4be_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_3c4be_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_3c4be_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_3c4be_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_3c4be_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c4be_row0_col0" class="data row0 col0" >kind of</td>
#       <td id="T_3c4be_row0_col1" class="data row0 col1" >Uncertainty</td>
#       <td id="T_3c4be_row0_col2" class="data row0 col2" >62</td>
#       <td id="T_3c4be_row0_col3" class="data row0 col3" >107.77</td>
#       <td id="T_3c4be_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row1_col0" class="data row1 col0" >whether</td>
#       <td id="T_3c4be_row1_col1" class="data row1 col1" >Uncertainty</td>
#       <td id="T_3c4be_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_3c4be_row1_col3" class="data row1 col3" >41.72</td>
#       <td id="T_3c4be_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row2_col0" class="data row2 col0" >wilder</td>
#       <td id="T_3c4be_row2_col1" class="data row2 col1" >Uncertainty</td>
#       <td id="T_3c4be_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_3c4be_row2_col3" class="data row2 col3" >15.64</td>
#       <td id="T_3c4be_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row3_col0" class="data row3 col0" >about 40</td>
#       <td id="T_3c4be_row3_col1" class="data row3 col1" >Uncertainty</td>
#       <td id="T_3c4be_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_3c4be_row3_col3" class="data row3 col3" >13.91</td>
#       <td id="T_3c4be_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row4_col0" class="data row4 col0" >at about</td>
#       <td id="T_3c4be_row4_col1" class="data row4 col1" >Uncertainty</td>
#       <td id="T_3c4be_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_3c4be_row4_col3" class="data row4 col3" >13.91</td>
#       <td id="T_3c4be_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row5_col0" class="data row5 col0" >about 20</td>
#       <td id="T_3c4be_row5_col1" class="data row5 col1" >Uncertainty</td>
#       <td id="T_3c4be_row5_col2" class="data row5 col2" >7</td>
#       <td id="T_3c4be_row5_col3" class="data row5 col3" >12.17</td>
#       <td id="T_3c4be_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row6_col0" class="data row6 col0" >about 60</td>
#       <td id="T_3c4be_row6_col1" class="data row6 col1" >Uncertainty</td>
#       <td id="T_3c4be_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_3c4be_row6_col3" class="data row6 col3" >12.17</td>
#       <td id="T_3c4be_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row7_col0" class="data row7 col0" >about 10</td>
#       <td id="T_3c4be_row7_col1" class="data row7 col1" >Uncertainty</td>
#       <td id="T_3c4be_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_3c4be_row7_col3" class="data row7 col3" >10.43</td>
#       <td id="T_3c4be_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row8_col0" class="data row8 col0" >about 50</td>
#       <td id="T_3c4be_row8_col1" class="data row8 col1" >Uncertainty</td>
#       <td id="T_3c4be_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_3c4be_row8_col3" class="data row8 col3" >10.43</td>
#       <td id="T_3c4be_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_3c4be_row9_col0" class="data row9 col0" >someone else 's</td>
#       <td id="T_3c4be_row9_col1" class="data row9 col1" >Uncertainty</td>
#       <td id="T_3c4be_row9_col2" class="data row9 col2" >6</td>
#       <td id="T_3c4be_row9_col3" class="data row9 col3" >10.43</td>
#       <td id="T_3c4be_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.3 Tags Frequency Tables

# %% [markdown]
# We can focus on the tag counts by using the `tags_table` function. It works just like the `frequency_table` function, taking a dictionary created by the `convert_corpus` function, an integer against which to normalize, and a `count_by` argument of either `‘pos’` or `‘ds’`.

# %%
tags_freq_table_POS = tags_table(
    tok=tp,
    n_tokens=non_punct,
    count_by='pos'
)

# %%
tags_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cddf5">
#   <thead>
#     <tr>
#       <th id="T_cddf5_level0_col0" class="col_heading level0 col0" >Tag</th>
#       <th id="T_cddf5_level0_col1" class="col_heading level0 col1" >AF</th>
#       <th id="T_cddf5_level0_col2" class="col_heading level0 col2" >RF</th>
#       <th id="T_cddf5_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cddf5_row0_col0" class="data row0 col0" >NN1</td>
#       <td id="T_cddf5_row0_col1" class="data row0 col1" >116736</td>
#       <td id="T_cddf5_row0_col2" class="data row0 col2" >26.11</td>
#       <td id="T_cddf5_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row1_col0" class="data row1 col0" >II</td>
#       <td id="T_cddf5_row1_col1" class="data row1 col1" >35035</td>
#       <td id="T_cddf5_row1_col2" class="data row1 col2" >7.84</td>
#       <td id="T_cddf5_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row2_col0" class="data row2 col0" >JJ</td>
#       <td id="T_cddf5_row2_col1" class="data row2 col1" >29771</td>
#       <td id="T_cddf5_row2_col2" class="data row2 col2" >6.66</td>
#       <td id="T_cddf5_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row3_col0" class="data row3 col0" >AT</td>
#       <td id="T_cddf5_row3_col1" class="data row3 col1" >25620</td>
#       <td id="T_cddf5_row3_col2" class="data row3 col2" >5.73</td>
#       <td id="T_cddf5_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row4_col0" class="data row4 col0" >NN2</td>
#       <td id="T_cddf5_row4_col1" class="data row4 col1" >20337</td>
#       <td id="T_cddf5_row4_col2" class="data row4 col2" >4.55</td>
#       <td id="T_cddf5_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row5_col0" class="data row5 col0" >DD1</td>
#       <td id="T_cddf5_row5_col1" class="data row5 col1" >18706</td>
#       <td id="T_cddf5_row5_col2" class="data row5 col2" >4.18</td>
#       <td id="T_cddf5_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row6_col0" class="data row6 col0" >IO</td>
#       <td id="T_cddf5_row6_col1" class="data row6 col1" >15678</td>
#       <td id="T_cddf5_row6_col2" class="data row6 col2" >3.51</td>
#       <td id="T_cddf5_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row7_col0" class="data row7 col0" >MC</td>
#       <td id="T_cddf5_row7_col1" class="data row7 col1" >15135</td>
#       <td id="T_cddf5_row7_col2" class="data row7 col2" >3.39</td>
#       <td id="T_cddf5_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row8_col0" class="data row8 col0" >AT1</td>
#       <td id="T_cddf5_row8_col1" class="data row8 col1" >14363</td>
#       <td id="T_cddf5_row8_col2" class="data row8 col2" >3.21</td>
#       <td id="T_cddf5_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_cddf5_row9_col0" class="data row9 col0" >VVN</td>
#       <td id="T_cddf5_row9_col1" class="data row9 col1" >11448</td>
#       <td id="T_cddf5_row9_col2" class="data row9 col2" >2.56</td>
#       <td id="T_cddf5_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And by DocuScope category:

# %%
tags_freq_table_DS = tags_table(
    tok=tp,
    n_tokens=corpus_total,
    count_by='ds'
)

# %%
tags_freq_table_DS.sort_values('RF', ascending=False).head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_190cd">
#   <thead>
#     <tr>
#       <th id="T_190cd_level0_col0" class="col_heading level0 col0" >Tag</th>
#       <th id="T_190cd_level0_col1" class="col_heading level0 col1" >AF</th>
#       <th id="T_190cd_level0_col2" class="col_heading level0 col2" >RF</th>
#       <th id="T_190cd_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_190cd_row0_col0" class="data row0 col0" >Description</td>
#       <td id="T_190cd_row0_col1" class="data row0 col1" >52153</td>
#       <td id="T_190cd_row0_col2" class="data row0 col2" >9.07</td>
#       <td id="T_190cd_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row1_col0" class="data row1 col0" >Narrative</td>
#       <td id="T_190cd_row1_col1" class="data row1 col1" >46685</td>
#       <td id="T_190cd_row1_col2" class="data row1 col2" >8.11</td>
#       <td id="T_190cd_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row2_col0" class="data row2 col0" >Character</td>
#       <td id="T_190cd_row2_col1" class="data row2 col1" >39714</td>
#       <td id="T_190cd_row2_col2" class="data row2 col2" >6.90</td>
#       <td id="T_190cd_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row3_col0" class="data row3 col0" >Academic Terms</td>
#       <td id="T_190cd_row3_col1" class="data row3 col1" >17821</td>
#       <td id="T_190cd_row3_col2" class="data row3 col2" >3.10</td>
#       <td id="T_190cd_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row4_col0" class="data row4 col0" >Information Exposition</td>
#       <td id="T_190cd_row4_col1" class="data row4 col1" >12611</td>
#       <td id="T_190cd_row4_col2" class="data row4 col2" >2.19</td>
#       <td id="T_190cd_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row5_col0" class="data row5 col0" >Information Topics</td>
#       <td id="T_190cd_row5_col1" class="data row5 col1" >11763</td>
#       <td id="T_190cd_row5_col2" class="data row5 col2" >2.04</td>
#       <td id="T_190cd_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row6_col0" class="data row6 col0" >Negative</td>
#       <td id="T_190cd_row6_col1" class="data row6 col1" >10008</td>
#       <td id="T_190cd_row6_col2" class="data row6 col2" >1.74</td>
#       <td id="T_190cd_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row7_col0" class="data row7 col0" >Information Place</td>
#       <td id="T_190cd_row7_col1" class="data row7 col1" >9938</td>
#       <td id="T_190cd_row7_col2" class="data row7 col2" >1.73</td>
#       <td id="T_190cd_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row8_col0" class="data row8 col0" >Positive</td>
#       <td id="T_190cd_row8_col1" class="data row8 col1" >8077</td>
#       <td id="T_190cd_row8_col2" class="data row8 col2" >1.40</td>
#       <td id="T_190cd_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_190cd_row9_col0" class="data row9 col0" >Force Stressed</td>
#       <td id="T_190cd_row9_col1" class="data row9 col1" >5885</td>
#       <td id="T_190cd_row9_col2" class="data row9 col2" >1.02</td>
#       <td id="T_190cd_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.4 N-gram Frequency Tables

# %% [markdown]
# Ngrams (between bigrams and 5-grams) can be calculated using the `ngrams_table` function. It works much like the `frequency_table` function but with the addition of a span argument `ng_span` consisting of an integer between 2 and 5.
#
# This will return a table of 3-grams:

# %%
ngram_freq_table_POS = ngrams_table(
    tok=tp,
    ng_span=3,
    n_tokens=non_punct,
    count_by='pos'
)

# %% [markdown]
# The returned data frame includes both the sequence of tokens, as well as the sequence of tags:

# %%
ngram_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_231ca">
#   <thead>
#     <tr>
#       <th id="T_231ca_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_231ca_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_231ca_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_231ca_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_231ca_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_231ca_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_231ca_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_231ca_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_231ca_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_231ca_row0_col0" class="data row0 col0" >it</td>
#       <td id="T_231ca_row0_col1" class="data row0 col1" >'s</td>
#       <td id="T_231ca_row0_col2" class="data row0 col2" >the</td>
#       <td id="T_231ca_row0_col3" class="data row0 col3" >PPH1</td>
#       <td id="T_231ca_row0_col4" class="data row0 col4" >VBZ</td>
#       <td id="T_231ca_row0_col5" class="data row0 col5" >AT</td>
#       <td id="T_231ca_row0_col6" class="data row0 col6" >661</td>
#       <td id="T_231ca_row0_col7" class="data row0 col7" >1478.50</td>
#       <td id="T_231ca_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row1_col0" class="data row1 col0" >of</td>
#       <td id="T_231ca_row1_col1" class="data row1 col1" >the</td>
#       <td id="T_231ca_row1_col2" class="data row1 col2" >clue</td>
#       <td id="T_231ca_row1_col3" class="data row1 col3" >IO</td>
#       <td id="T_231ca_row1_col4" class="data row1 col4" >AT</td>
#       <td id="T_231ca_row1_col5" class="data row1 col5" >NN1</td>
#       <td id="T_231ca_row1_col6" class="data row1 col6" >629</td>
#       <td id="T_231ca_row1_col7" class="data row1 col7" >1406.92</td>
#       <td id="T_231ca_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_231ca_row2_col1" class="data row2 col1" >clue</td>
#       <td id="T_231ca_row2_col2" class="data row2 col2" >crew</td>
#       <td id="T_231ca_row2_col3" class="data row2 col3" >AT</td>
#       <td id="T_231ca_row2_col4" class="data row2 col4" >NN1</td>
#       <td id="T_231ca_row2_col5" class="data row2 col5" >NN1</td>
#       <td id="T_231ca_row2_col6" class="data row2 col6" >627</td>
#       <td id="T_231ca_row2_col7" class="data row2 col7" >1402.45</td>
#       <td id="T_231ca_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row3_col0" class="data row3 col0" >one</td>
#       <td id="T_231ca_row3_col1" class="data row3 col1" >of</td>
#       <td id="T_231ca_row3_col2" class="data row3 col2" >these</td>
#       <td id="T_231ca_row3_col3" class="data row3 col3" >MC1</td>
#       <td id="T_231ca_row3_col4" class="data row3 col4" >IO</td>
#       <td id="T_231ca_row3_col5" class="data row3 col5" >DD2</td>
#       <td id="T_231ca_row3_col6" class="data row3 col6" >462</td>
#       <td id="T_231ca_row3_col7" class="data row3 col7" >1033.38</td>
#       <td id="T_231ca_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row4_col0" class="data row4 col0" >the</td>
#       <td id="T_231ca_row4_col1" class="data row4 col1" >name</td>
#       <td id="T_231ca_row4_col2" class="data row4 col2" >of</td>
#       <td id="T_231ca_row4_col3" class="data row4 col3" >AT</td>
#       <td id="T_231ca_row4_col4" class="data row4 col4" >NN1</td>
#       <td id="T_231ca_row4_col5" class="data row4 col5" >IO</td>
#       <td id="T_231ca_row4_col6" class="data row4 col6" >363</td>
#       <td id="T_231ca_row4_col7" class="data row4 col7" >811.94</td>
#       <td id="T_231ca_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row5_col0" class="data row5 col0" >this</td>
#       <td id="T_231ca_row5_col1" class="data row5 col1" >type</td>
#       <td id="T_231ca_row5_col2" class="data row5 col2" >of</td>
#       <td id="T_231ca_row5_col3" class="data row5 col3" >DD1</td>
#       <td id="T_231ca_row5_col4" class="data row5 col4" >NN1</td>
#       <td id="T_231ca_row5_col5" class="data row5 col5" >IO</td>
#       <td id="T_231ca_row5_col6" class="data row5 col6" >280</td>
#       <td id="T_231ca_row5_col7" class="data row5 col7" >626.29</td>
#       <td id="T_231ca_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row6_col0" class="data row6 col0" >name</td>
#       <td id="T_231ca_row6_col1" class="data row6 col1" >of</td>
#       <td id="T_231ca_row6_col2" class="data row6 col2" >this</td>
#       <td id="T_231ca_row6_col3" class="data row6 col3" >NN1</td>
#       <td id="T_231ca_row6_col4" class="data row6 col4" >IO</td>
#       <td id="T_231ca_row6_col5" class="data row6 col5" >DD1</td>
#       <td id="T_231ca_row6_col6" class="data row6 col6" >267</td>
#       <td id="T_231ca_row6_col7" class="data row6 col7" >597.22</td>
#       <td id="T_231ca_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row7_col0" class="data row7 col0" >it</td>
#       <td id="T_231ca_row7_col1" class="data row7 col1" >'s</td>
#       <td id="T_231ca_row7_col2" class="data row7 col2" >a</td>
#       <td id="T_231ca_row7_col3" class="data row7 col3" >PPH1</td>
#       <td id="T_231ca_row7_col4" class="data row7 col4" >VBZ</td>
#       <td id="T_231ca_row7_col5" class="data row7 col5" >AT1</td>
#       <td id="T_231ca_row7_col6" class="data row7 col6" >262</td>
#       <td id="T_231ca_row7_col7" class="data row7 col7" >586.03</td>
#       <td id="T_231ca_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row8_col0" class="data row8 col0" >one</td>
#       <td id="T_231ca_row8_col1" class="data row8 col1" >of</td>
#       <td id="T_231ca_row8_col2" class="data row8 col2" >the</td>
#       <td id="T_231ca_row8_col3" class="data row8 col3" >MC1</td>
#       <td id="T_231ca_row8_col4" class="data row8 col4" >IO</td>
#       <td id="T_231ca_row8_col5" class="data row8 col5" >AT</td>
#       <td id="T_231ca_row8_col6" class="data row8 col6" >238</td>
#       <td id="T_231ca_row8_col7" class="data row8 col7" >532.35</td>
#       <td id="T_231ca_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_231ca_row9_col0" class="data row9 col0" >it</td>
#       <td id="T_231ca_row9_col1" class="data row9 col1" >s</td>
#       <td id="T_231ca_row9_col2" class="data row9 col2" >name</td>
#       <td id="T_231ca_row9_col3" class="data row9 col3" >PPH1</td>
#       <td id="T_231ca_row9_col4" class="data row9 col4" >GE</td>
#       <td id="T_231ca_row9_col5" class="data row9 col5" >NN1</td>
#       <td id="T_231ca_row9_col6" class="data row9 col6" >203</td>
#       <td id="T_231ca_row9_col7" class="data row9 col7" >454.06</td>
#       <td id="T_231ca_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we can filter ngrams that, for example, start with a verb:

# %%
ngram_freq_table_POS.query('Tag1.str.startswith("V")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8390e">
#   <thead>
#     <tr>
#       <th id="T_8390e_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_8390e_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_8390e_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_8390e_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_8390e_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_8390e_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_8390e_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_8390e_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_8390e_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8390e_row0_col0" class="data row0 col0" >named</td>
#       <td id="T_8390e_row0_col1" class="data row0 col1" >for</td>
#       <td id="T_8390e_row0_col2" class="data row0 col2" >this</td>
#       <td id="T_8390e_row0_col3" class="data row0 col3" >VVN</td>
#       <td id="T_8390e_row0_col4" class="data row0 col4" >IF</td>
#       <td id="T_8390e_row0_col5" class="data row0 col5" >DD1</td>
#       <td id="T_8390e_row0_col6" class="data row0 col6" >150</td>
#       <td id="T_8390e_row0_col7" class="data row0 col7" >335.51</td>
#       <td id="T_8390e_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row1_col0" class="data row1 col0" >named</td>
#       <td id="T_8390e_row1_col1" class="data row1 col1" >for</td>
#       <td id="T_8390e_row1_col2" class="data row1 col2" >a</td>
#       <td id="T_8390e_row1_col3" class="data row1 col3" >VVN</td>
#       <td id="T_8390e_row1_col4" class="data row1 col4" >IF</td>
#       <td id="T_8390e_row1_col5" class="data row1 col5" >AT1</td>
#       <td id="T_8390e_row1_col6" class="data row1 col6" >126</td>
#       <td id="T_8390e_row1_col7" class="data row1 col7" >281.83</td>
#       <td id="T_8390e_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row2_col0" class="data row2 col0" >is</td>
#       <td id="T_8390e_row2_col1" class="data row2 col1" >named</td>
#       <td id="T_8390e_row2_col2" class="data row2 col2" >for</td>
#       <td id="T_8390e_row2_col3" class="data row2 col3" >VBZ</td>
#       <td id="T_8390e_row2_col4" class="data row2 col4" >VVN</td>
#       <td id="T_8390e_row2_col5" class="data row2 col5" >IF</td>
#       <td id="T_8390e_row2_col6" class="data row2 col6" >124</td>
#       <td id="T_8390e_row2_col7" class="data row2 col7" >277.36</td>
#       <td id="T_8390e_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row3_col0" class="data row3 col0" >was</td>
#       <td id="T_8390e_row3_col1" class="data row3 col1" >the</td>
#       <td id="T_8390e_row3_col2" class="data row3 col2" >first</td>
#       <td id="T_8390e_row3_col3" class="data row3 col3" >VBDZ</td>
#       <td id="T_8390e_row3_col4" class="data row3 col4" >AT</td>
#       <td id="T_8390e_row3_col5" class="data row3 col5" >MD</td>
#       <td id="T_8390e_row3_col6" class="data row3 col6" >122</td>
#       <td id="T_8390e_row3_col7" class="data row3 col7" >272.88</td>
#       <td id="T_8390e_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row4_col0" class="data row4 col0" >became</td>
#       <td id="T_8390e_row4_col1" class="data row4 col1" >the</td>
#       <td id="T_8390e_row4_col2" class="data row4 col2" >first</td>
#       <td id="T_8390e_row4_col3" class="data row4 col3" >VVD</td>
#       <td id="T_8390e_row4_col4" class="data row4 col4" >AT</td>
#       <td id="T_8390e_row4_col5" class="data row4 col5" >MD</td>
#       <td id="T_8390e_row4_col6" class="data row4 col6" >115</td>
#       <td id="T_8390e_row4_col7" class="data row4 col7" >257.23</td>
#       <td id="T_8390e_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row5_col0" class="data row5 col0" >known</td>
#       <td id="T_8390e_row5_col1" class="data row5 col1" >as</td>
#       <td id="T_8390e_row5_col2" class="data row5 col2" >the</td>
#       <td id="T_8390e_row5_col3" class="data row5 col3" >VVN</td>
#       <td id="T_8390e_row5_col4" class="data row5 col4" >II</td>
#       <td id="T_8390e_row5_col5" class="data row5 col5" >AT</td>
#       <td id="T_8390e_row5_col6" class="data row5 col6" >115</td>
#       <td id="T_8390e_row5_col7" class="data row5 col7" >257.23</td>
#       <td id="T_8390e_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row6_col0" class="data row6 col0" >comes</td>
#       <td id="T_8390e_row6_col1" class="data row6 col1" >from</td>
#       <td id="T_8390e_row6_col2" class="data row6 col2" >the</td>
#       <td id="T_8390e_row6_col3" class="data row6 col3" >VVZ</td>
#       <td id="T_8390e_row6_col4" class="data row6 col4" >II</td>
#       <td id="T_8390e_row6_col5" class="data row6 col5" >AT</td>
#       <td id="T_8390e_row6_col6" class="data row6 col6" >89</td>
#       <td id="T_8390e_row6_col7" class="data row6 col7" >199.07</td>
#       <td id="T_8390e_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row7_col0" class="data row7 col0" >is</td>
#       <td id="T_8390e_row7_col1" class="data row7 col1" >one</td>
#       <td id="T_8390e_row7_col2" class="data row7 col2" >of</td>
#       <td id="T_8390e_row7_col3" class="data row7 col3" >VBZ</td>
#       <td id="T_8390e_row7_col4" class="data row7 col4" >MC1</td>
#       <td id="T_8390e_row7_col5" class="data row7 col5" >IO</td>
#       <td id="T_8390e_row7_col6" class="data row7 col6" >88</td>
#       <td id="T_8390e_row7_col7" class="data row7 col7" >196.83</td>
#       <td id="T_8390e_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row8_col0" class="data row8 col0" >was</td>
#       <td id="T_8390e_row8_col1" class="data row8 col1" >named</td>
#       <td id="T_8390e_row8_col2" class="data row8 col2" >for</td>
#       <td id="T_8390e_row8_col3" class="data row8 col3" >VBDZ</td>
#       <td id="T_8390e_row8_col4" class="data row8 col4" >VVN</td>
#       <td id="T_8390e_row8_col5" class="data row8 col5" >IF</td>
#       <td id="T_8390e_row8_col6" class="data row8 col6" >81</td>
#       <td id="T_8390e_row8_col7" class="data row8 col7" >181.18</td>
#       <td id="T_8390e_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row9_col0" class="data row9 col0" >was</td>
#       <td id="T_8390e_row9_col1" class="data row9 col1" >born</td>
#       <td id="T_8390e_row9_col2" class="data row9 col2" >in</td>
#       <td id="T_8390e_row9_col3" class="data row9 col3" >VBDZ</td>
#       <td id="T_8390e_row9_col4" class="data row9 col4" >VVN</td>
#       <td id="T_8390e_row9_col5" class="data row9 col5" >II</td>
#       <td id="T_8390e_row9_col6" class="data row9 col6" >79</td>
#       <td id="T_8390e_row9_col7" class="data row9 col7" >176.70</td>
#       <td id="T_8390e_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row10_col0" class="data row10 col0" >named</td>
#       <td id="T_8390e_row10_col1" class="data row10 col1" >for</td>
#       <td id="T_8390e_row10_col2" class="data row10 col2" >the</td>
#       <td id="T_8390e_row10_col3" class="data row10 col3" >VVN</td>
#       <td id="T_8390e_row10_col4" class="data row10 col4" >IF</td>
#       <td id="T_8390e_row10_col5" class="data row10 col5" >AT</td>
#       <td id="T_8390e_row10_col6" class="data row10 col6" >74</td>
#       <td id="T_8390e_row10_col7" class="data row10 col7" >165.52</td>
#       <td id="T_8390e_row10_col8" class="data row10 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8390e_row11_col0" class="data row11 col0" >delivers</td>
#       <td id="T_8390e_row11_col1" class="data row11 col1" >the</td>
#       <td id="T_8390e_row11_col2" class="data row11 col2" >clue</td>
#       <td id="T_8390e_row11_col3" class="data row11 col3" >VVZ</td>
#       <td id="T_8390e_row11_col4" class="data row11 col4" >AT</td>
#       <td i

# %% [markdown]
# Or sequences that end with a *past participle* (‘VVN’) preceded by a *to be verb* (‘VB’), thus showing passive constructions:

# %%
ngram_freq_table_POS.query('Tag3.str.startswith("VVN") and Tag2.str.startswith("VB")').head(15).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3c46">
#   <thead>
#     <tr>
#       <th id="T_f3c46_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_f3c46_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_f3c46_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_f3c46_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_f3c46_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_f3c46_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_f3c46_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_f3c46_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_f3c46_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3c46_row0_col0" class="data row0 col0" >he</td>
#       <td id="T_f3c46_row0_col1" class="data row0 col1" >was</td>
#       <td id="T_f3c46_row0_col2" class="data row0 col2" >born</td>
#       <td id="T_f3c46_row0_col3" class="data row0 col3" >PPHS1</td>
#       <td id="T_f3c46_row0_col4" class="data row0 col4" >VBDZ</td>
#       <td id="T_f3c46_row0_col5" class="data row0 col5" >VVN</td>
#       <td id="T_f3c46_row0_col6" class="data row0 col6" >22</td>
#       <td id="T_f3c46_row0_col7" class="data row0 col7" >49.21</td>
#       <td id="T_f3c46_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row1_col0" class="data row1 col0" >has</td>
#       <td id="T_f3c46_row1_col1" class="data row1 col1" >been</td>
#       <td id="T_f3c46_row1_col2" class="data row1 col2" >called</td>
#       <td id="T_f3c46_row1_col3" class="data row1 col3" >VHZ</td>
#       <td id="T_f3c46_row1_col4" class="data row1 col4" >VBN</td>
#       <td id="T_f3c46_row1_col5" class="data row1 col5" >VVN</td>
#       <td id="T_f3c46_row1_col6" class="data row1 col6" >14</td>
#       <td id="T_f3c46_row1_col7" class="data row1 col7" >31.31</td>
#       <td id="T_f3c46_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row2_col0" class="data row2 col0" >it</td>
#       <td id="T_f3c46_row2_col1" class="data row2 col1" >'s</td>
#       <td id="T_f3c46_row2_col2" class="data row2 col2" >said</td>
#       <td id="T_f3c46_row2_col3" class="data row2 col3" >PPH1</td>
#       <td id="T_f3c46_row2_col4" class="data row2 col4" >VBZ</td>
#       <td id="T_f3c46_row2_col5" class="data row2 col5" >VVN</td>
#       <td id="T_f3c46_row2_col6" class="data row2 col6" >14</td>
#       <td id="T_f3c46_row2_col7" class="data row2 col7" >31.31</td>
#       <td id="T_f3c46_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row3_col0" class="data row3 col0" >it</td>
#       <td id="T_f3c46_row3_col1" class="data row3 col1" >was</td>
#       <td id="T_f3c46_row3_col2" class="data row3 col2" >named</td>
#       <td id="T_f3c46_row3_col3" class="data row3 col3" >PPH1</td>
#       <td id="T_f3c46_row3_col4" class="data row3 col4" >VBDZ</td>
#       <td id="T_f3c46_row3_col5" class="data row3 col5" >VVN</td>
#       <td id="T_f3c46_row3_col6" class="data row3 col6" >14</td>
#       <td id="T_f3c46_row3_col7" class="data row3 col7" >31.31</td>
#       <td id="T_f3c46_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row4_col0" class="data row4 col0" >can</td>
#       <td id="T_f3c46_row4_col1" class="data row4 col1" >be</td>
#       <td id="T_f3c46_row4_col2" class="data row4 col2" >used</td>
#       <td id="T_f3c46_row4_col3" class="data row4 col3" >VM</td>
#       <td id="T_f3c46_row4_col4" class="data row4 col4" >VBI</td>
#       <td id="T_f3c46_row4_col5" class="data row4 col5" >VVN</td>
#       <td id="T_f3c46_row4_col6" class="data row4 col6" >12</td>
#       <td id="T_f3c46_row4_col7" class="data row4 col7" >26.84</td>
#       <td id="T_f3c46_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row5_col0" class="data row5 col0" >it</td>
#       <td id="T_f3c46_row5_col1" class="data row5 col1" >'s</td>
#       <td id="T_f3c46_row5_col2" class="data row5 col2" >known</td>
#       <td id="T_f3c46_row5_col3" class="data row5 col3" >PPH1</td>
#       <td id="T_f3c46_row5_col4" class="data row5 col4" >VBZ</td>
#       <td id="T_f3c46_row5_col5" class="data row5 col5" >VVN</td>
#       <td id="T_f3c46_row5_col6" class="data row5 col6" >12</td>
#       <td id="T_f3c46_row5_col7" class="data row5 col7" >26.84</td>
#       <td id="T_f3c46_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row6_col0" class="data row6 col0" >who</td>
#       <td id="T_f3c46_row6_col1" class="data row6 col1" >was</td>
#       <td id="T_f3c46_row6_col2" class="data row6 col2" >born</td>
#       <td id="T_f3c46_row6_col3" class="data row6 col3" >PNQS</td>
#       <td id="T_f3c46_row6_col4" class="data row6 col4" >VBDZ</td>
#       <td id="T_f3c46_row6_col5" class="data row6 col5" >VVN</td>
#       <td id="T_f3c46_row6_col6" class="data row6 col6" >9</td>
#       <td id="T_f3c46_row6_col7" class="data row6 col7" >20.13</td>
#       <td id="T_f3c46_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row7_col0" class="data row7 col0" >can</td>
#       <td id="T_f3c46_row7_col1" class="data row7 col1" >be</td>
#       <td id="T_f3c46_row7_col2" class="data row7 col2" >found</td>
#       <td id="T_f3c46_row7_col3" class="data row7 col3" >VM</td>
#       <td id="T_f3c46_row7_col4" class="data row7 col4" >VBI</td>
#       <td id="T_f3c46_row7_col5" class="data row7 col5" >VVN</td>
#       <td id="T_f3c46_row7_col6" class="data row7 col6" >8</td>
#       <td id="T_f3c46_row7_col7" class="data row7 col7" >17.89</td>
#       <td id="T_f3c46_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row8_col0" class="data row8 col0" >he</td>
#       <td id="T_f3c46_row8_col1" class="data row8 col1" >was</td>
#       <td id="T_f3c46_row8_col2" class="data row8 col2" >elected</td>
#       <td id="T_f3c46_row8_col3" class="data row8 col3" >PPHS1</td>
#       <td id="T_f3c46_row8_col4" class="data row8 col4" >VBDZ</td>
#       <td id="T_f3c46_row8_col5" class="data row8 col5" >VVN</td>
#       <td id="T_f3c46_row8_col6" class="data row8 col6" >8</td>
#       <td id="T_f3c46_row8_col7" class="data row8 col7" >17.89</td>
#       <td id="T_f3c46_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row9_col0" class="data row9 col0" >in</td>
#       <td id="T_f3c46_row9_col1" class="data row9 col1" >was</td>
#       <td id="T_f3c46_row9_col2" class="data row9 col2" >named</td>
#       <td id="T_f3c46_row9_col3" class="data row9 col3" >II</td>
#       <td id="T_f3c46_row9_col4" class="data row9 col4" >VBDZ</td>
#       <td id="T_f3c46_row9_col5" class="data row9 col5" >VVN</td>
#       <td id="T_f3c46_row9_col6" class="data row9 col6" >8</td>
#       <td id="T_f3c46_row9_col7" class="data row9 col7" >17.89</td>
#       <td id="T_f3c46_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row10_col0" class="data row10 col0" >it</td>
#       <td id="T_f3c46_row10_col1" class="data row10 col1" >'s</td>
#       <td id="T_f3c46_row10_col2" class="data row10 col2" >made</td>
#       <td id="T_f3c46_row10_col3" class="data row10 col3" >PPH1</td>
#       <td id="T_f3c46_row10_col4" class="data row10 col4" >VBZ</td>
#       <td id="T_f3c46_row10_col5" class="data row10 col5" >VVN</td>
#       <td id="T_f3c46_row10_col6" class="data row10 col6" >8</td>
#       <td id="T_f3c46_row10_col7" class="data row10 col7" >17.89</td>
#       <td id="T_f3c46_row10_col8" class="data row10 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_f3c46_row11_col0" class="data row11 col0" >to</td>
#       <td id="T_f3c46_row11_col1" class="data row11 col1" >be</td>
#       <td id="T_f3c46_row11_col2" class="data row11 col2" >called</td>
#       <td id="T_f3c46_row11_col3" class="data row11 col3" >TO</td>
#       <td id="T_f3c46_row11_col4" class="data row11 col4" >VBI</td>
#       <td id="T_f3c46_

# %% [markdown]
# Similar ngram tables can be created for DocuScope sequences. Here we generate trigrams again:

# %%
ngram_freq_table_DS = ngrams_table(
    tok=tp,
    ng_span=3,
    n_tokens=corpus_total,
    count_by='ds'
)

# %%
ngram_freq_table_DS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15a07">
#   <thead>
#     <tr>
#       <th id="T_15a07_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_15a07_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_15a07_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_15a07_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_15a07_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_15a07_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_15a07_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_15a07_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_15a07_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15a07_row0_col0" class="data row0 col0" >one</td>
#       <td id="T_15a07_row0_col1" class="data row0 col1" >of</td>
#       <td id="T_15a07_row0_col2" class="data row0 col2" >these</td>
#       <td id="T_15a07_row0_col3" class="data row0 col3" >Untagged</td>
#       <td id="T_15a07_row0_col4" class="data row0 col4" >Untagged</td>
#       <td id="T_15a07_row0_col5" class="data row0 col5" >Untagged</td>
#       <td id="T_15a07_row0_col6" class="data row0 col6" >351</td>
#       <td id="T_15a07_row0_col7" class="data row0 col7" >610.10</td>
#       <td id="T_15a07_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row1_col0" class="data row1 col0" >of</td>
#       <td id="T_15a07_row1_col1" class="data row1 col1" >the clue</td>
#       <td id="T_15a07_row1_col2" class="data row1 col2" >crew</td>
#       <td id="T_15a07_row1_col3" class="data row1 col3" >Untagged</td>
#       <td id="T_15a07_row1_col4" class="data row1 col4" >Inquiry</td>
#       <td id="T_15a07_row1_col5" class="data row1 col5" >Character</td>
#       <td id="T_15a07_row1_col6" class="data row1 col6" >276</td>
#       <td id="T_15a07_row1_col7" class="data row1 col7" >479.74</td>
#       <td id="T_15a07_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row2_col0" class="data row2 col0" >the name</td>
#       <td id="T_15a07_row2_col1" class="data row2 col1" >of</td>
#       <td id="T_15a07_row2_col2" class="data row2 col2" >this</td>
#       <td id="T_15a07_row2_col3" class="data row2 col3" >InformationTopics</td>
#       <td id="T_15a07_row2_col4" class="data row2 col4" >Untagged</td>
#       <td id="T_15a07_row2_col5" class="data row2 col5" >Narrative</td>
#       <td id="T_15a07_row2_col6" class="data row2 col6" >188</td>
#       <td id="T_15a07_row2_col7" class="data row2 col7" >326.78</td>
#       <td id="T_15a07_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row3_col0" class="data row3 col0" >of</td>
#       <td id="T_15a07_row3_col1" class="data row3 col1" >the</td>
#       <td id="T_15a07_row3_col2" class="data row3 col2" >clue crew</td>
#       <td id="T_15a07_row3_col3" class="data row3 col3" >Untagged</td>
#       <td id="T_15a07_row3_col4" class="data row3 col4" >Untagged</td>
#       <td id="T_15a07_row3_col5" class="data row3 col5" >Character</td>
#       <td id="T_15a07_row3_col6" class="data row3 col6" >176</td>
#       <td id="T_15a07_row3_col7" class="data row3 col7" >305.92</td>
#       <td id="T_15a07_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row4_col0" class="data row4 col0" >of</td>
#       <td id="T_15a07_row4_col1" class="data row4 col1" >the</td>
#       <td id="T_15a07_row4_col2" class="data row4 col2" >clue</td>
#       <td id="T_15a07_row4_col3" class="data row4 col3" >Untagged</td>
#       <td id="T_15a07_row4_col4" class="data row4 col4" >Untagged</td>
#       <td id="T_15a07_row4_col5" class="data row4 col5" >Untagged</td>
#       <td id="T_15a07_row4_col6" class="data row4 col6" >173</td>
#       <td id="T_15a07_row4_col7" class="data row4 col7" >300.70</td>
#       <td id="T_15a07_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row5_col0" class="data row5 col0" >sarah</td>
#       <td id="T_15a07_row5_col1" class="data row5 col1" >of</td>
#       <td id="T_15a07_row5_col2" class="data row5 col2" >the</td>
#       <td id="T_15a07_row5_col3" class="data row5 col3" >Character</td>
#       <td id="T_15a07_row5_col4" class="data row5 col4" >Untagged</td>
#       <td id="T_15a07_row5_col5" class="data row5 col5" >Untagged</td>
#       <td id="T_15a07_row5_col6" class="data row5 col6" >173</td>
#       <td id="T_15a07_row5_col7" class="data row5 col7" >300.70</td>
#       <td id="T_15a07_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row6_col0" class="data row6 col0" >the</td>
#       <td id="T_15a07_row6_col1" class="data row6 col1" >clue</td>
#       <td id="T_15a07_row6_col2" class="data row6 col2" >crew</td>
#       <td id="T_15a07_row6_col3" class="data row6 col3" >Untagged</td>
#       <td id="T_15a07_row6_col4" class="data row6 col4" >Untagged</td>
#       <td id="T_15a07_row6_col5" class="data row6 col5" >Character</td>
#       <td id="T_15a07_row6_col6" class="data row6 col6" >169</td>
#       <td id="T_15a07_row6_col7" class="data row6 col7" >293.75</td>
#       <td id="T_15a07_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row7_col0" class="data row7 col0" >jimmy</td>
#       <td id="T_15a07_row7_col1" class="data row7 col1" >of</td>
#       <td id="T_15a07_row7_col2" class="data row7 col2" >the clue</td>
#       <td id="T_15a07_row7_col3" class="data row7 col3" >Character</td>
#       <td id="T_15a07_row7_col4" class="data row7 col4" >Untagged</td>
#       <td id="T_15a07_row7_col5" class="data row7 col5" >Inquiry</td>
#       <td id="T_15a07_row7_col6" class="data row7 col6" >157</td>
#       <td id="T_15a07_row7_col7" class="data row7 col7" >272.89</td>
#       <td id="T_15a07_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row8_col0" class="data row8 col0" >one</td>
#       <td id="T_15a07_row8_col1" class="data row8 col1" >of</td>
#       <td id="T_15a07_row8_col2" class="data row8 col2" >the</td>
#       <td id="T_15a07_row8_col3" class="data row8 col3" >Untagged</td>
#       <td id="T_15a07_row8_col4" class="data row8 col4" >Untagged</td>
#       <td id="T_15a07_row8_col5" class="data row8 col5" >Untagged</td>
#       <td id="T_15a07_row8_col6" class="data row8 col6" >154</td>
#       <td id="T_15a07_row8_col7" class="data row8 col7" >267.68</td>
#       <td id="T_15a07_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_15a07_row9_col0" class="data row9 col0" >the</td>
#       <td id="T_15a07_row9_col1" class="data row9 col1" >latin</td>
#       <td id="T_15a07_row9_col2" class="data row9 col2" >for "</td>
#       <td id="T_15a07_row9_col3" class="data row9 col3" >Untagged</td>
#       <td id="T_15a07_row9_col4" class="data row9 col4" >AcademicTerms</td>
#       <td id="T_15a07_row9_col5" class="data row9 col5" >Citation</td>
#       <td id="T_15a07_row9_col6" class="data row9 col6" >113</td>
#       <td id="T_15a07_row9_col7" class="data row9 col7" >196.41</td>
#       <td id="T_15a07_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's find a sequence tagged as ‘Positive’ on the right and on the left we filter out Untagged (‘O’) and ‘Syntactic Complexity’:

# %%
ngram_freq_table_DS.query('Tag1.str.startswith("Positive") and (~Tag2.str.startswith("Syntactic") and ~Tag2.str.startswith("Untagged") and ~Tag3.str.startswith("Untagged"))').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9f45">
#   <thead>
#     <tr>
#       <th id="T_a9f45_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_a9f45_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_a9f45_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_a9f45_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_a9f45_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_a9f45_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_a9f45_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_a9f45_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_a9f45_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9f45_row0_col0" class="data row0 col0" >nobel</td>
#       <td id="T_a9f45_row0_col1" class="data row0 col1" >prize</td>
#       <td id="T_a9f45_row0_col2" class="data row0 col2" >winner</td>
#       <td id="T_a9f45_row0_col3" class="data row0 col3" >Positive</td>
#       <td id="T_a9f45_row0_col4" class="data row0 col4" >Positive</td>
#       <td id="T_a9f45_row0_col5" class="data row0 col5" >Positive</td>
#       <td id="T_a9f45_row0_col6" class="data row0 col6" >7</td>
#       <td id="T_a9f45_row0_col7" class="data row0 col7" >12.17</td>
#       <td id="T_a9f45_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row1_col0" class="data row1 col0" >nobel</td>
#       <td id="T_a9f45_row1_col1" class="data row1 col1" >peace</td>
#       <td id="T_a9f45_row1_col2" class="data row1 col2" >prize</td>
#       <td id="T_a9f45_row1_col3" class="data row1 col3" >Positive</td>
#       <td id="T_a9f45_row1_col4" class="data row1 col4" >Positive</td>
#       <td id="T_a9f45_row1_col5" class="data row1 col5" >Positive</td>
#       <td id="T_a9f45_row1_col6" class="data row1 col6" >6</td>
#       <td id="T_a9f45_row1_col7" class="data row1 col7" >10.43</td>
#       <td id="T_a9f45_row1_col8" class="data row1 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row2_col0" class="data row2 col0" >best</td>
#       <td id="T_a9f45_row2_col1" class="data row2 col1" >actor</td>
#       <td id="T_a9f45_row2_col2" class="data row2 col2" >oscar</td>
#       <td id="T_a9f45_row2_col3" class="data row2 col3" >Positive</td>
#       <td id="T_a9f45_row2_col4" class="data row2 col4" >Character</td>
#       <td id="T_a9f45_row2_col5" class="data row2 col5" >Character</td>
#       <td id="T_a9f45_row2_col6" class="data row2 col6" >4</td>
#       <td id="T_a9f45_row2_col7" class="data row2 col7" >6.95</td>
#       <td id="T_a9f45_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row3_col0" class="data row3 col0" >best</td>
#       <td id="T_a9f45_row3_col1" class="data row3 col1" >picture</td>
#       <td id="T_a9f45_row3_col2" class="data row3 col2" >oscar</td>
#       <td id="T_a9f45_row3_col3" class="data row3 col3" >Positive</td>
#       <td id="T_a9f45_row3_col4" class="data row3 col4" >Description</td>
#       <td id="T_a9f45_row3_col5" class="data row3 col5" >Character</td>
#       <td id="T_a9f45_row3_col6" class="data row3 col6" >4</td>
#       <td id="T_a9f45_row3_col7" class="data row3 col7" >6.95</td>
#       <td id="T_a9f45_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row4_col0" class="data row4 col0" >founded</td>
#       <td id="T_a9f45_row4_col1" class="data row4 col1" >this</td>
#       <td id="T_a9f45_row4_col2" class="data row4 col2" >city</td>
#       <td id="T_a9f45_row4_col3" class="data row4 col3" >Positive</td>
#       <td id="T_a9f45_row4_col4" class="data row4 col4" >Narrative</td>
#       <td id="T_a9f45_row4_col5" class="data row4 col5" >InformationPlace</td>
#       <td id="T_a9f45_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_a9f45_row4_col7" class="data row4 col7" >6.95</td>
#       <td id="T_a9f45_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row5_col0" class="data row5 col0" >kiss</td>
#       <td id="T_a9f45_row5_col1" class="data row5 col1" >me</td>
#       <td id="T_a9f45_row5_col2" class="data row5 col2" >kate</td>
#       <td id="T_a9f45_row5_col3" class="data row5 col3" >Positive</td>
#       <td id="T_a9f45_row5_col4" class="data row5 col4" >FirstPerson</td>
#       <td id="T_a9f45_row5_col5" class="data row5 col5" >Character</td>
#       <td id="T_a9f45_row5_col6" class="data row5 col6" >4</td>
#       <td id="T_a9f45_row5_col7" class="data row5 col7" >6.95</td>
#       <td id="T_a9f45_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row6_col0" class="data row6 col0" >the nobel</td>
#       <td id="T_a9f45_row6_col1" class="data row6 col1" >peace</td>
#       <td id="T_a9f45_row6_col2" class="data row6 col2" >prize</td>
#       <td id="T_a9f45_row6_col3" class="data row6 col3" >Positive</td>
#       <td id="T_a9f45_row6_col4" class="data row6 col4" >Positive</td>
#       <td id="T_a9f45_row6_col5" class="data row6 col5" >Positive</td>
#       <td id="T_a9f45_row6_col6" class="data row6 col6" >4</td>
#       <td id="T_a9f45_row6_col7" class="data row6 col7" >6.95</td>
#       <td id="T_a9f45_row6_col8" class="data row6 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row7_col0" class="data row7 col0" >founded</td>
#       <td id="T_a9f45_row7_col1" class="data row7 col1" >this</td>
#       <td id="T_a9f45_row7_col2" class="data row7 col2" >organization</td>
#       <td id="T_a9f45_row7_col3" class="data row7 col3" >Positive</td>
#       <td id="T_a9f45_row7_col4" class="data row7 col4" >Narrative</td>
#       <td id="T_a9f45_row7_col5" class="data row7 col5" >PublicTerms</td>
#       <td id="T_a9f45_row7_col6" class="data row7 col6" >3</td>
#       <td id="T_a9f45_row7_col7" class="data row7 col7" >5.21</td>
#       <td id="T_a9f45_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row8_col0" class="data row8 col0" >awards</td>
#       <td id="T_a9f45_row8_col1" class="data row8 col1" >" when</td>
#       <td id="T_a9f45_row8_col2" class="data row8 col2" >this</td>
#       <td id="T_a9f45_row8_col3" class="data row8 col3" >Positive</td>
#       <td id="T_a9f45_row8_col4" class="data row8 col4" >Character</td>
#       <td id="T_a9f45_row8_col5" class="data row8 col5" >Narrative</td>
#       <td id="T_a9f45_row8_col6" class="data row8 col6" >2</td>
#       <td id="T_a9f45_row8_col7" class="data row8 col7" >3.48</td>
#       <td id="T_a9f45_row8_col8" class="data row8 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_a9f45_row9_col0" class="data row9 col0" >best</td>
#       <td id="T_a9f45_row9_col1" class="data row9 col1" >actor</td>
#       <td id="T_a9f45_row9_col2" class="data row9 col2" >winner</td>
#       <td id="T_a9f45_row9_col3" class="data row9 col3" >Positive</td>
#       <td id="T_a9f45_row9_col4" class="data row9 col4" >Character</td>
#       <td id="T_a9f45_row9_col5" class="data row9 col5" >Positive</td>
#       <td id="T_a9f45_row9_col6" class="data row9 col6" >2</td>
#       <td id="T_a9f45_row9_col7" class="data row9 col7" >3.48</td>
#       <td id="T_a9f45_row9_col8" class="data row9 col8" >33.33</td>
#     </tr>
#   </tbody>
# </table>

# %%
ngram_freq_table_DS.query('Tag1.str.startswith("Negative") and (~Tag2.str.startswith("Syntactic") and ~Tag2.str.startswith("Untagged") and ~Tag3.str.startswith("Untagged"))').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35e78">
#   <thead>
#     <tr>
#       <th id="T_35e78_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_35e78_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_35e78_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_35e78_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_35e78_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_35e78_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_35e78_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_35e78_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_35e78_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35e78_row0_col0" class="data row0 col0" >no</td>
#       <td id="T_35e78_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_35e78_row0_col2" class="data row0 col2" >hit</td>
#       <td id="T_35e78_row0_col3" class="data row0 col3" >Negative</td>
#       <td id="T_35e78_row0_col4" class="data row0 col4" >InformationExposition</td>
#       <td id="T_35e78_row0_col5" class="data row0 col5" >Description</td>
#       <td id="T_35e78_row0_col6" class="data row0 col6" >28</td>
#       <td id="T_35e78_row0_col7" class="data row0 col7" >48.67</td>
#       <td id="T_35e78_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row1_col0" class="data row1 col0" >no</td>
#       <td id="T_35e78_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_35e78_row1_col2" class="data row1 col2" >hit with</td>
#       <td id="T_35e78_row1_col3" class="data row1 col3" >Negative</td>
#       <td id="T_35e78_row1_col4" class="data row1 col4" >InformationExposition</td>
#       <td id="T_35e78_row1_col5" class="data row1 col5" >Negative</td>
#       <td id="T_35e78_row1_col6" class="data row1 col6" >5</td>
#       <td id="T_35e78_row1_col7" class="data row1 col7" >8.69</td>
#       <td id="T_35e78_row1_col8" class="data row1 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row2_col0" class="data row2 col0" >jeopardy</td>
#       <td id="T_35e78_row2_col1" class="data row2 col1" >!</td>
#       <td id="T_35e78_row2_col2" class="data row2 col2" >science</td>
#       <td id="T_35e78_row2_col3" class="data row2 col3" >Negative</td>
#       <td id="T_35e78_row2_col4" class="data row2 col4" >ForceStressed</td>
#       <td id="T_35e78_row2_col5" class="data row2 col5" >AcademicTerms</td>
#       <td id="T_35e78_row2_col6" class="data row2 col6" >4</td>
#       <td id="T_35e78_row2_col7" class="data row2 col7" >6.95</td>
#       <td id="T_35e78_row2_col8" class="data row2 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row3_col0" class="data row3 col0" >no</td>
#       <td id="T_35e78_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_35e78_row3_col2" class="data row3 col2" >album</td>
#       <td id="T_35e78_row3_col3" class="data row3 col3" >Negative</td>
#       <td id="T_35e78_row3_col4" class="data row3 col4" >InformationExposition</td>
#       <td id="T_35e78_row3_col5" class="data row3 col5" >Description</td>
#       <td id="T_35e78_row3_col6" class="data row3 col6" >4</td>
#       <td id="T_35e78_row3_col7" class="data row3 col7" >6.95</td>
#       <td id="T_35e78_row3_col8" class="data row3 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row4_col0" class="data row4 col0" >no</td>
#       <td id="T_35e78_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_35e78_row4_col2" class="data row4 col2" >hits</td>
#       <td id="T_35e78_row4_col3" class="data row4 col3" >Negative</td>
#       <td id="T_35e78_row4_col4" class="data row4 col4" >InformationExposition</td>
#       <td id="T_35e78_row4_col5" class="data row4 col5" >Description</td>
#       <td id="T_35e78_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_35e78_row4_col7" class="data row4 col7" >6.95</td>
#       <td id="T_35e78_row4_col8" class="data row4 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row5_col0" class="data row5 col0" >hit with</td>
#       <td id="T_35e78_row5_col1" class="data row5 col1" >this</td>
#       <td id="T_35e78_row5_col2" class="data row5 col2" >song</td>
#       <td id="T_35e78_row5_col3" class="data row5 col3" >Negative</td>
#       <td id="T_35e78_row5_col4" class="data row5 col4" >Narrative</td>
#       <td id="T_35e78_row5_col5" class="data row5 col5" >Description</td>
#       <td id="T_35e78_row5_col6" class="data row5 col6" >3</td>
#       <td id="T_35e78_row5_col7" class="data row5 col7" >5.21</td>
#       <td id="T_35e78_row5_col8" class="data row5 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row6_col0" class="data row6 col0" >no</td>
#       <td id="T_35e78_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_35e78_row6_col2" class="data row6 col2" >pop</td>
#       <td id="T_35e78_row6_col3" class="data row6 col3" >Negative</td>
#       <td id="T_35e78_row6_col4" class="data row6 col4" >InformationExposition</td>
#       <td id="T_35e78_row6_col5" class="data row6 col5" >Description</td>
#       <td id="T_35e78_row6_col6" class="data row6 col6" >3</td>
#       <td id="T_35e78_row6_col7" class="data row6 col7" >5.21</td>
#       <td id="T_35e78_row6_col8" class="data row6 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row7_col0" class="data row7 col0" >nor</td>
#       <td id="T_35e78_row7_col1" class="data row7 col1" >any</td>
#       <td id="T_35e78_row7_col2" class="data row7 col2" >drop to</td>
#       <td id="T_35e78_row7_col3" class="data row7 col3" >Negative</td>
#       <td id="T_35e78_row7_col4" class="data row7 col4" >InformationExposition</td>
#       <td id="T_35e78_row7_col5" class="data row7 col5" >Narrative</td>
#       <td id="T_35e78_row7_col6" class="data row7 col6" >3</td>
#       <td id="T_35e78_row7_col7" class="data row7 col7" >5.21</td>
#       <td id="T_35e78_row7_col8" class="data row7 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row8_col0" class="data row8 col0" >would n't</td>
#       <td id="T_35e78_row8_col1" class="data row8 col1" >be</td>
#       <td id="T_35e78_row8_col2" class="data row8 col2" >complete without</td>
#       <td id="T_35e78_row8_col3" class="data row8 col3" >Negative</td>
#       <td id="T_35e78_row8_col4" class="data row8 col4" >InformationStates</td>
#       <td id="T_35e78_row8_col5" class="data row8 col5" >ForceStressed</td>
#       <td id="T_35e78_row8_col6" class="data row8 col6" >3</td>
#       <td id="T_35e78_row8_col7" class="data row8 col7" >5.21</td>
#       <td id="T_35e78_row8_col8" class="data row8 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_35e78_row9_col0" class="data row9 col0" >afraid of</td>
#       <td id="T_35e78_row9_col1" class="data row9 col1" >virginia</td>
#       <td id="T_35e78_row9_col2" class="data row9 col2" >woolf</td>
#       <td id="T_35e78_row9_col3" class="data row9 col3" >Negative</td>
#       <td id="T_35e78_row9_col4" class="data row9 col4" >InformationPlace</td>
#       <td id="T_35e78_row9_col5" class="data row9 col5" >InformationTopics</td>
#       <td id="T_35e78_row9_col6" class="data row9 col6" >2</td>
#       <td id="T_35e78_row9_col7" class="data row9 col7" >3.48</td>
#       <td id="T_35e78_row9_col8" class="data row9 col8" >33.33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.5 Collocation Frequency Tables

# %% [markdown]
# Calculate *collocations* within a left-and-right span of a node word can be calculated according to several association measures.
#
# Default span is 4 tokens to the left and 4 tokens to the right of the node word.
#
# Like `frequency_table`, `coll_table` requires a dictionary of the type generated by the `convert_corpus` function. It also requires
#
# - a node word,
# - a node tag, and
# - an association measure statistic
#
# <blockquote>
# <h4><a href="https://docuscospacy.readthedocs.io/en/latest/api.html#corpus-analysis-coll-table-tok-node-word-l-span-4-r-span-4-statistic-pmi-count-by-pos-node-tag-none-tag-ignore-false">corpus_analysis.coll_table(tok, node_word, l_span=4, r_span=4, statistic=’pmi’, count_by=’pos’, node_tag=None, tag_ignore=False)</a></h4>
# <div><dl class="field-list simple">
# <dt class="field-odd">Parameters</dt>
# <dd class="field-odd"><ul class="simple">
# <li><p><strong>tok</strong> - A dictionary of tuples as generated by the <cite>convert_corpus</cite> function</p></li>
# <li><p><strong>node_word</strong> - The token around with collocations are measured</p></li>
# <li><p><strong>l_span</strong> - An integer between 0 and 9 representing the span to the left of the node word</p></li>
# <li><p><strong>r_span</strong> - An integer between 0 and 9 representing the span to the right of the node word</p></li>
# <li><p><strong>statistic</strong> - The association measure to be calculated. One of: ‘pmi’, ‘npmi’, ‘pmi2’, ‘pmi3’</p></li>
# <li><p><strong>count_by</strong> - One of ‘pos’ or ‘ds’ for aggregating tokens</p></li>
# <li><p><strong>node_tag</strong> - A value specifying the tag of the node word. If the node_word were ‘can’, a node_tag ‘V’ would search for can as a verb.</p></li>
# <li><p><strong>tag_ignore</strong> - A boolean value indicating whether or not tags should be ignored during analysis.</p></li>
# </ul>
# </dd>
# <dt class="field-even">Return</dt>
# <dd class="field-even"><ul class="simple">
# <li><p>a dataframe containing collocate tokens, tags, the absolute frequency the collocate in the corpus, the absolute frequency of the collocate within the designated span, and the association measure.</p></li>
# </ul>
# </dd>
# </dl>
# </div>
# </blockquote>

# %% [markdown]
# ##### POS tags

# %%
collocations_freq_table_POS = coll_table(
    tok=tp,
    node_word='can',
    node_tag='V',
    statistic='pmi',
    count_by='pos'
)
collocations_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\cradd\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 99 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=0'>1</a> collocations_freq_table_POS = coll_table(
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=1'>2</a>     tok=tp,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=2'>3</a>     node_word='can',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=3'>4</a>     node_tag='V',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=4'>5</a>     statistic='pmi',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=5'>6</a>     count_by='pos'
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> collocations_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\docuscospacy\corpus_analysis.py:249, in coll_table(tok, node_word, l_span, r_span, statistic, count_by, node_tag, tag_ignore)
#     247     df = pd.merge(df_span, df_total, how='inner', on=['Token', 'Tag'])
#     248 if statistic=='pmi':
# --> 249     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=False)
#     250 if statistic=='npmi':
#     251     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=True)
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\tmtoolkit\tokenseq\_metrics.py:62, in pmi(x, y, xy, n_total, logfn, k, alpha, normalize)
#      59 if k > 1 and normalize:
#      60     raise ValueError('normalization is only implemented for standard PMI with `k=1`')
# ---> 62 if x.ndim == 1:
#      63     if y is None or xy is None or x.shape != y.shape or x.shape != xy.shape:
#      64         raise ValueError('if `x` is given as vector, `y` and `xy` must also be given and must have the same length')
#
# AttributeError: 'int' object has no attribute 'ndim'

# %%
collocations_freq_table_POS.query('`Freq Total` > 5 and MI > 3 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d26e">
#   <thead>
#     <tr>
#       <th id="T_5d26e_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_5d26e_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_5d26e_level0_col2" class="col_heading level0 col2" >Freq Span</th>
#       <th id="T_5d26e_level0_col3" class="col_heading level0 col3" >Freq Total</th>
#       <th id="T_5d26e_level0_col4" class="col_heading level0 col4" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d26e_row0_col0" class="data row0 col0" >ascertain</td>
#       <td id="T_5d26e_row0_col1" class="data row0 col1" >VVI</td>
#       <td id="T_5d26e_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_5d26e_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_5d26e_row0_col4" class="data row0 col4" >4.96</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row1_col0" class="data row1 col0" >discarded</td>
#       <td id="T_5d26e_row1_col1" class="data row1 col1" >VVN</td>
#       <td id="T_5d26e_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_5d26e_row1_col3" class="data row1 col3" >9</td>
#       <td id="T_5d26e_row1_col4" class="data row1 col4" >4.71</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row2_col0" class="data row2 col0" >access</td>
#       <td id="T_5d26e_row2_col1" class="data row2 col1" >VVI</td>
#       <td id="T_5d26e_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_5d26e_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_5d26e_row2_col4" class="data row2 col4" >4.63</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row3_col0" class="data row3 col0" >thought</td>
#       <td id="T_5d26e_row3_col1" class="data row3 col1" >VVN</td>
#       <td id="T_5d26e_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_5d26e_row3_col3" class="data row3 col3" >7</td>
#       <td id="T_5d26e_row3_col4" class="data row3 col4" >4.63</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row4_col0" class="data row4 col0" >observe</td>
#       <td id="T_5d26e_row4_col1" class="data row4 col1" >VVI</td>
#       <td id="T_5d26e_row4_col2" class="data row4 col2" >57</td>
#       <td id="T_5d26e_row4_col3" class="data row4 col3" >81</td>
#       <td id="T_5d26e_row4_col4" class="data row4 col4" >4.61</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row5_col0" class="data row5 col0" >conclude</td>
#       <td id="T_5d26e_row5_col1" class="data row5 col1" >VVI</td>
#       <td id="T_5d26e_row5_col2" class="data row5 col2" >19</td>
#       <td id="T_5d26e_row5_col3" class="data row5 col3" >27</td>
#       <td id="T_5d26e_row5_col4" class="data row5 col4" >4.61</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row6_col0" class="data row6 col0" >infer</td>
#       <td id="T_5d26e_row6_col1" class="data row6 col1" >VVI</td>
#       <td id="T_5d26e_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_5d26e_row6_col3" class="data row6 col3" >9</td>
#       <td id="T_5d26e_row6_col4" class="data row6 col4" >4.56</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row7_col0" class="data row7 col0" >rejected</td>
#       <td id="T_5d26e_row7_col1" class="data row7 col1" >VVN</td>
#       <td id="T_5d26e_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_5d26e_row7_col3" class="data row7 col3" >9</td>
#       <td id="T_5d26e_row7_col4" class="data row7 col4" >4.56</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row8_col0" class="data row8 col0" >spot</td>
#       <td id="T_5d26e_row8_col1" class="data row8 col1" >VVI</td>
#       <td id="T_5d26e_row8_col2" class="data row8 col2" >7</td>
#       <td id="T_5d26e_row8_col3" class="data row8 col3" >11</td>
#       <td id="T_5d26e_row8_col4" class="data row8 col4" >4.51</td>
#     </tr>
#     <tr>
#       <td id="T_5d26e_row9_col0" class="data row9 col0" >communicate</td>
#       <td id="T_5d26e_row9_col1" class="data row9 col1" >VVI</td>
#       <td id="T_5d26e_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_5d26e_row9_col3" class="data row9 col3" >8</td>
#       <td id="T_5d26e_row9_col4" class="data row9 col4" >4.49</td>
#     </tr>
#   </tbody>
# </table>

# %%
collocations_freq_table_POS_npmi = coll_table(
    tok=tp,
    node_word='data',
    node_tag='N',
    statistic='npmi',
    count_by='pos',
    # tag_ignore=True
)
collocations_freq_table_POS_npmi.head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\cradd\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 101 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=0'>1</a> collocations_freq_table_POS_npmi = coll_table(
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=1'>2</a>     tok=tp,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=2'>3</a>     node_word='data',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=3'>4</a>     node_tag='N',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=4'>5</a>     statistic='npmi',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=5'>6</a>     count_by='pos',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=6'>7</a>     # tag_ignore=True
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=7'>8</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y202sZmlsZQ%3D%3D?line=8'>9</a> collocations_freq_table_POS_npmi.head(10).style.hide(axis='index').format(precision=2)
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\docuscospacy\corpus_analysis.py:251, in coll_table(tok, node_word, l_span, r_span, statistic, count_by, node_tag, tag_ignore)
#     249     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=False)
#     250 if statistic=='npmi':
# --> 251     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=True)
#     252 if statistic=='pmi2':
#     253     df['MI'] = pmi2(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']))
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\tmtoolkit\tokenseq\_metrics.py:62, in pmi(x, y, xy, n_total, logfn, k, alpha, normalize)
#      59 if k > 1 and normalize:
#      60     raise ValueError('normalization is only implemented for standard PMI with `k=1`')
# ---> 62 if x.ndim == 1:
#      63     if y is None or xy is None or x.shape != y.shape or x.shape != xy.shape:
#      64         raise ValueError('if `x` is given as vector, `y` and `xy` must also be given and must have the same length')
#
# AttributeError: 'int' object has no attribute 'ndim'

# %% [markdown]
# ##### DS tags

# %%
# DS Time!
collocations_freq_table_DS_npmi = coll_table(
    tok=tp,
    node_word='data',
    node_tag='Academic Terms',
    statistic='npmi', 
    count_by='ds'
)
collocations_freq_table_DS_npmi.head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\cradd\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 103 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=0'>1</a> # DS Time!
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=1'>2</a> collocations_freq_table_DS_npmi = coll_table(
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=2'>3</a>     tok=tp,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=3'>4</a>     node_word='data',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=4'>5</a>     node_tag='Academic Terms',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=5'>6</a>     statistic='npmi',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=6'>7</a>     count_by='ds'
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=7'>8</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y204sZmlsZQ%3D%3D?line=8'>9</a> collocations_freq_table_DS_npmi.head(10).style.hide(axis='index').format(precision=2)
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\docuscospacy\corpus_analysis.py:251, in coll_table(tok, node_word, l_span, r_span, statistic, count_by, node_tag, tag_ignore)
#     249     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=False)
#     250 if statistic=='npmi':
# --> 251     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=True)
#     252 if statistic=='pmi2':
#     253     df['MI'] = pmi2(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']))
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\tmtoolkit\tokenseq\_metrics.py:62, in pmi(x, y, xy, n_total, logfn, k, alpha, normalize)
#      59 if k > 1 and normalize:
#      60     raise ValueError('normalization is only implemented for standard PMI with `k=1`')
# ---> 62 if x.ndim == 1:
#      63     if y is None or xy is None or x.shape != y.shape or x.shape != xy.shape:
#      64         raise ValueError('if `x` is given as vector, `y` and `xy` must also be given and must have the same length')
#
# AttributeError: 'int' object has no attribute 'ndim'

# %% [markdown]
# We can also calculate collocations, while ignoring tags completely by setting `tag_ignore` to `True`

# %%
collocations_freq_table_DS_npmi_ignore_tag = coll_table(
    tok=tp,
    # Dial up the span of words to search for
    l_span=6,
    r_span=6,
    node_word='justice',
    tag_ignore=True, 
    statistic='npmi'
)
# Note the sorting method used too
collocations_freq_table_DS_npmi_ignore_tag.sort_values(by=['Freq Total'], ascending=False).head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\cradd\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 105 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=0'>1</a> collocations_freq_table_DS_npmi_ignore_tag = coll_table(
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=1'>2</a>     tok=tp,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=2'>3</a>     # Dial up the span of words to search for
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=3'>4</a>     l_span=6,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=4'>5</a>     r_span=6,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=5'>6</a>     node_word='justice',
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=6'>7</a>     tag_ignore=True,
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=7'>8</a>     statistic='npmi'
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=8'>9</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=9'>10</a> # Note the sorting method used too
#      <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y206sZmlsZQ%3D%3D?line=10'>11</a> collocations_freq_table_DS_npmi_ignore_tag.sort_values(by=['Freq Total'], ascending=False).head(10).style.hide(axis='index').format(precision=2)
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\docuscospacy\corpus_analysis.py:251, in coll_table(tok, node_word, l_span, r_span, statistic, count_by, node_tag, tag_ignore)
#     249     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=False)
#     250 if statistic=='npmi':
# --> 251     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=True)
#     252 if statistic=='pmi2':
#     253     df['MI'] = pmi2(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']))
#
# File c:\Users\cradd\AppData\Local\Programs\Python\Python39\lib\site-packages\tmtoolkit\tokenseq\_metrics.py:62, in pmi(x, y, xy, n_total, logfn, k, alpha, normalize)
#      59 if k > 1 and normalize:
#      60     raise ValueError('normalization is only implemented for standard PMI with `k=1`')
# ---> 62 if x.ndim == 1:
#      63     if y is None or xy is None or x.shape != y.shape or x.shape != xy.shape:
#      64         raise ValueError('if `x` is given as vector, `y` and `xy` must also be given and must have the same length')
#
# AttributeError: 'int' object has no attribute 'ndim'

# %% [markdown]
# ## 4.4 Document-term matrices for tags

# %% [markdown]
# Document-term matrices (DTMs) are basic data structures for text analysis. Each row is a document (observation) and each column is a token (variable). These can be produced by tmtoolkit) using the `dtm` function.
#
# The `docuscopspacy` package allows for the creation of DTMs with (*raw*) tag counts (rather than token counts) as variables.
#
# These are produced by the `tags_dtm` function, which takes a dictionary created by the `convert_corpus` function and a `count_by` argument of either `‘pos’` or `‘ds’`.

# %% [markdown]
# ### 4.4.1 POS DTM

# %%
dtm_POS = tags_dtm(
    tok=tp,
    count_by='pos'
)

# %%
dtm_POS.head(10).style.hide(axis='index').format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_128a5">
#   <thead>
#     <tr>
#       <th id="T_128a5_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_128a5_level0_col1" class="col_heading level0 col1" >APPGE</th>
#       <th id="T_128a5_level0_col2" class="col_heading level0 col2" >AT</th>
#       <th id="T_128a5_level0_col3" class="col_heading level0 col3" >AT1</th>
#       <th id="T_128a5_level0_col4" class="col_heading level0 col4" >BCL</th>
#       <th id="T_128a5_level0_col5" class="col_heading level0 col5" >CC</th>
#       <th id="T_128a5_level0_col6" class="col_heading level0 col6" >CCB</th>
#       <th id="T_128a5_level0_col7" class="col_heading level0 col7" >CS</th>
#       <th id="T_128a5_level0_col8" class="col_heading level0 col8" >CSA</th>
#       <th id="T_128a5_level0_col9" class="col_heading level0 col9" >CSN</th>
#       <th id="T_128a5_level0_col10" class="col_heading level0 col10" >CST</th>
#       <th id="T_128a5_level0_col11" class="col_heading level0 col11" >CSW</th>
#       <th id="T_128a5_level0_col12" class="col_heading level0 col12" >DA</th>
#       <th id="T_128a5_level0_col13" class="col_heading level0 col13" >DA1</th>
#       <th id="T_128a5_level0_col14" class="col_heading level0 col14" >DA2</th>
#       <th id="T_128a5_level0_col15" class="col_heading level0 col15" >DAR</th>
#       <th id="T_128a5_level0_col16" class="col_heading level0 col16" >DAT</th>
#       <th id="T_128a5_level0_col17" class="col_heading level0 col17" >DB</th>
#       <th id="T_128a5_level0_col18" class="col_heading level0 col18" >DB2</th>
#       <th id="T_128a5_level0_col19" class="col_heading level0 col19" >DD</th>
#       <th id="T_128a5_level0_col20" class="col_heading level0 col20" >DD1</th>
#       <th id="T_128a5_level0_col21" class="col_heading level0 col21" >DD2</th>
#       <th id="T_128a5_level0_col22" class="col_heading level0 col22" >DDQ</th>
#       <th id="T_128a5_level0_col23" class="col_heading level0 col23" >DDQGE</th>
#       <th id="T_128a5_level0_col24" class="col_heading level0 col24" >DDQV</th>
#       <th id="T_128a5_level0_col25" class="col_heading level0 col25" >EX</th>
#       <th id="T_128a5_level0_col26" class="col_heading level0 col26" >FO</th>
#       <th id="T_128a5_level0_col27" class="col_heading level0 col27" >FW</th>
#       <th id="T_128a5_level0_col28" class="col_heading level0 col28" >GE</th>
#       <th id="T_128a5_level0_col29" class="col_heading level0 col29" >IF</th>
#       <th id="T_128a5_level0_col30" class="col_heading level0 col30" >II</th>
#       <th id="T_128a5_level0_col31" class="col_heading level0 col31" >IO</th>
#       <th id="T_128a5_level0_col32" class="col_heading level0 col32" >IW</th>
#       <th id="T_128a5_level0_col33" class="col_heading level0 col33" >JJ</th>
#       <th id="T_128a5_level0_col34" class="col_heading level0 col34" >JJR</th>
#       <th id="T_128a5_level0_col35" class="col_heading level0 col35" >JJT</th>
#       <th id="T_128a5_level0_col36" class="col_heading level0 col36" >JK</th>
#       <th id="T_128a5_level0_col37" class="col_heading level0 col37" >MC</th>
#       <th id="T_128a5_level0_col38" class="col_heading level0 col38" >MC1</th>
#       <th id="T_128a5_level0_col39" class="col_heading level0 col39" >MC2</th>
#       <th id="T_128a5_level0_col40" class="col_heading level0 col40" >MCMC</th>
#       <th id="T_128a5_level0_col41" class="col_heading level0 col41" >MD</th>
#       <th id="T_128a5_level0_col42" class="col_heading level0 col42" >ND1</th>
#       <th id="T_128a5_level0_col43" class="col_heading level0 col43" >NN</th>
#       <th id="T_128a5_level0_col44" class="col_heading level0 col44" >NN1</th>
#       <th id="T_128a5_level0_col45" class="col_heading level0 col45" >NN2</th>
#       <th id="T_128a5_level0_col46" class="col_heading level0 col46" >NNA</th>
#       <th id="T_128a5_level0_col47" class="col_heading level0 col47" >NNB</th>
#       <th id="T_128a5_level0_col48" class="col_heading level0 col48" >NNL1</th>
#       <th id="T_128a5_level0_col49" class="col_heading level0 col49" >NNO</th>
#       <th id="T_128a5_level0_col50" class="col_heading level0 col50" >NNO2</th>
#       <th id="T_128a5_level0_col51" class="col_heading level0 col51" >NNT1</th>
#       <th id="T_128a5_level0_col52" class="col_heading level0 col52" >NNT2</th>
#       <th id="T_128a5_level0_col53" class="col_heading level0 col53" >NNU</th>
#       <th id="T_128a5_level0_col54" class="col_heading level0 col54" >NNU1</th>
#       <th id="T_128a5_level0_col55" class="col_heading level0 col55" >NNU2</th>
#       <th id="T_128a5_level0_col56" class="col_heading level0 col56" >NP</th>
#       <th id="T_128a5_level0_col57" class="col_heading level0 col57" >NP1</th>
#       <th id="T_128a5_level0_col58" class="col_heading level0 col58" >NPD1</th>
#       <th id="T_128a5_level0_col59" class="col_heading level0 col59" >NPD2</th>
#       <th id="T_128a5_level0_col60" class="col_heading level0 col60" >NPM1</th>
#       <th id="T_128a5_level0_col61" class="col_heading level0 col61" >PN</th>
#       <th id="T_128a5_level0_col62" class="col_heading level0 col62" >PN1</th>
#       <th id="T_128a5_level0_col63" class="col_heading level0 col63" >PNQO</th>
#       <th id="T_128a5_level0_col64" class="col_heading level0 col64" >PNQS</th>
#       <th id="T_128a5_level0_col65" class="col_heading level0 col65" >PNQV</th>
#       <th id="T_128a5_level0_col66" class="col_heading level0 col66" >PNX1</th>
#       <th id="T_128a5_level0_col67" class="col_heading level0 col67" >PPGE</th>
#       <th id="T_128a5_level0_col68" class="col_heading level0 col68" >PPH1</th>
#       <th id="T_128a5_level0_col69" class="col_heading level0 col69" >PPHO1</th>
#       <th id="T_128a5_level0_col70" class="col_heading level0 col70" >PPHO2</th>
#       <th id="T_128a5_level0_col71" class="col_heading level0 col71" >PPHS1</th>
#       <th id="T_128a5_level0_col72" class="col_heading level0 col72" >PPHS2</th>
#       <th id="T_128a5_level0_col73" class="col_heading level0 col73" >PPIO1</th>
#       <th id="T_128a5_level0_col74" class="col_heading level0 col74" >PPIO2</th>
#       <th id="T_128a5_level0_col75" class="col_heading level0 col75" >PPIS2</th>
#       <th id="T_128a5_level0_col76" class="col_heading level0 col76" >PPX1</th>
#       <th id="T_128a5_level0_col77" class="col_heading level0 col77" >PPX2</th>
#       <th id="T_128a5_level0_col78" class="col_heading level0 col78" >PPY</th>
#       <th id="T_128a5_level0_col79" class="col_heading level0 col79" >RA</th>
#       <th id="T_128a5_level0_col80" class="col_heading level0 col80" >REX</th>
#       <th id="T_128a5_level0_col81" class="col_heading level0 col81" >RG</th>
#       <th id="T_128a5_level0_col82" class="col_heading level0 col82" >RGQ</th>
#       <th id="T_128a5_level0_col83" class="col_heading level0 col83" >RGQV</th>
#       <th id="T_128a5_level0_col84" class="col_heading level0 col84" >RGR</th>
#       <th id="T_128a5_level0_col85" class="col_heading level0 col85" >RGT</th>
#       <th id="T_128a5_level0_col86" class="col_heading level0 col86" >RL</th>
#       <th id="T_128a5_level0_col87" class="col_heading level0 col87" >RP</th>
#       <th id="T_128a5_level0_col88" class="col_heading level0 col88" >RPK</th>
#       <th id="T_128a5_level0_col89" class="col_heading level0 col89" >RR</th>
#       <th id="T_128a5_level0_col90" class="col_heading level0 col90" >RRQ</th>
#       <th id="T_128a5_level0_col91" class="col_heading level0 col91" >RRQV</th>
#       <th id="T_128a5_level0_col92" class="col_heading level0 col92" >RRR</th>
#       <th id="T_128a5_level0_col93" class="col_heading level0 col93" >RRT</th>
#       <th id="T_128a5_level0_col94" class="col_heading level0 col94" >RT</th>
#       <th id="T_128a5_level0_col95" class="col_heading level0 col95" >TO</th>
#       <th id="T_128a5_level0_col96" class="col_heading level0 col96" >UH</th>
#       <th id="T_128a5_level0_col97" class="col_heading level0 col97" >VBDR</th>
#       <th id="T_128a5_level0_col98" class="col_heading level0 col98" >VBDZ</th>
#       <th id="T_128a5_level0_col99" class="col_heading level0 col99" >VBG</th>
#       <th id="T_128a5_level0_col

# %% [markdown]
# ### 4.4.2 DS DTM

# %%
dtm_DS = tags_dtm(
    tok=tp,
    count_by='ds'
)
dtm_DS.head(10).style.hide(axis='index').format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb543">
#   <thead>
#     <tr>
#       <th id="T_cb543_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_cb543_level0_col1" class="col_heading level0 col1" >AcademicTerms</th>
#       <th id="T_cb543_level0_col2" class="col_heading level0 col2" >AcademicWritingMoves</th>
#       <th id="T_cb543_level0_col3" class="col_heading level0 col3" >Character</th>
#       <th id="T_cb543_level0_col4" class="col_heading level0 col4" >Citation</th>
#       <th id="T_cb543_level0_col5" class="col_heading level0 col5" >CitationAuthority</th>
#       <th id="T_cb543_level0_col6" class="col_heading level0 col6" >CitationHedged</th>
#       <th id="T_cb543_level0_col7" class="col_heading level0 col7" >ConfidenceHedged</th>
#       <th id="T_cb543_level0_col8" class="col_heading level0 col8" >ConfidenceHigh</th>
#       <th id="T_cb543_level0_col9" class="col_heading level0 col9" >ConfidenceLow</th>
#       <th id="T_cb543_level0_col10" class="col_heading level0 col10" >Contingent</th>
#       <th id="T_cb543_level0_col11" class="col_heading level0 col11" >Description</th>
#       <th id="T_cb543_level0_col12" class="col_heading level0 col12" >Facilitate</th>
#       <th id="T_cb543_level0_col13" class="col_heading level0 col13" >FirstPerson</th>
#       <th id="T_cb543_level0_col14" class="col_heading level0 col14" >ForceStressed</th>
#       <th id="T_cb543_level0_col15" class="col_heading level0 col15" >Future</th>
#       <th id="T_cb543_level0_col16" class="col_heading level0 col16" >InformationChange</th>
#       <th id="T_cb543_level0_col17" class="col_heading level0 col17" >InformationChangeNegative</th>
#       <th id="T_cb543_level0_col18" class="col_heading level0 col18" >InformationChangePositive</th>
#       <th id="T_cb543_level0_col19" class="col_heading level0 col19" >InformationExposition</th>
#       <th id="T_cb543_level0_col20" class="col_heading level0 col20" >InformationPlace</th>
#       <th id="T_cb543_level0_col21" class="col_heading level0 col21" >InformationReportVerbs</th>
#       <th id="T_cb543_level0_col22" class="col_heading level0 col22" >InformationStates</th>
#       <th id="T_cb543_level0_col23" class="col_heading level0 col23" >InformationTopics</th>
#       <th id="T_cb543_level0_col24" class="col_heading level0 col24" >Inquiry</th>
#       <th id="T_cb543_level0_col25" class="col_heading level0 col25" >Interactive</th>
#       <th id="T_cb543_level0_col26" class="col_heading level0 col26" >MetadiscourseCohesive</th>
#       <th id="T_cb543_level0_col27" class="col_heading level0 col27" >MetadiscourseInteractive</th>
#       <th id="T_cb543_level0_col28" class="col_heading level0 col28" >Narrative</th>
#       <th id="T_cb543_level0_col29" class="col_heading level0 col29" >Negative</th>
#       <th id="T_cb543_level0_col30" class="col_heading level0 col30" >Positive</th>
#       <th id="T_cb543_level0_col31" class="col_heading level0 col31" >PublicTerms</th>
#       <th id="T_cb543_level0_col32" class="col_heading level0 col32" >Reasoning</th>
#       <th id="T_cb543_level0_col33" class="col_heading level0 col33" >Responsibility</th>
#       <th id="T_cb543_level0_col34" class="col_heading level0 col34" >Strategic</th>
#       <th id="T_cb543_level0_col35" class="col_heading level0 col35" >Uncertainty</th>
#       <th id="T_cb543_level0_col36" class="col_heading level0 col36" >Untagged</th>
#       <th id="T_cb543_level0_col37" class="col_heading level0 col37" >Updates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cb543_row0_col0" class="data row0 col0" >split-q_greater_than_1000</td>
#       <td id="T_cb543_row0_col1" class="data row0 col1" >6753</td>
#       <td id="T_cb543_row0_col2" class="data row0 col2" >129</td>
#       <td id="T_cb543_row0_col3" class="data row0 col3" >14027</td>
#       <td id="T_cb543_row0_col4" class="data row0 col4" >1270</td>
#       <td id="T_cb543_row0_col5" class="data row0 col5" >167</td>
#       <td id="T_cb543_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_cb543_row0_col7" class="data row0 col7" >425</td>
#       <td id="T_cb543_row0_col8" class="data row0 col8" >582</td>
#       <td id="T_cb543_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_cb543_row0_col10" class="data row0 col10" >323</td>
#       <td id="T_cb543_row0_col11" class="data row0 col11" >17767</td>
#       <td id="T_cb543_row0_col12" class="data row0 col12" >155</td>
#       <td id="T_cb543_row0_col13" class="data row0 col13" >627</td>
#       <td id="T_cb543_row0_col14" class="data row0 col14" >1977</td>
#       <td id="T_cb543_row0_col15" class="data row0 col15" >278</td>
#       <td id="T_cb543_row0_col16" class="data row0 col16" >660</td>
#       <td id="T_cb543_row0_col17" class="data row0 col17" >106</td>
#       <td id="T_cb543_row0_col18" class="data row0 col18" >119</td>
#       <td id="T_cb543_row0_col19" class="data row0 col19" >4244</td>
#       <td id="T_cb543_row0_col20" class="data row0 col20" >3469</td>
#       <td id="T_cb543_row0_col21" class="data row0 col21" >1167</td>
#       <td id="T_cb543_row0_col22" class="data row0 col22" >1583</td>
#       <td id="T_cb543_row0_col23" class="data row0 col23" >4034</td>
#       <td id="T_cb543_row0_col24" class="data row0 col24" >638</td>
#       <td id="T_cb543_row0_col25" class="data row0 col25" >1510</td>
#       <td id="T_cb543_row0_col26" class="data row0 col26" >1676</td>
#       <td id="T_cb543_row0_col27" class="data row0 col27" >207</td>
#       <td id="T_cb543_row0_col28" class="data row0 col28" >15784</td>
#       <td id="T_cb543_row0_col29" class="data row0 col29" >3554</td>
#       <td id="T_cb543_row0_col30" class="data row0 col30" >2808</td>
#       <td id="T_cb543_row0_col31" class="data row0 col31" >1964</td>
#       <td id="T_cb543_row0_col32" class="data row0 col32" >564</td>
#       <td id="T_cb543_row0_col33" class="data row0 col33" >52</td>
#       <td id="T_cb543_row0_col34" class="data row0 col34" >1430</td>
#       <td id="T_cb543_row0_col35" class="data row0 col35" >103</td>
#       <td id="T_cb543_row0_col36" class="data row0 col36" >39308</td>
#       <td id="T_cb543_row0_col37" class="data row0 col37" >309</td>
#     </tr>
#     <tr>
#       <td id="T_cb543_row1_col0" class="data row1 col0" >split-q_greater_than_400_less_than_1000</td>
#       <td id="T_cb543_row1_col1" class="data row1 col1" >5824</td>
#       <td id="T_cb543_row1_col2" class="data row1 col2" >106</td>
#       <td id="T_cb543_row1_col3" class="data row1 col3" >13428</td>
#       <td id="T_cb543_row1_col4" class="data row1 col4" >1164</td>
#       <td id="T_cb543_row1_col5" class="data row1 col5" >119</td>
#       <td id="T_cb543_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_cb543_row1_col7" class="data row1 col7" >433</td>
#       <td id="T_cb543_row1_col8" class="data row1 col8" >568</td>
#       <td id="T_cb543_row1_col9" class="data row1 col9" >3</td>
#       <td id="T_cb543_row1_col10" class="data row1 col10" >304</td>
#       <td id="T_cb543_row1_col11" class="data row1 col11" >17385</td>
#       <td id="T_cb543_row1_col12" class="data row1 col12" >164</td>
#       <td id="T_cb543_row1_col13" class="data row1 col13" >550</td>
#       <td id="T_cb543_row1_col14" class="data row1 col14" >1933</td>
#       <td id="T_cb543_row1_col15" class="data row1 col15" >247</td>
#       <td id="T_cb543_row1_col16" class="data row1 col16" >603</td>
#       <td id="T_cb543_row1_col17" class="data row1 col17" >87</td>
#       <td id="T_cb543_row1_col18" class="data row1 col18" >123</td>
#       <td id="T_cb543_row1_col19" class="data row1 col19" >4166</td>
#       <td id="T_cb543_row1_col20" class="data row1 col20" >3365</td>
#       <td id="T_cb543_row1_col21" class="data row1 col21" >1156</td>
#       <td id="T_cb543_row1_col22" class="data row1 col22" >1418</td>
#       <td id="T_cb543_row1_col23" class="data row1 col23" >3989</td>
#       <td id="T_cb543_row1_col24" class="data row1 col24" >452</td>
#       <td id="T_cb543_row1_col25" class="data row1 col25" >1519</td>
#       <td id="T_cb543_row1_col26" class="data row1 col26" >1534</td>
#       <td id="T_cb543_row1_c

# %% [markdown]
# ### 4.4.3 Count frequencies, then give weight (importance) to document-term counts
#
# We can use the tmtoolkit library to create weighted counts (using its `tf_proportions` function), `tf-idf` values (using the tfidf function), or other types of data structures.

# %%
from temptmtoolkit.bow.bow_stats import tf_proportions, tfidf

# %% [markdown]
# #### 4.4.3.1 Count the document term frequencies (raw counts)

# %%
dtm_POS.set_index('doc_id', inplace=True)
dtm_POS.head(10).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_96542">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96542_level0_col0" class="col_heading level0 col0" >APPGE</th>
#       <th id="T_96542_level0_col1" class="col_heading level0 col1" >AT</th>
#       <th id="T_96542_level0_col2" class="col_heading level0 col2" >AT1</th>
#       <th id="T_96542_level0_col3" class="col_heading level0 col3" >BCL</th>
#       <th id="T_96542_level0_col4" class="col_heading level0 col4" >CC</th>
#       <th id="T_96542_level0_col5" class="col_heading level0 col5" >CCB</th>
#       <th id="T_96542_level0_col6" class="col_heading level0 col6" >CS</th>
#       <th id="T_96542_level0_col7" class="col_heading level0 col7" >CSA</th>
#       <th id="T_96542_level0_col8" class="col_heading level0 col8" >CSN</th>
#       <th id="T_96542_level0_col9" class="col_heading level0 col9" >CST</th>
#       <th id="T_96542_level0_col10" class="col_heading level0 col10" >CSW</th>
#       <th id="T_96542_level0_col11" class="col_heading level0 col11" >DA</th>
#       <th id="T_96542_level0_col12" class="col_heading level0 col12" >DA1</th>
#       <th id="T_96542_level0_col13" class="col_heading level0 col13" >DA2</th>
#       <th id="T_96542_level0_col14" class="col_heading level0 col14" >DAR</th>
#       <th id="T_96542_level0_col15" class="col_heading level0 col15" >DAT</th>
#       <th id="T_96542_level0_col16" class="col_heading level0 col16" >DB</th>
#       <th id="T_96542_level0_col17" class="col_heading level0 col17" >DB2</th>
#       <th id="T_96542_level0_col18" class="col_heading level0 col18" >DD</th>
#       <th id="T_96542_level0_col19" class="col_heading level0 col19" >DD1</th>
#       <th id="T_96542_level0_col20" class="col_heading level0 col20" >DD2</th>
#       <th id="T_96542_level0_col21" class="col_heading level0 col21" >DDQ</th>
#       <th id="T_96542_level0_col22" class="col_heading level0 col22" >DDQGE</th>
#       <th id="T_96542_level0_col23" class="col_heading level0 col23" >DDQV</th>
#       <th id="T_96542_level0_col24" class="col_heading level0 col24" >EX</th>
#       <th id="T_96542_level0_col25" class="col_heading level0 col25" >FO</th>
#       <th id="T_96542_level0_col26" class="col_heading level0 col26" >FW</th>
#       <th id="T_96542_level0_col27" class="col_heading level0 col27" >GE</th>
#       <th id="T_96542_level0_col28" class="col_heading level0 col28" >IF</th>
#       <th id="T_96542_level0_col29" class="col_heading level0 col29" >II</th>
#       <th id="T_96542_level0_col30" class="col_heading level0 col30" >IO</th>
#       <th id="T_96542_level0_col31" class="col_heading level0 col31" >IW</th>
#       <th id="T_96542_level0_col32" class="col_heading level0 col32" >JJ</th>
#       <th id="T_96542_level0_col33" class="col_heading level0 col33" >JJR</th>
#       <th id="T_96542_level0_col34" class="col_heading level0 col34" >JJT</th>
#       <th id="T_96542_level0_col35" class="col_heading level0 col35" >JK</th>
#       <th id="T_96542_level0_col36" class="col_heading level0 col36" >MC</th>
#       <th id="T_96542_level0_col37" class="col_heading level0 col37" >MC1</th>
#       <th id="T_96542_level0_col38" class="col_heading level0 col38" >MC2</th>
#       <th id="T_96542_level0_col39" class="col_heading level0 col39" >MCMC</th>
#       <th id="T_96542_level0_col40" class="col_heading level0 col40" >MD</th>
#       <th id="T_96542_level0_col41" class="col_heading level0 col41" >ND1</th>
#       <th id="T_96542_level0_col42" class="col_heading level0 col42" >NN</th>
#       <th id="T_96542_level0_col43" class="col_heading level0 col43" >NN1</th>
#       <th id="T_96542_level0_col44" class="col_heading level0 col44" >NN2</th>
#       <th id="T_96542_level0_col45" class="col_heading level0 col45" >NNA</th>
#       <th id="T_96542_level0_col46" class="col_heading level0 col46" >NNB</th>
#       <th id="T_96542_level0_col47" class="col_heading level0 col47" >NNL1</th>
#       <th id="T_96542_level0_col48" class="col_heading level0 col48" >NNO</th>
#       <th id="T_96542_level0_col49" class="col_heading level0 col49" >NNO2</th>
#       <th id="T_96542_level0_col50" class="col_heading level0 col50" >NNT1</th>
#       <th id="T_96542_level0_col51" class="col_heading level0 col51" >NNT2</th>
#       <th id="T_96542_level0_col52" class="col_heading level0 col52" >NNU</th>
#       <th id="T_96542_level0_col53" class="col_heading level0 col53" >NNU1</th>
#       <th id="T_96542_level0_col54" class="col_heading level0 col54" >NNU2</th>
#       <th id="T_96542_level0_col55" class="col_heading level0 col55" >NP</th>
#       <th id="T_96542_level0_col56" class="col_heading level0 col56" >NP1</th>
#       <th id="T_96542_level0_col57" class="col_heading level0 col57" >NPD1</th>
#       <th id="T_96542_level0_col58" class="col_heading level0 col58" >NPD2</th>
#       <th id="T_96542_level0_col59" class="col_heading level0 col59" >NPM1</th>
#       <th id="T_96542_level0_col60" class="col_heading level0 col60" >PN</th>
#       <th id="T_96542_level0_col61" class="col_heading level0 col61" >PN1</th>
#       <th id="T_96542_level0_col62" class="col_heading level0 col62" >PNQO</th>
#       <th id="T_96542_level0_col63" class="col_heading level0 col63" >PNQS</th>
#       <th id="T_96542_level0_col64" class="col_heading level0 col64" >PNQV</th>
#       <th id="T_96542_level0_col65" class="col_heading level0 col65" >PNX1</th>
#       <th id="T_96542_level0_col66" class="col_heading level0 col66" >PPGE</th>
#       <th id="T_96542_level0_col67" class="col_heading level0 col67" >PPH1</th>
#       <th id="T_96542_level0_col68" class="col_heading level0 col68" >PPHO1</th>
#       <th id="T_96542_level0_col69" class="col_heading level0 col69" >PPHO2</th>
#       <th id="T_96542_level0_col70" class="col_heading level0 col70" >PPHS1</th>
#       <th id="T_96542_level0_col71" class="col_heading level0 col71" >PPHS2</th>
#       <th id="T_96542_level0_col72" class="col_heading level0 col72" >PPIO1</th>
#       <th id="T_96542_level0_col73" class="col_heading level0 col73" >PPIO2</th>
#       <th id="T_96542_level0_col74" class="col_heading level0 col74" >PPIS2</th>
#       <th id="T_96542_level0_col75" class="col_heading level0 col75" >PPX1</th>
#       <th id="T_96542_level0_col76" class="col_heading level0 col76" >PPX2</th>
#       <th id="T_96542_level0_col77" class="col_heading level0 col77" >PPY</th>
#       <th id="T_96542_level0_col78" class="col_heading level0 col78" >RA</th>
#       <th id="T_96542_level0_col79" class="col_heading level0 col79" >REX</th>
#       <th id="T_96542_level0_col80" class="col_heading level0 col80" >RG</th>
#       <th id="T_96542_level0_col81" class="col_heading level0 col81" >RGQ</th>
#       <th id="T_96542_level0_col82" class="col_heading level0 col82" >RGQV</th>
#       <th id="T_96542_level0_col83" class="col_heading level0 col83" >RGR</th>
#       <th id="T_96542_level0_col84" class="col_heading level0 col84" >RGT</th>
#       <th id="T_96542_level0_col85" class="col_heading level0 col85" >RL</th>
#       <th id="T_96542_level0_col86" class="col_heading level0 col86" >RP</th>
#       <th id="T_96542_level0_col87" class="col_heading level0 col87" >RPK</th>
#       <th id="T_96542_level0_col88" class="col_heading level0 col88" >RR</th>
#       <th id="T_96542_level0_col89" class="col_heading level0 col89" >RRQ</th>
#       <th id="T_96542_level0_col90" class="col_heading level0 col90" >RRQV</th>
#       <th id="T_96542_level0_col91" class="col_heading level0 col91" >RRR</th>
#       <th id="T_96542_level0_col92" class="col_heading level0 col92" >RRT</th>
#       <th id="T_96542_level0_col93" class="col_heading level0 col93" >RT</th>
#       <th id="T_96542_level0_col94" class="col_heading level0 col94" >TO</th>
#       <th id="T_96542_level0_col95" class="col_heading level0 col95" >UH</th>
#       <th id="T_96542_level0_col96" class="col_heading level0 col96" >VBDR</th>
#       <th id="T_96542_level0_col97" class="col_heading level0 col97" >VBDZ</th>
#       <th id="T_96542_level0_col98" class="col_heading level0 col98" >VBG</th>
#       <th id="T_96542_level0_col99" class="col_heading level0 col99" >

# %%
dtm_DS.set_index('doc_id', inplace=True)
dtm_DS.head(10).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc672">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc672_level0_col0" class="col_heading level0 col0" >AcademicTerms</th>
#       <th id="T_fc672_level0_col1" class="col_heading level0 col1" >AcademicWritingMoves</th>
#       <th id="T_fc672_level0_col2" class="col_heading level0 col2" >Character</th>
#       <th id="T_fc672_level0_col3" class="col_heading level0 col3" >Citation</th>
#       <th id="T_fc672_level0_col4" class="col_heading level0 col4" >CitationAuthority</th>
#       <th id="T_fc672_level0_col5" class="col_heading level0 col5" >CitationHedged</th>
#       <th id="T_fc672_level0_col6" class="col_heading level0 col6" >ConfidenceHedged</th>
#       <th id="T_fc672_level0_col7" class="col_heading level0 col7" >ConfidenceHigh</th>
#       <th id="T_fc672_level0_col8" class="col_heading level0 col8" >ConfidenceLow</th>
#       <th id="T_fc672_level0_col9" class="col_heading level0 col9" >Contingent</th>
#       <th id="T_fc672_level0_col10" class="col_heading level0 col10" >Description</th>
#       <th id="T_fc672_level0_col11" class="col_heading level0 col11" >Facilitate</th>
#       <th id="T_fc672_level0_col12" class="col_heading level0 col12" >FirstPerson</th>
#       <th id="T_fc672_level0_col13" class="col_heading level0 col13" >ForceStressed</th>
#       <th id="T_fc672_level0_col14" class="col_heading level0 col14" >Future</th>
#       <th id="T_fc672_level0_col15" class="col_heading level0 col15" >InformationChange</th>
#       <th id="T_fc672_level0_col16" class="col_heading level0 col16" >InformationChangeNegative</th>
#       <th id="T_fc672_level0_col17" class="col_heading level0 col17" >InformationChangePositive</th>
#       <th id="T_fc672_level0_col18" class="col_heading level0 col18" >InformationExposition</th>
#       <th id="T_fc672_level0_col19" class="col_heading level0 col19" >InformationPlace</th>
#       <th id="T_fc672_level0_col20" class="col_heading level0 col20" >InformationReportVerbs</th>
#       <th id="T_fc672_level0_col21" class="col_heading level0 col21" >InformationStates</th>
#       <th id="T_fc672_level0_col22" class="col_heading level0 col22" >InformationTopics</th>
#       <th id="T_fc672_level0_col23" class="col_heading level0 col23" >Inquiry</th>
#       <th id="T_fc672_level0_col24" class="col_heading level0 col24" >Interactive</th>
#       <th id="T_fc672_level0_col25" class="col_heading level0 col25" >MetadiscourseCohesive</th>
#       <th id="T_fc672_level0_col26" class="col_heading level0 col26" >MetadiscourseInteractive</th>
#       <th id="T_fc672_level0_col27" class="col_heading level0 col27" >Narrative</th>
#       <th id="T_fc672_level0_col28" class="col_heading level0 col28" >Negative</th>
#       <th id="T_fc672_level0_col29" class="col_heading level0 col29" >Positive</th>
#       <th id="T_fc672_level0_col30" class="col_heading level0 col30" >PublicTerms</th>
#       <th id="T_fc672_level0_col31" class="col_heading level0 col31" >Reasoning</th>
#       <th id="T_fc672_level0_col32" class="col_heading level0 col32" >Responsibility</th>
#       <th id="T_fc672_level0_col33" class="col_heading level0 col33" >Strategic</th>
#       <th id="T_fc672_level0_col34" class="col_heading level0 col34" >Uncertainty</th>
#       <th id="T_fc672_level0_col35" class="col_heading level0 col35" >Untagged</th>
#       <th id="T_fc672_level0_col36" class="col_heading level0 col36" >Updates</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >doc_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc672_level0_row0" class="row_heading level0 row0" >split-q_greater_than_1000</th>
#       <td id="T_fc672_row0_col0" class="data row0 col0" >6753</td>
#       <td id="T_fc672_row0_col1" class="data row0 col1" >129</td>
#       <td id="T_fc672_row0_col2" class="data row0 col2" >14027</td>
#       <td id="T_fc672_row0_col3" class="data row0 col3" >1270</td>
#       <td id="T_fc672_row0_col4" class="data row0 col4" >167</td>
#       <td id="T_fc672_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_fc672_row0_col6" class="data row0 col6" >425</td>
#       <td id="T_fc672_row0_col7" class="data row0 col7" >582</td>
#       <td id="T_fc672_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_fc672_row0_col9" class="data row0 col9" >323</td>
#       <td id="T_fc672_row0_col10" class="data row0 col10" >17767</td>
#       <td id="T_fc672_row0_col11" class="data row0 col11" >155</td>
#       <td id="T_fc672_row0_col12" class="data row0 col12" >627</td>
#       <td id="T_fc672_row0_col13" class="data row0 col13" >1977</td>
#       <td id="T_fc672_row0_col14" class="data row0 col14" >278</td>
#       <td id="T_fc672_row0_col15" class="data row0 col15" >660</td>
#       <td id="T_fc672_row0_col16" class="data row0 col16" >106</td>
#       <td id="T_fc672_row0_col17" class="data row0 col17" >119</td>
#       <td id="T_fc672_row0_col18" class="data row0 col18" >4244</td>
#       <td id="T_fc672_row0_col19" class="data row0 col19" >3469</td>
#       <td id="T_fc672_row0_col20" class="data row0 col20" >1167</td>
#       <td id="T_fc672_row0_col21" class="data row0 col21" >1583</td>
#       <td id="T_fc672_row0_col22" class="data row0 col22" >4034</td>
#       <td id="T_fc672_row0_col23" class="data row0 col23" >638</td>
#       <td id="T_fc672_row0_col24" class="data row0 col24" >1510</td>
#       <td id="T_fc672_row0_col25" class="data row0 col25" >1676</td>
#       <td id="T_fc672_row0_col26" class="data row0 col26" >207</td>
#       <td id="T_fc672_row0_col27" class="data row0 col27" >15784</td>
#       <td id="T_fc672_row0_col28" class="data row0 col28" >3554</td>
#       <td id="T_fc672_row0_col29" class="data row0 col29" >2808</td>
#       <td id="T_fc672_row0_col30" class="data row0 col30" >1964</td>
#       <td id="T_fc672_row0_col31" class="data row0 col31" >564</td>
#       <td id="T_fc672_row0_col32" class="data row0 col32" >52</td>
#       <td id="T_fc672_row0_col33" class="data row0 col33" >1430</td>
#       <td id="T_fc672_row0_col34" class="data row0 col34" >103</td>
#       <td id="T_fc672_row0_col35" class="data row0 col35" >39308</td>
#       <td id="T_fc672_row0_col36" class="data row0 col36" >309</td>
#     </tr>
#     <tr>
#       <th id="T_fc672_level0_row1" class="row_heading level0 row1" >split-q_greater_than_400_less_than_1000</th>
#       <td id="T_fc672_row1_col0" class="data row1 col0" >5824</td>
#       <td id="T_fc672_row1_col1" class="data row1 col1" >106</td>
#       <td id="T_fc672_r

# %% [markdown]
# #### 4.4.3.2 Weigh the document-terms by proportions
#
# Simply take the percentage of the frequencies across the sum across the corpus, e.g., AT () below comes out to roughly 6% of the corpus across the documents.

# %%
tf_proportions(dtm_POS).head(10)
# Out:
#                                             APPGE        AT       AT1  \
# doc_id
# split-q_greater_than_1000                0.010374  0.062129  0.034588
# split-q_greater_than_400_less_than_1000  0.010990  0.058380  0.032388
# split-q_less_than_400                    0.011231  0.057740  0.032993
#
#                                               BCL        CC       CCB  \
# doc_id
# split-q_greater_than_1000                0.000040  0.004879  0.001624
# split-q_greater_than_400_less_than_1000  0.000007  0.005043  0.001240
# split-q_less_than_400                    0.000029  0.005291  0.001591
#
#                                                CS       CSA       CSN  \
# doc_id
# split-q_greater_than_1000                0.005588  0.002559  0.000696
# split-q_greater_than_400_less_than_1000  0.005484  0.002557  0.000686
# split-q_less_than_400                    0.006262  0.002642  0.000876
#
#                                               CST  ...       VVD       VVG  \
# doc_id                                             ...
# split-q_greater_than_1000                0.004468  ...  0.024234  0.010937
# split-q_greater_than_400_less_than_1000  0.004371  ...  0.025215  0.010422
# split-q_less_than_400                    0.003934  ...  0.025593  0.009947
#
#                                              VVGK       VVI       VVN  \
# doc_id
# split-q_greater_than_1000                0.000146  0.012501  0.025858
# split-q_greater_than_400_less_than_1000  0.000056  0.013287  0.026889
# split-q_less_than_400                    0.000168  0.014223  0.027060
#
#                                              VVNK       VVZ        XX  \
# doc_id
# split-q_greater_than_1000                0.000007  0.014318  0.003241
# split-q_greater_than_400_less_than_1000  0.000000  0.012930  0.003362
# split-q_less_than_400                    0.000015  0.012735  0.003846
#
#                                               ZZ1       ZZ2
# doc_id
# split-q_greater_than_1000                0.004527  0.000013
# split-q_greater_than_400_less_than_1000  0.003733  0.000021
# split-q_less_than_400                    0.003766  0.000029
#
# [3 rows x 129 columns]

# %%
tf_proportions(dtm_DS).head(10)
# Out:
#                                          AcademicTerms  AcademicWritingMoves  \
# doc_id
# split-q_greater_than_1000                     0.052038              0.000994
# split-q_greater_than_400_less_than_1000       0.047216              0.000859
# split-q_less_than_400                         0.044570              0.000994
#
#                                          Character  Citation  \
# doc_id
# split-q_greater_than_1000                 0.108091  0.009787
# split-q_greater_than_400_less_than_1000   0.108863  0.009437
# split-q_less_than_400                     0.104192  0.009077
#
#                                          CitationAuthority  CitationHedged  \
# doc_id
# split-q_greater_than_1000                         0.001287        0.000008
# split-q_greater_than_400_less_than_1000           0.000965        0.000008
# split-q_less_than_400                             0.001249        0.000025
#
#                                          ConfidenceHedged  ConfidenceHigh  \
# doc_id
# split-q_greater_than_1000                        0.003275        0.004485
# split-q_greater_than_400_less_than_1000          0.003510        0.004605
# split-q_less_than_400                            0.003995        0.004887
#
#                                          ConfidenceLow  Contingent  ...  \
# doc_id                                                              ...
# split-q_greater_than_1000                     0.000000    0.002489  ...
# split-q_greater_than_400_less_than_1000       0.000024    0.002465  ...
# split-q_less_than_400                         0.000042    0.002975  ...
#
#                                          Narrative  Negative  Positive  \
# doc_id
# split-q_greater_than_1000                 0.121631  0.027387  0.021638
# split-q_greater_than_400_less_than_1000   0.126844  0.027110  0.022554
# split-q_less_than_400                     0.129655  0.026433  0.021138
#
#                                          PublicTerms  Reasoning  \
# doc_id
# split-q_greater_than_1000                   0.015134   0.004346
# split-q_greater_than_400_less_than_1000     0.014877   0.004483
# split-q_less_than_400                       0.014381   0.004471
#
#                                          Responsibility  Strategic  \
# doc_id
# split-q_greater_than_1000                      0.000401   0.011019
# split-q_greater_than_400_less_than_1000        0.000397   0.011796
# split-q_less_than_400                          0.000552   0.011924
#
#                                          Uncertainty  Untagged   Updates
# doc_id
# split-q_greater_than_1000                   0.000794  0.302905  0.002381
# split-q_greater_than_400_less_than_1000     0.000770  0.295862  0.002400
# split-q_less_than_400                       0.000960  0.294634  0.002210
#
# [3 rows x 37 columns]

# %% [markdown]
# #### 4.4.3.3 Weigh document terms by Term Frequencies in relation to Inverse Document Frequency (TF-IDF)

# %% [markdown]
# What's TF-IDF? It solves the raw-count problem, where all terms are treated equally. For instance, we would expect a corpus about pets to include high frequencies of terms like the nouns of pets: *cat*, *dog*, etc. Those raw counts aren't necessarily helpful in many cases, so one way to weigh the importance of terms to derive more targeted meaning from the corpus is by calculating either TF, IDF (Inverse Document Frequency), or TF-IDF.
#
# - TF: Relative frequency of a term within document by taking the sum of the term and dividing it by the sum total of all words in the document.
# - IDF: Calculation that diminishes the weight of terms that occur very frequently in the document set and increases the weight of terms that occur rarely. Hence, the IDF of a rare term is high, whereas the IDF of a frequent term is likely to be low.
#
# TF-IDF is the composite measure of TF and IDF. The tf-idf weighting scheme considers each document in a corpus as a vector, so it assigns to term $t$ a weight in document $d$. The end result? Each term can be considered in the following ways:
#
# 1. highest when $t$ occurs many times within a small number of documents (thus lending high discriminating power to those documents);
# 2. lower when the term occurs fewer times in a document, or occurs in many documents (thus offering a less pronounced relevance signal);
# 3. lowest when the term occurs in virtually all documents.
#
# <p style="background-color:#FFCCCB;color:black;margin:1rem;padding:1rem;font-size:0.9rem"><strong>NOTE</strong>: IDF should be based on a decently large corpora and should be representative of texts you would be using to extract keywords. Several articles on the web compute the IDF using only a handful of documents, so just be aware of this requirement.<br><br>To understand why IDF should be based on a fairly large collection, please read this <a href="./readings/IDF-explainer.pdf" target"_blank" rel="noopenner noreferrer">page from Standford's IR book</a> (<a href="https://nlp.stanford.edu/IR-book/html/htmledition/inverse-document-frequency-1.html" target"_blank" rel="noopenner noreferrer">original src</a>).</p>
#
# **Factoid**: Approximately 83% of digital libraries use text-based recommender systems that employ TF-IDF. (See Breitinger, Corinna; Gipp, Bela; Langer, Stefan (2015). Research-paper recommender systems: A literature survey. *International Journal on Digital Libraries*, 17(4), 305–338. doi:10.1007/s00799-015-0156-0.)

# %%
tfidf(dtm_POS).head(10)
# Out:
#                                             APPGE        AT       AT1  \
# doc_id
# split-q_greater_than_1000                0.005805  0.034768  0.019356
# split-q_greater_than_400_less_than_1000  0.006150  0.032670  0.018125
# split-q_less_than_400                    0.006285  0.032312  0.018464
#
#                                               BCL        CC       CCB  \
# doc_id
# split-q_greater_than_1000                0.000022  0.002730  0.000909
# split-q_greater_than_400_less_than_1000  0.000004  0.002822  0.000694
# split-q_less_than_400                    0.000016  0.002961  0.000890
#
#                                                CS       CSA       CSN  \
# doc_id
# split-q_greater_than_1000                0.003127  0.001432  0.000389
# split-q_greater_than_400_less_than_1000  0.003069  0.001431  0.000384
# split-q_less_than_400                    0.003504  0.001478  0.000490
#
#                                               CST  ...       VVD       VVG  \
# doc_id                                             ...
# split-q_greater_than_1000                0.002500  ...  0.013562  0.006121
# split-q_greater_than_400_less_than_1000  0.002446  ...  0.014111  0.005832
# split-q_less_than_400                    0.002201  ...  0.014323  0.005566
#
#                                              VVGK       VVI       VVN  \
# doc_id
# split-q_greater_than_1000                0.000082  0.006996  0.014470
# split-q_greater_than_400_less_than_1000  0.000031  0.007436  0.015048
# split-q_less_than_400                    0.000094  0.007960  0.015143
#
#                                              VVNK       VVZ        XX  \
# doc_id
# split-q_greater_than_1000                0.000005  0.008012  0.001814
# split-q_greater_than_400_less_than_1000  0.000000  0.007236  0.001881
# split-q_less_than_400                    0.000010  0.007127  0.002152
#
#                                               ZZ1       ZZ2
# doc_id
# split-q_greater_than_1000                0.002534  0.000007
# split-q_greater_than_400_less_than_1000  0.002089  0.000012
# split-q_less_than_400                    0.002107  0.000016
#
# [3 rows x 129 columns]

# %%
tfidf(dtm_DS).head(10)
# Out:
#                                          AcademicTerms  AcademicWritingMoves  \
# doc_id
# split-q_greater_than_1000                     0.029121              0.000556
# split-q_greater_than_400_less_than_1000       0.026423              0.000481
# split-q_less_than_400                         0.024942              0.000556
#
#                                          Character  Citation  \
# doc_id
# split-q_greater_than_1000                 0.060490  0.005477
# split-q_greater_than_400_less_than_1000   0.060921  0.005281
# split-q_less_than_400                     0.058307  0.005080
#
#                                          CitationAuthority  CitationHedged  \
# doc_id
# split-q_greater_than_1000                         0.000720        0.000004
# split-q_greater_than_400_less_than_1000           0.000540        0.000005
# split-q_less_than_400                             0.000699        0.000014
#
#                                          ConfidenceHedged  ConfidenceHigh  \
# doc_id
# split-q_greater_than_1000                        0.001833        0.002510
# split-q_greater_than_400_less_than_1000          0.001964        0.002577
# split-q_less_than_400                            0.002235        0.002735
#
#                                          ConfidenceLow  Contingent  ...  \
# doc_id                                                              ...
# split-q_greater_than_1000                     0.000000    0.001393  ...
# split-q_greater_than_400_less_than_1000       0.000017    0.001379  ...
# split-q_less_than_400                         0.000029    0.001665  ...
#
#                                          Narrative  Negative  Positive  \
# doc_id
# split-q_greater_than_1000                 0.068066  0.015326  0.012109
# split-q_greater_than_400_less_than_1000   0.070984  0.015171  0.012622
# split-q_less_than_400                     0.072557  0.014792  0.011829
#
#                                          PublicTerms  Reasoning  \
# doc_id
# split-q_greater_than_1000                   0.008469   0.002432
# split-q_greater_than_400_less_than_1000     0.008325   0.002509
# split-q_less_than_400                       0.008048   0.002502
#
#                                          Responsibility  Strategic  \
# doc_id
# split-q_greater_than_1000                      0.000224   0.006167
# split-q_greater_than_400_less_than_1000        0.000222   0.006601
# split-q_less_than_400                          0.000309   0.006673
#
#                                          Uncertainty  Untagged   Updates
# doc_id
# split-q_greater_than_1000                   0.000444  0.169510  0.001333
# split-q_greater_than_400_less_than_1000     0.000431  0.165569  0.001343
# split-q_less_than_400                       0.000537  0.164882  0.001237
#
# [3 rows x 37 columns]

# %% [markdown]
# ## 4.5 Application: Your turn to explore the data

# %% [markdown]
# Go back through the sections above. Explore the words and tags of your own interest. Consider importing a different dataset in the following folder `../data/04-textual-analysis`:
#
# Recall how this notebook uses data that I collected for a study on Kaggle notebooks. This NB uses data that I processed by sampling markdown cells by the position in which it occurs in the NB: the first third, second third, and last third ('../data/04-textual-analysis/kaggle-nb-examples/by-position'). Feel free to import the following other datasets and explore them.
#
# - **Kaggle NBs divded by distribution of their total votes**: `../data/04-textual-analysis/kaggle-nb-examples/by-votes`
# - **Amazon "Video Game" reviews by product ratings (1-5)** ([src](https://cseweb.ucsd.edu/~jmcauley/datasets/amazon_v2/)): `../data/04-textual-analysis/amazon`
# - **Jeopardy questions**: `../data/04-textual-analysis/jeopardy`

# %% [markdown]
# ## 4.6 Other Codebits

# %%
samp = """Who knew language and media were so tangled up with code, data, and computation?!"""
demo_doc = nlp_web_sm(samp)
options = {"compact": True, "distance": 50, "color": "yellow", "bg": "black", "font": "Gill Sans"}
displacy.render(demo_doc, style="dep", options=options)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\cradd\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 128 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y241sZmlsZQ%3D%3D?line=0'>1</a> samp = """Who knew language and media were so tangled up with code, data, and computation?!"""
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y241sZmlsZQ%3D%3D?line=1'>2</a> demo_doc = nlp_web_sm(samp)
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y241sZmlsZQ%3D%3D?line=2'>3</a> options = {"compact": True, "distance": 50, "color": "yellow", "bg": "black", "font": "Gill Sans"}
#       <a href='vscode-notebook-cell:/c%3A/Users/cradd/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y241sZmlsZQ%3D%3D?line=3'>4</a> displacy.render(demo_doc, style="dep", options=options)
#
# NameError: name 'nlp_web_sm' is not defined
